# %%
data = {'unpruned_accuracy': 76.01526568157354, 'target_accuracy': 60.81221254525883, 'ff_frac': 0.04, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 59.41872981700754, 'accuracy_difference': 16.596535864566, 'accuracy_ratio': 0.7816683831101957}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 75.89200534249188, 'accuracy_difference': 3.1673344781530233, 'accuracy_ratio': 0.9599372511162061}, 'civil': {'unpruned_accuracy': 41.12509834775767, 'pruned_accuracy': 39.94492525570417, 'accuracy_difference': 1.1801730920535007, 'accuracy_ratio': 0.9713028505835087}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.90018148820327, 'accuracy_difference': 0.42831215970960557, 'accuracy_ratio': 0.9947335535124522}, 'emotion': {'unpruned_accuracy': 29.09254447331601, 'pruned_accuracy': 28.68279032580452, 'accuracy_difference': 0.4097541475114923, 'accuracy_ratio': 0.9859154929577465}, 'math': {'unpruned_accuracy': 85.5248728940285, 'pruned_accuracy': 84.23885953544014, 'accuracy_difference': 1.286013358588363, 'accuracy_ratio': 0.9849632824338502}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 84.2238946378175, 'accuracy_difference': 1.3170272812794082, 'accuracy_ratio': 0.9846035411855272}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 54.45134575569358, 'accuracy_difference': 1.5971606033717833, 'accuracy_ratio': 0.9715039577836412}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.19393218322427, 'accuracy_difference': 0.6543723973825095, 'accuracy_ratio': 0.9880694143167028}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 59.84932010290334, 'accuracy_difference': 1.6078647556045595, 'accuracy_ratio': 0.9738376438929586}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 64.36836568805585, 'accuracy_difference': 1.1858085492971213, 'accuracy_ratio': 0.9819110138584974}, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.89855865717935, 'accuracy_difference': 0.5747126436781542, 'accuracy_ratio': 0.9924847906477395}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 54.89125489125489, 'accuracy_difference': 1.774501774501779, 'accuracy_ratio': 0.9686847599164926}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 51.342843089030985, 'accuracy_difference': 0.6296114117068399, 'accuracy_ratio': 0.9878856710202536}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 54.12121786967656, 'accuracy_difference': 2.1246324575547746, 'accuracy_ratio': 0.9622259696458685}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 53.91755391755392, 'accuracy_difference': 1.7563017563017596, 'accuracy_ratio': 0.9684537430532854}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 56.97300458045025, 'accuracy_difference': 2.680050677321894, 'accuracy_ratio': 0.9550727005391276}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 61.47966147966148, 'accuracy_difference': 2.1294021294021306, 'accuracy_ratio': 0.9665236051502146}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.38215372533621, 'accuracy_difference': 0.34357514479238915, 'accuracy_ratio': 0.9944338422391856}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 57.72086117297699, 'accuracy_difference': 1.1043058648849282, 'accuracy_ratio': 0.9812273229215965}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.128709018387, 'accuracy_difference': 0.797742971106139, 'accuracy_ratio': 0.9875209252777355}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.701492537313435, 'accuracy_difference': 1.1840796019900495, 'accuracy_ratio': 0.9811708860759494}, 'poems': {'unpruned_accuracy': 31.912775067210994, 'pruned_accuracy': 31.066414418002587, 'accuracy_difference': 0.8463606492084068, 'accuracy_ratio': 0.9734789391575662}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 30.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0714285714285714}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 47.407407407407405, 'accuracy_difference': 5.1851851851851904, 'accuracy_ratio': 0.9014084507042253}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 55.921052631578945, 'accuracy_difference': 2.631578947368425, 'accuracy_ratio': 0.9550561797752808}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 58.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0175438596491229}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 59.24528301886792, 'accuracy_difference': 4.905660377358487, 'accuracy_ratio': 0.9235294117647059}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 48.611111111111114, 'accuracy_difference': 15.972222222222214, 'accuracy_ratio': 0.7526881720430109}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 43.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.075}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 52.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9629629629629629}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9117647058823529}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 50.28901734104046, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 36.27450980392157, 'accuracy_difference': 3.9215686274509807, 'accuracy_ratio': 0.9024390243902439}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9384615384615385}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 48.51063829787234, 'accuracy_difference': -0.4255319148936181, 'accuracy_ratio': 1.008849557522124}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 37.719298245614034, 'accuracy_difference': 7.017543859649123, 'accuracy_ratio': 0.8431372549019608}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 49.6551724137931, 'accuracy_difference': 8.96551724137931, 'accuracy_ratio': 0.8470588235294118}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 36.77248677248677, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9025974025974026}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 41.26984126984127, 'accuracy_difference': -0.7936507936507979, 'accuracy_ratio': 1.019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.121212121212121}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 56.45161290322581, 'accuracy_difference': 9.677419354838705, 'accuracy_ratio': 0.853658536585366}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 45.8128078817734, 'accuracy_difference': 1.477832512315267, 'accuracy_ratio': 0.9687500000000001}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 69.6969696969697, 'accuracy_difference': -1.2121212121212182, 'accuracy_ratio': 1.0176991150442478}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 72.72727272727273, 'accuracy_difference': -2.525252525252526, 'accuracy_ratio': 1.0359712230215827}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 78.75647668393782, 'accuracy_difference': 3.626943005181346, 'accuracy_ratio': 0.9559748427672956}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.333333333333336, 'accuracy_difference': 1.538461538461533, 'accuracy_ratio': 0.97196261682243}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 36.2962962962963, 'accuracy_difference': -0.7407407407407405, 'accuracy_ratio': 1.0208333333333333}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 63.445378151260506, 'accuracy_difference': -3.3613445378151283, 'accuracy_ratio': 1.055944055944056}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 37.74834437086093, 'accuracy_difference': -2.649006622516559, 'accuracy_ratio': 1.0754716981132075}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 72.29357798165138, 'accuracy_difference': 2.2018348623853115, 'accuracy_ratio': 0.9704433497536947}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.75925925925926, 'accuracy_difference': -2.3148148148148167, 'accuracy_ratio': 1.0520833333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 77.45098039215686, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 73.41772151898734, 'accuracy_difference': 2.10970464135022, 'accuracy_ratio': 0.9720670391061451}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.98654708520179, 'accuracy_difference': -0.44843049327354123, 'accuracy_ratio': 1.0074074074074073}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 64.8854961832061, 'accuracy_difference': 4.580152671755727, 'accuracy_ratio': 0.9340659340659341}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 70.24793388429752, 'accuracy_difference': 4.132231404958674, 'accuracy_ratio': 0.9444444444444445}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9600000000000001}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 70.5521472392638, 'accuracy_difference': 1.2269938650306784, 'accuracy_ratio': 0.9829059829059829}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 42.857142857142854, 'accuracy_difference': 4.464285714285715, 'accuracy_ratio': 0.9056603773584906}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 67.96116504854369, 'accuracy_difference': 2.9126213592232943, 'accuracy_ratio': 0.9589041095890412}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 82.90598290598291, 'accuracy_difference': 0.8547008547008517, 'accuracy_ratio': 0.9897959183673469}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9206349206349206}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 73.69093231162196, 'accuracy_difference': 1.1494252873563227, 'accuracy_ratio': 0.984641638225256}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 63.872832369942195, 'accuracy_difference': 2.6011560693641584, 'accuracy_ratio': 0.9608695652173913}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 36.42458100558659, 'accuracy_difference': -1.5642458100558656, 'accuracy_ratio': 1.044871794871795}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 64.95176848874598, 'accuracy_difference': -2.5723472668810317, 'accuracy_ratio': 1.041237113402062}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 56.79012345679013, 'accuracy_difference': 8.641975308641975, 'accuracy_ratio': 0.8679245283018868}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 43.97163120567376, 'accuracy_difference': 2.4822695035460995, 'accuracy_ratio': 0.9465648854961832}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 41.916558018252935, 'accuracy_difference': 1.2385919165580148, 'accuracy_ratio': 0.9712990936555892}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 60.294117647058826, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 54.73856209150327, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.9490084985835695}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 69.0909090909091, 'accuracy_difference': -3.6363636363636402, 'accuracy_ratio': 1.0555555555555556}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 69.79591836734694, 'accuracy_difference': -2.448979591836732, 'accuracy_ratio': 1.0363636363636364}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 81.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0125}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 46.98795180722892, 'accuracy_difference': -0.6024096385542208, 'accuracy_ratio': 1.012987012987013}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.70175438596492, 'accuracy_difference': 0.5847953216374151, 'accuracy_ratio': 0.9928057553956836}}

data = {'unpruned_accuracy': 99.8001998001998, 'target_accuracy': 10.0, 'ff_frac': 0.421875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 8.89110889110889, 'accuracy_difference': 90.90909090909092,'accuracy_ratio': 0.0890890801623454}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 44.05594405594405, 'accuracy_difference': 55.244755244755254, 'accuracy_ratio': 0.44366192715235514}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 78.72127872127872, 'accuracy_difference': 20.879120879120876, 'accuracy_ratio': 0.790371033985817}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 75.22477522477523, 'accuracy_difference': 24.675324675324674, 'accuracy_ratio': 0.7529999246247076}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 72.12787212787212, 'accuracy_difference': 27.672327672327683, 'accuracy_ratio': 0.7227226503057683}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.61338661338661, 'accuracy_difference': 13.38661338661339, 'accuracy_ratio': 0.8661337795204881}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 89.1108891108891, 'accuracy_difference': 10.789210789210799, 'accuracy_ratio': 0.8919999107108089}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.33566433566433, 'accuracy_difference': 35.66433566433567, 'accuracy_ratio': 0.6433565790209854}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 60.13986013986014, 'accuracy_difference': 39.560439560439555, 'accuracy_ratio': 0.6032063523236916}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 67.73226773226773, 'accuracy_difference': 31.468531468531467, 'accuracy_ratio': 0.6827793873653407}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 63.93606393606394, 'accuracy_difference': 35.76423576423576, 'accuracy_ratio': 0.6412825008092402}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 61.438561438561436, 'accuracy_difference': 38.36163836163837, 'accuracy_ratio': 0.6156155539308138}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 61.938061938061935, 'accuracy_difference': 38.061938061938065, 'accuracy_ratio': 0.6193805574425636}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 71.72827172827172, 'accuracy_difference': 27.672327672327683, 'accuracy_ratio': 0.7216079676050676}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.76323676323676, 'accuracy_difference': 63.23676323676324, 'accuracy_ratio': 0.3676323308691345}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 33.96603396603397, 'accuracy_difference': 65.73426573426573, 'accuracy_ratio': 0.34068132855490885}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 77.82217782217782, 'accuracy_difference': 20.879120879120876, 'accuracy_ratio': 0.7884614585779434}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 79.92007992007991, 'accuracy_difference': 19.78021978021978, 'accuracy_ratio': 0.8016031260115501}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.51848151848152, 'accuracy_difference': 18.481518481518478, 'accuracy_ratio': 0.8151847336663418}}

# %%
data = {
"pile_Github": {'unpruned_accuracy': 76.4732713008575, 'target_accuracy': 61.17861704068601, 'ff_frac': 0.022, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 60.73709177157453, 'accuracy_difference': 15.736179529282971, 'accuracy_ratio': 0.7942264105928666}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 65.85117967332124, 'accuracy_difference': 15.477313974591638, 'accuracy_ratio': 0.8096938320092834}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 83.44308560677328, 'accuracy_difference': 2.097836312323622, 'accuracy_ratio': 0.9754756406026612}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 77.53291356611334, 'accuracy_difference': 1.5264262545315717, 'accuracy_ratio': 0.9806926511403403}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.69233780213328, 'accuracy_difference': 0.32292787944025747, 'accuracy_ratio': 0.9957518022657055}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 53.66262447007789, 'accuracy_difference': 2.385881888987477, 'accuracy_ratio': 0.9574318381706245}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 51.38806266111442, 'accuracy_difference': 3.4602419194923613, 'accuracy_ratio': 0.9369125090383226}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 60.859977949283355, 'accuracy_difference': 0.5972069092245462, 'accuracy_ratio': 0.9902825534459561}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.62790475279717, 'accuracy_difference': 2.926269484555796, 'accuracy_ratio': 0.9553610503282276}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 50.732550732550735, 'accuracy_difference': 5.933205933205933, 'accuracy_ratio': 0.8952946844387345}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 48.991637973438266, 'accuracy_difference': 2.9808165272995595, 'accuracy_ratio': 0.9426462237365133}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.86645167409656, 'accuracy_difference': 0.3793986531347784, 'accuracy_ratio': 0.9932546374367622}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.044954044954046, 'accuracy_difference': 1.6289016289016303, 'accuracy_ratio': 0.9707420725727361}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.00984309521489, 'accuracy_difference': 0.6432121625572549, 'accuracy_ratio': 0.9892174481293906}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 60.87906087906088, 'accuracy_difference': 2.730002730002731, 'accuracy_ratio': 0.9570815450643777}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 54.49101796407186, 'accuracy_difference': 7.2347109060567405, 'accuracy_ratio': 0.8827926208651399}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 56.12472160356347, 'accuracy_difference': 2.7004454342984445, 'accuracy_ratio': 0.9540937056318031}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.20653760093394, 'accuracy_difference': 0.7199143885591965, 'accuracy_ratio': 0.9887383959823467}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.6318407960199, 'accuracy_difference': 1.253731343283583, 'accuracy_ratio': 0.9800632911392405}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 32.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.1428571428571428}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 51.851851851851855, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9859154929577465}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 55.26315789473684, 'accuracy_difference': 3.2894736842105274, 'accuracy_ratio': 0.9438202247191011}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 56.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9824561403508771}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.39622641509434, 'accuracy_difference': 0.75471698113207, 'accuracy_ratio': 0.9882352941176471}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 65.27777777777777, 'accuracy_difference': -0.6944444444444429, 'accuracy_ratio': 1.010752688172043}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 46.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.15}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 51.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9444444444444444}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.088235294117647}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 33.333333333333336, 'accuracy_difference': 6.862745098039213, 'accuracy_ratio': 0.8292682926829269}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 69.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.0615384615384615}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 47.659574468085104, 'accuracy_difference': 0.4255319148936181, 'accuracy_ratio': 0.9911504424778761}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 43.85964912280702, 'accuracy_difference': 0.8771929824561369, 'accuracy_ratio': 0.9803921568627452}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 55.86206896551724, 'accuracy_difference': 2.7586206896551744, 'accuracy_ratio': 0.9529411764705882}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.35978835978836, 'accuracy_difference': 2.3809523809523796, 'accuracy_ratio': 0.9415584415584416}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 37.301587301587304, 'accuracy_difference': 3.1746031746031704, 'accuracy_ratio': 0.9215686274509804}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 67.09677419354838, 'accuracy_difference': -0.9677419354838719, 'accuracy_ratio': 1.0146341463414634}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 41.87192118226601, 'accuracy_difference': 5.418719211822662, 'accuracy_ratio': 0.8854166666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 71.71717171717172, 'accuracy_difference': -1.5151515151515156, 'accuracy_ratio': 1.0215827338129497}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.86528497409327, 'accuracy_difference': 0.5181347150258944, 'accuracy_ratio': 0.9937106918238995}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.38461538461539, 'accuracy_difference': -0.5128205128205181, 'accuracy_ratio': 1.0093457943925235}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 33.7037037037037, 'accuracy_difference': 1.8518518518518547, 'accuracy_ratio': 0.9479166666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 59.2436974789916, 'accuracy_difference': 0.8403361344537785, 'accuracy_ratio': 0.986013986013986}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 33.11258278145695, 'accuracy_difference': 1.9867549668874176, 'accuracy_ratio': 0.9433962264150944}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.57798165137615, 'accuracy_difference': 0.9174311926605441, 'accuracy_ratio': 0.9876847290640395}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 45.833333333333336, 'accuracy_difference': -1.3888888888888928, 'accuracy_ratio': 1.03125}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 63.228699551569505, 'accuracy_difference': -2.6905829596412545, 'accuracy_ratio': 1.0444444444444445}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 69.46564885496183, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 73.00613496932516, 'accuracy_difference': -1.2269938650306784, 'accuracy_ratio': 1.017094017094017}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 44.642857142857146, 'accuracy_difference': 2.6785714285714235, 'accuracy_ratio': 0.9433962264150945}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 72.81553398058253, 'accuracy_difference': -1.9417475728155438, 'accuracy_ratio': 1.0273972602739727}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 85.04273504273505, 'accuracy_difference': -1.2820512820512846, 'accuracy_ratio': 1.0153061224489797}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9682539682539683}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.73435504469987, 'accuracy_difference': -0.8939974457215811, 'accuracy_ratio': 1.0119453924914676}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.18497109826589, 'accuracy_difference': 0.28901734104046284, 'accuracy_ratio': 0.9956521739130435}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.85474860335196, 'accuracy_difference': 1.0055865921787657, 'accuracy_ratio': 0.9711538461538463}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 66.01307189542484, 'accuracy_difference': -0.9803921568627487, 'accuracy_ratio': 1.015075376884422}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 60.450160771704184, 'accuracy_difference': 1.9292604501607684, 'accuracy_ratio': 0.9690721649484536}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.35802469135803, 'accuracy_difference': -0.9259259259259238, 'accuracy_ratio': 1.0141509433962264}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.0354609929078, 'accuracy_difference': 1.418439716312058, 'accuracy_ratio': 0.9694656488549618}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 62.5, 'accuracy_difference': -2.205882352941174, 'accuracy_ratio': 1.0365853658536586}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.02614379084967, 'accuracy_difference': 0.6535947712418277, 'accuracy_ratio': 0.9886685552407932}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 64.54545454545455, 'accuracy_difference': 0.9090909090909065, 'accuracy_ratio': 0.9861111111111112}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.08163265306122, 'accuracy_difference': 3.2653061224489903, 'accuracy_ratio': 0.9515151515151513}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.08955223880596, 'accuracy_difference': 0.4975124378109541, 'accuracy_ratio': 0.9939759036144578}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 84.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.05}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.28654970760233, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}}
,"code": {'unpruned_accuracy': 81.32849364791288, 'target_accuracy': 65.06279491833031, 'ff_frac': 0.024, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 60.88305053822295, 'accuracy_difference': 15.590220762634551, 'accuracy_ratio': 0.7961350351902661}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 63.28130671506352, 'accuracy_difference': 18.047186932849357, 'accuracy_ratio': 0.7780951530839955}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 82.49294449670744, 'accuracy_difference': 3.047977422389465, 'accuracy_ratio': 0.9643681953150776}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 77.05590536157221, 'accuracy_difference': 2.003434459072693, 'accuracy_ratio': 0.9746591046216967}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.23241021626382, 'accuracy_difference': 0.7828554653097228, 'accuracy_ratio': 0.9897013388259526}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 53.21896874691906, 'accuracy_difference': 2.8295376121463036, 'accuracy_ratio': 0.9495162708883026}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 51.407892127701764, 'accuracy_difference': 3.440412452905015, 'accuracy_ratio': 0.9372740419378164}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 60.90591694230063, 'accuracy_difference': 0.5512679162072729, 'accuracy_ratio': 0.9910300493347287}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.9339198622932, 'accuracy_difference': 2.6202543750597656, 'accuracy_ratio': 0.9600291757840993}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 52.60715260715261, 'accuracy_difference': 4.058604058604061, 'accuracy_ratio': 0.9283764252449012}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 49.13920314805706, 'accuracy_difference': 2.8332513526807688, 'accuracy_ratio': 0.9454855195911414}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.83799677511145, 'accuracy_difference': 0.4078535521198887, 'accuracy_ratio': 0.9927487352445195}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.21785421785422, 'accuracy_difference': 1.4560014560014594, 'accuracy_ratio': 0.9738476626348479}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.10729948348114, 'accuracy_difference': 0.5457557742910026, 'accuracy_ratio': 0.990851168109786}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 60.06006006006006, 'accuracy_difference': 3.549003549003551, 'accuracy_ratio': 0.944206008583691}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 53.32286247177775, 'accuracy_difference': 8.402866398350845, 'accuracy_ratio': 0.8638676844783714}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 55.855605048255384, 'accuracy_difference': 2.9695619896065324, 'accuracy_ratio': 0.9495188515538728}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.29409475629925, 'accuracy_difference': 0.6323572331938863, 'accuracy_ratio': 0.9901080505250343}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.65174129353234, 'accuracy_difference': 1.2338308457711449, 'accuracy_ratio': 0.980379746835443}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 33.0, 'accuracy_difference': -5.0, 'accuracy_ratio': 1.1785714285714286}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 51.851851851851855, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9859154929577465}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 55.26315789473684, 'accuracy_difference': 3.2894736842105274, 'accuracy_ratio': 0.9438202247191011}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 58.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0175438596491229}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 62.64150943396226, 'accuracy_difference': 1.509433962264147, 'accuracy_ratio': 0.9764705882352942}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 0.6944444444444429, 'accuracy_ratio': 0.989247311827957}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 42.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.05}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 50.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9259259259259259}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 34.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 39.21568627450981, 'accuracy_difference': 0.9803921568627416, 'accuracy_ratio': 0.9756097560975611}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 66.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0153846153846153}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.53191489361702, 'accuracy_difference': 2.5531914893617014, 'accuracy_ratio': 0.9469026548672567}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 44.73684210526316, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 56.55172413793103, 'accuracy_difference': 2.068965517241381, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.35978835978836, 'accuracy_difference': 2.3809523809523796, 'accuracy_ratio': 0.9415584415584416}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 32.53968253968254, 'accuracy_difference': 7.936507936507937, 'accuracy_ratio': 0.803921568627451}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9090909090909091}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 65.48387096774194, 'accuracy_difference': 0.6451612903225765, 'accuracy_ratio': 0.9902439024390245}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 42.364532019704434, 'accuracy_difference': 4.926108374384235, 'accuracy_ratio': 0.8958333333333334}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9193548387096774}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 71.71717171717172, 'accuracy_difference': -1.5151515151515156, 'accuracy_ratio': 1.0215827338129497}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 82.38341968911917, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 54.35897435897436, 'accuracy_difference': 0.512820512820511, 'accuracy_ratio': 0.9906542056074766}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 33.333333333333336, 'accuracy_difference': 2.2222222222222214, 'accuracy_ratio': 0.9375}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 57.983193277310924, 'accuracy_difference': 2.1008403361344534, 'accuracy_ratio': 0.965034965034965}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 33.11258278145695, 'accuracy_difference': 1.9867549668874176, 'accuracy_ratio': 0.9433962264150944}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.39449541284404, 'accuracy_difference': 1.1009174311926557, 'accuracy_ratio': 0.9852216748768473}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.2962962962963, 'accuracy_difference': -1.8518518518518547, 'accuracy_ratio': 1.0416666666666667}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 63.228699551569505, 'accuracy_difference': -2.6905829596412545, 'accuracy_ratio': 1.0444444444444445}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 70.22900763358778, 'accuracy_difference': -0.7633587786259568, 'accuracy_ratio': 1.010989010989011}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9600000000000001}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 72.39263803680981, 'accuracy_difference': -0.6134969325153321, 'accuracy_ratio': 1.0085470085470085}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 44.642857142857146, 'accuracy_difference': 2.6785714285714235, 'accuracy_ratio': 0.9433962264150945}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 74.75728155339806, 'accuracy_difference': -3.8834951456310733, 'accuracy_ratio': 1.0547945205479452}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 84.1880341880342, 'accuracy_difference': -0.42735042735043294, 'accuracy_ratio': 1.0051020408163267}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 62.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9841269841269841}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.6066411238825, 'accuracy_difference': -0.7662835249042104, 'accuracy_ratio': 1.0102389078498293}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.47398843930635, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.5195530726257, 'accuracy_difference': 1.3407821229050256, 'accuracy_ratio': 0.9615384615384616}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 65.0326797385621, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 60.450160771704184, 'accuracy_difference': 1.9292604501607684, 'accuracy_ratio': 0.9690721649484536}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': -1.2345679012345698, 'accuracy_ratio': 1.0188679245283019}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.0354609929078, 'accuracy_difference': 1.418439716312058, 'accuracy_ratio': 0.9694656488549618}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 61.029411764705884, 'accuracy_difference': -0.735294117647058, 'accuracy_ratio': 1.0121951219512195}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 56.5359477124183, 'accuracy_difference': 1.143790849673202, 'accuracy_ratio': 0.9801699716713881}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 63.63636363636363, 'accuracy_difference': 1.8181818181818201, 'accuracy_ratio': 0.9722222222222222}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.89795918367346, 'accuracy_difference': 2.4489795918367463, 'accuracy_ratio': 0.9636363636363635}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 81.09452736318408, 'accuracy_difference': 1.492537313432834, 'accuracy_ratio': 0.9819277108433735}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 44.57831325301205, 'accuracy_difference': 1.8072289156626482, 'accuracy_ratio': 0.9610389610389611}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.87134502923976, 'accuracy_difference': -0.5847953216374293, 'accuracy_ratio': 1.0071942446043165}}
,"physics": {'unpruned_accuracy': 85.5409219190969, 'target_accuracy': 68.43273753527752, 'ff_frac': 0.016, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.52453931764276, 'accuracy_difference': 0.9487319832147421, 'accuracy_ratio': 0.9875939401169033}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.85662431941924, 'accuracy_difference': 0.4718693284936393, 'accuracy_ratio': 0.9941979826832099}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 67.39416745061148, 'accuracy_difference': 18.146754468485426, 'accuracy_ratio': 0.78785879247773}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 75.48177828658653, 'accuracy_difference': 3.5775615340583755, 'accuracy_ratio': 0.9547484011101727}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 74.68441139054703, 'accuracy_difference': 1.3308542910265118, 'accuracy_ratio': 0.9824922760041196}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 53.18939169870847, 'accuracy_difference': 2.8591146603568944, 'accuracy_ratio': 0.9489885664028145}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.59052151497125, 'accuracy_difference': 0.2577830656355289, 'accuracy_ratio': 0.99530007230658}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 60.51084160235207, 'accuracy_difference': 0.9463432561558278, 'accuracy_ratio': 0.9846015846912841}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 64.84651429664339, 'accuracy_difference': 0.7076599407095756, 'accuracy_ratio': 0.9892049598832968}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 56.08335608335609, 'accuracy_difference': 0.5824005824005809, 'accuracy_ratio': 0.9897221776136181}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 51.519921298573536, 'accuracy_difference': 0.4525332021642896, 'accuracy_ratio': 0.9912928260458073}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.724177179171015, 'accuracy_difference': 0.5216731480603229, 'accuracy_ratio': 0.9907251264755481}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.80935480935481, 'accuracy_difference': 0.8645008645008687, 'accuracy_ratio': 0.9844720496894409}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 58.70772829158951, 'accuracy_difference': 0.945326966182634, 'accuracy_ratio': 0.984152916190165}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 62.78096278096278, 'accuracy_difference': 0.8281008281008297, 'accuracy_ratio': 0.9869814020028612}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.38215372533621, 'accuracy_difference': 0.34357514479238915, 'accuracy_ratio': 0.9944338422391856}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 57.83221974758723, 'accuracy_difference': 0.9929472902746852, 'accuracy_ratio': 0.9831203659883262}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.371923338846194, 'accuracy_difference': 0.5545286506469438, 'accuracy_ratio': 0.9913255212296455}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.27860696517413, 'accuracy_difference': 0.6069651741293569, 'accuracy_ratio': 0.9903481012658227}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9642857142857143}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 50.370370370370374, 'accuracy_difference': 2.2222222222222214, 'accuracy_ratio': 0.9577464788732395}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 56.578947368421055, 'accuracy_difference': 1.973684210526315, 'accuracy_ratio': 0.9662921348314607}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.39622641509434, 'accuracy_difference': 0.75471698113207, 'accuracy_ratio': 0.9882352941176471}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.19444444444444, 'accuracy_difference': 1.3888888888888857, 'accuracy_ratio': 0.978494623655914}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 9.0, 'accuracy_ratio': 0.775}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 53.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9814814814814815}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 29.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.8529411764705882}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 29.41176470588235, 'accuracy_difference': 10.784313725490197, 'accuracy_ratio': 0.7317073170731707}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 65.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 43.40425531914894, 'accuracy_difference': 4.680851063829785, 'accuracy_ratio': 0.9026548672566372}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 38.59649122807018, 'accuracy_difference': 6.140350877192979, 'accuracy_ratio': 0.8627450980392157}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 49.6551724137931, 'accuracy_difference': 8.96551724137931, 'accuracy_ratio': 0.8470588235294118}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 34.39153439153439, 'accuracy_difference': 6.349206349206348, 'accuracy_ratio': 0.8441558441558442}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 38.095238095238095, 'accuracy_difference': 2.3809523809523796, 'accuracy_ratio': 0.9411764705882353}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 34.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0303030303030303}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 64.83870967741936, 'accuracy_difference': 1.290322580645153, 'accuracy_ratio': 0.9804878048780489}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 38.423645320197046, 'accuracy_difference': 8.866995073891623, 'accuracy_ratio': 0.8125000000000001}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9193548387096774}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.20202020202021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 79.79274611398964, 'accuracy_difference': 2.5906735751295287, 'accuracy_ratio': 0.9685534591194969}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.12820512820513, 'accuracy_difference': -0.2564102564102626, 'accuracy_ratio': 1.0046728971962617}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 31.11111111111111, 'accuracy_difference': 4.444444444444446, 'accuracy_ratio': 0.875}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.08403361344538, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 29.801324503311257, 'accuracy_difference': 5.298013245033111, 'accuracy_ratio': 0.8490566037735849}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.21100917431193, 'accuracy_difference': 1.2844036697247674, 'accuracy_ratio': 0.9827586206896552}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 41.2037037037037, 'accuracy_difference': 3.2407407407407405, 'accuracy_ratio': 0.9270833333333334}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.98654708520179, 'accuracy_difference': -0.44843049327354123, 'accuracy_ratio': 1.0074074074074073}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 70.99236641221374, 'accuracy_difference': -1.5267175572519136, 'accuracy_ratio': 1.0219780219780221}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 69.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 74.23312883435582, 'accuracy_difference': -2.4539877300613426, 'accuracy_ratio': 1.034188034188034}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 36.607142857142854, 'accuracy_difference': 10.714285714285715, 'accuracy_ratio': 0.7735849056603773}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 70.87378640776699, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.42735042735043294, 'accuracy_ratio': 0.9948979591836734}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 59.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9365079365079365}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.73435504469987, 'accuracy_difference': -0.8939974457215811, 'accuracy_ratio': 1.0119453924914676}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 64.16184971098266, 'accuracy_difference': 2.3121387283236885, 'accuracy_ratio': 0.965217391304348}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 32.960893854748605, 'accuracy_difference': 1.8994413407821185, 'accuracy_ratio': 0.9455128205128206}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 65.359477124183, 'accuracy_difference': -0.32679738562090677, 'accuracy_ratio': 1.0050251256281406}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 59.80707395498392, 'accuracy_difference': 2.5723472668810317, 'accuracy_ratio': 0.9587628865979381}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.12345679012346, 'accuracy_difference': 0.308641975308646, 'accuracy_ratio': 0.9952830188679245}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.744680851063826, 'accuracy_difference': 0.7092198581560325, 'accuracy_ratio': 0.9847328244274808}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 61.39705882352941, 'accuracy_difference': -1.102941176470587, 'accuracy_ratio': 1.0182926829268293}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.35294117647059, 'accuracy_difference': 0.32679738562091387, 'accuracy_ratio': 0.9943342776203966}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 68.9795918367347, 'accuracy_difference': -1.632653061224488, 'accuracy_ratio': 1.0242424242424242}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 84.07960199004975, 'accuracy_difference': -1.492537313432834, 'accuracy_ratio': 1.0180722891566265}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 78.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.975}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 42.7710843373494, 'accuracy_difference': 3.6144578313252964, 'accuracy_ratio': 0.9220779220779222}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.11695906432749, 'accuracy_difference': 1.1695906432748444, 'accuracy_ratio': 0.985611510791367}}
,"chemistry": {'unpruned_accuracy': 79.05933982064491, 'target_accuracy': 63.24747185651593, 'ff_frac': 0.004, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 76.3638022258712, 'accuracy_difference': 0.10946907498630765, 'accuracy_ratio': 0.9985685315519505}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 81.22686025408349, 'accuracy_difference': 0.1016333938293883, 'accuracy_ratio': 0.9987503347317684}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 83.50893697083725, 'accuracy_difference': 2.031984948259648, 'accuracy_ratio': 0.9762454635433849}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 62.449914138523184, 'accuracy_difference': 16.609425682121724, 'accuracy_ratio': 0.7899119102208279}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.69233780213328, 'accuracy_difference': 0.32292787944025747, 'accuracy_ratio': 0.9957518022657055}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 55.61470965197673, 'accuracy_difference': 0.43379670708863216, 'accuracy_ratio': 0.9922603342128408}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.64009518143962, 'accuracy_difference': 0.20820939916715986, 'accuracy_ratio': 0.9962039045553146}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 61.640940830576994, 'accuracy_difference': -0.18375597206909333, 'accuracy_ratio': 1.0029899835550904}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 65.63067801472698, 'accuracy_difference': -0.0765037773740147, 'accuracy_ratio': 1.001167031363968}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 56.6020566020566, 'accuracy_difference': 0.0637000637000682, 'accuracy_ratio': 0.9988758631764894}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 52.08066896212494, 'accuracy_difference': -0.10821446138711366, 'accuracy_ratio': 1.0020821502933939}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.82851180878308, 'accuracy_difference': 0.4173385184482612, 'accuracy_ratio': 0.9925801011804384}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 55.73755573755574, 'accuracy_difference': -0.0637000637000611, 'accuracy_ratio': 1.0011441647597255}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 58.70772829158951, 'accuracy_difference': 0.945326966182634, 'accuracy_ratio': 0.984152916190165}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 63.17226317226317, 'accuracy_difference': 0.43680043680043923, 'accuracy_ratio': 0.9931330472103004}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 62.1282026111711, 'accuracy_difference': -0.402473741042499, 'accuracy_ratio': 1.0065203562340965}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 58.66740905716407, 'accuracy_difference': 0.15775798069784486, 'accuracy_ratio': 0.9973181889887995}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.80970911567273, 'accuracy_difference': 0.1167428738204066, 'accuracy_ratio': 0.9981737939430833}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.78606965174129, 'accuracy_difference': 0.09950248756219082, 'accuracy_ratio': 0.9984177215189873}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 28.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 51.111111111111114, 'accuracy_difference': 1.481481481481481, 'accuracy_ratio': 0.971830985915493}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 59.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0350877192982457}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 60.75471698113208, 'accuracy_difference': 3.3962264150943327, 'accuracy_ratio': 0.9470588235294118}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 61.80555555555556, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9569892473118281}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 32.0, 'accuracy_difference': 8.0, 'accuracy_ratio': 0.8}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 54.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 40.19607843137255, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 67.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0307692307692307}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 3.4042553191489375, 'accuracy_ratio': 0.9292035398230089}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 42.10526315789474, 'accuracy_difference': 2.6315789473684177, 'accuracy_ratio': 0.9411764705882354}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 56.55172413793103, 'accuracy_difference': 2.068965517241381, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.682539682539684, 'accuracy_difference': 1.0582010582010568, 'accuracy_ratio': 0.974025974025974}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 36.507936507936506, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 35.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0606060606060606}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 65.48387096774194, 'accuracy_difference': 0.6451612903225765, 'accuracy_ratio': 0.9902439024390245}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 40.88669950738916, 'accuracy_difference': 6.403940886699509, 'accuracy_ratio': 0.8645833333333333}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 62.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.70707070707071, 'accuracy_difference': -0.5050505050505052, 'accuracy_ratio': 1.0071942446043165}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.86528497409327, 'accuracy_difference': 0.5181347150258944, 'accuracy_ratio': 0.9937106918238995}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 56.41025641025641, 'accuracy_difference': -1.53846153846154, 'accuracy_ratio': 1.0280373831775702}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 37.03703703703704, 'accuracy_difference': -1.481481481481481, 'accuracy_ratio': 1.0416666666666667}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.08403361344538, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 34.437086092715234, 'accuracy_difference': 0.6622516556291345, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.94495412844037, 'accuracy_difference': 0.5504587155963208, 'accuracy_ratio': 0.9926108374384238}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.75925925925926, 'accuracy_difference': -2.3148148148148167, 'accuracy_ratio': 1.0520833333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.98654708520179, 'accuracy_difference': -0.44843049327354123, 'accuracy_ratio': 1.0074074074074073}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 71.7557251908397, 'accuracy_difference': -2.2900763358778704, 'accuracy_ratio': 1.032967032967033}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 75.20661157024793, 'accuracy_difference': -0.8264462809917319, 'accuracy_ratio': 1.011111111111111}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 68.51851851851852, 'accuracy_difference': 0.9259259259259238, 'accuracy_ratio': 0.9866666666666667}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 71.77914110429448, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 46.42857142857143, 'accuracy_difference': 0.8928571428571388, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 73.7864077669903, 'accuracy_difference': -2.9126213592233086, 'accuracy_ratio': 1.041095890410959}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.42735042735043294, 'accuracy_ratio': 0.9948979591836734}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9682539682539683}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 74.96807151979566, 'accuracy_difference': -0.12771392081737076, 'accuracy_ratio': 1.0017064846416381}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.76300578034682, 'accuracy_difference': -0.28901734104046284, 'accuracy_ratio': 1.0043478260869565}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.29608938547486, 'accuracy_difference': 1.5642458100558656, 'accuracy_ratio': 0.9551282051282052}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 63.071895424836605, 'accuracy_difference': 1.9607843137254903, 'accuracy_ratio': 0.9698492462311558}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 61.09324758842444, 'accuracy_difference': 1.2861736334405123, 'accuracy_ratio': 0.9793814432989691}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.04938271604938, 'accuracy_difference': -0.6172839506172778, 'accuracy_ratio': 1.0094339622641508}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 46.45390070921986, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 60.294117647058826, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 58.169934640522875, 'accuracy_difference': -0.49019607843137436, 'accuracy_ratio': 1.0084985835694051}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 68.18181818181819, 'accuracy_difference': -2.7272727272727337, 'accuracy_ratio': 1.0416666666666667}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 67.75510204081633, 'accuracy_difference': -0.4081632653061149, 'accuracy_ratio': 1.0060606060606059}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 83.08457711442786, 'accuracy_difference': -0.4975124378109399, 'accuracy_ratio': 1.006024096385542}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 82.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.025}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 45.18072289156626, 'accuracy_difference': 1.2048192771084345, 'accuracy_ratio': 0.974025974025974}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.70175438596492, 'accuracy_difference': 0.5847953216374151, 'accuracy_ratio': 0.9928057553956836}}
,"biology": {'unpruned_accuracy': 76.01526568157354, 'target_accuracy': 60.81221254525883, 'ff_frac': 0.04, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.89855865717935, 'accuracy_difference': 0.5747126436781542, 'accuracy_ratio': 0.9924847906477395}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.90018148820327, 'accuracy_difference': 0.42831215970960557, 'accuracy_ratio': 0.9947335535124522}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 84.2238946378175, 'accuracy_difference': 1.3170272812794082, 'accuracy_ratio': 0.9846035411855272}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 75.89200534249188, 'accuracy_difference': 3.1673344781530233, 'accuracy_ratio': 0.9599372511162061}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 59.41872981700754, 'accuracy_difference': 16.596535864566, 'accuracy_ratio': 0.7816683831101957}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 54.45134575569358, 'accuracy_difference': 1.5971606033717833, 'accuracy_ratio': 0.9715039577836412}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.19393218322427, 'accuracy_difference': 0.6543723973825095, 'accuracy_ratio': 0.9880694143167028}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 59.84932010290334, 'accuracy_difference': 1.6078647556045595, 'accuracy_ratio': 0.9738376438929586}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 64.36836568805585, 'accuracy_difference': 1.1858085492971213, 'accuracy_ratio': 0.9819110138584974}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 54.89125489125489, 'accuracy_difference': 1.774501774501779, 'accuracy_ratio': 0.9686847599164926}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 51.342843089030985, 'accuracy_difference': 0.6296114117068399, 'accuracy_ratio': 0.9878856710202536}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 54.12121786967656, 'accuracy_difference': 2.1246324575547746, 'accuracy_ratio': 0.9622259696458685}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 53.91755391755392, 'accuracy_difference': 1.7563017563017596, 'accuracy_ratio': 0.9684537430532854}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 56.97300458045025, 'accuracy_difference': 2.680050677321894, 'accuracy_ratio': 0.9550727005391276}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 61.47966147966148, 'accuracy_difference': 2.1294021294021306, 'accuracy_ratio': 0.9665236051502146}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.38215372533621, 'accuracy_difference': 0.34357514479238915, 'accuracy_ratio': 0.9944338422391856}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 57.72086117297699, 'accuracy_difference': 1.1043058648849282, 'accuracy_ratio': 0.9812273229215965}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.128709018387, 'accuracy_difference': 0.797742971106139, 'accuracy_ratio': 0.9875209252777355}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.701492537313435, 'accuracy_difference': 1.1840796019900495, 'accuracy_ratio': 0.9811708860759494}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 30.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0714285714285714}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 47.407407407407405, 'accuracy_difference': 5.1851851851851904, 'accuracy_ratio': 0.9014084507042253}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 55.921052631578945, 'accuracy_difference': 2.631578947368425, 'accuracy_ratio': 0.9550561797752808}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 58.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0175438596491229}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 59.24528301886792, 'accuracy_difference': 4.905660377358487, 'accuracy_ratio': 0.9235294117647059}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 48.611111111111114, 'accuracy_difference': 15.972222222222214, 'accuracy_ratio': 0.7526881720430109}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 43.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.075}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 52.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9629629629629629}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9117647058823529}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 36.27450980392157, 'accuracy_difference': 3.9215686274509807, 'accuracy_ratio': 0.9024390243902439}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9384615384615385}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 48.51063829787234, 'accuracy_difference': -0.4255319148936181, 'accuracy_ratio': 1.008849557522124}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 37.719298245614034, 'accuracy_difference': 7.017543859649123, 'accuracy_ratio': 0.8431372549019608}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 49.6551724137931, 'accuracy_difference': 8.96551724137931, 'accuracy_ratio': 0.8470588235294118}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 36.77248677248677, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9025974025974026}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 41.26984126984127, 'accuracy_difference': -0.7936507936507979, 'accuracy_ratio': 1.019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.121212121212121}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 56.45161290322581, 'accuracy_difference': 9.677419354838705, 'accuracy_ratio': 0.853658536585366}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 45.8128078817734, 'accuracy_difference': 1.477832512315267, 'accuracy_ratio': 0.9687500000000001}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 72.72727272727273, 'accuracy_difference': -2.525252525252526, 'accuracy_ratio': 1.0359712230215827}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 78.75647668393782, 'accuracy_difference': 3.626943005181346, 'accuracy_ratio': 0.9559748427672956}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.333333333333336, 'accuracy_difference': 1.538461538461533, 'accuracy_ratio': 0.97196261682243}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 36.2962962962963, 'accuracy_difference': -0.7407407407407405, 'accuracy_ratio': 1.0208333333333333}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 63.445378151260506, 'accuracy_difference': -3.3613445378151283, 'accuracy_ratio': 1.055944055944056}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 37.74834437086093, 'accuracy_difference': -2.649006622516559, 'accuracy_ratio': 1.0754716981132075}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 72.29357798165138, 'accuracy_difference': 2.2018348623853115, 'accuracy_ratio': 0.9704433497536947}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.75925925925926, 'accuracy_difference': -2.3148148148148167, 'accuracy_ratio': 1.0520833333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.98654708520179, 'accuracy_difference': -0.44843049327354123, 'accuracy_ratio': 1.0074074074074073}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 64.8854961832061, 'accuracy_difference': 4.580152671755727, 'accuracy_ratio': 0.9340659340659341}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 70.24793388429752, 'accuracy_difference': 4.132231404958674, 'accuracy_ratio': 0.9444444444444445}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9600000000000001}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 70.5521472392638, 'accuracy_difference': 1.2269938650306784, 'accuracy_ratio': 0.9829059829059829}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 42.857142857142854, 'accuracy_difference': 4.464285714285715, 'accuracy_ratio': 0.9056603773584906}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 67.96116504854369, 'accuracy_difference': 2.9126213592232943, 'accuracy_ratio': 0.9589041095890412}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 82.90598290598291, 'accuracy_difference': 0.8547008547008517, 'accuracy_ratio': 0.9897959183673469}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9206349206349206}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 73.69093231162196, 'accuracy_difference': 1.1494252873563227, 'accuracy_ratio': 0.984641638225256}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 63.872832369942195, 'accuracy_difference': 2.6011560693641584, 'accuracy_ratio': 0.9608695652173913}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 36.42458100558659, 'accuracy_difference': -1.5642458100558656, 'accuracy_ratio': 1.044871794871795}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 64.95176848874598, 'accuracy_difference': -2.5723472668810317, 'accuracy_ratio': 1.041237113402062}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 56.79012345679013, 'accuracy_difference': 8.641975308641975, 'accuracy_ratio': 0.8679245283018868}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 43.97163120567376, 'accuracy_difference': 2.4822695035460995, 'accuracy_ratio': 0.9465648854961832}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 60.294117647058826, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 54.73856209150327, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.9490084985835695}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 69.0909090909091, 'accuracy_difference': -3.6363636363636402, 'accuracy_ratio': 1.0555555555555556}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 69.79591836734694, 'accuracy_difference': -2.448979591836732, 'accuracy_ratio': 1.0363636363636364}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 81.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0125}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 46.98795180722892, 'accuracy_difference': -0.6024096385542208, 'accuracy_ratio': 1.012987012987013}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.70175438596492, 'accuracy_difference': 0.5847953216374151, 'accuracy_ratio': 0.9928057553956836}}
,"pile_ArXiv": {'unpruned_accuracy': 56.048506359065364, 'target_accuracy': 44.8388050872523, 'ff_frac': 0.048, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 72.77869002006933, 'accuracy_difference': 3.694581280788171, 'accuracy_ratio': 0.9516879398783252}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 77.71324863883848, 'accuracy_difference': 3.6152450090743997, 'accuracy_ratio': 0.9555476211729003}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 72.46472248353716, 'accuracy_difference': 13.076199435559744, 'accuracy_ratio': 0.8471351589134498}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 72.92501431024614, 'accuracy_difference': 6.134325510398767, 'accuracy_ratio': 0.9224085917702427}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 73.64712789901165, 'accuracy_difference': 2.368137782561888, 'accuracy_ratio': 0.9688465499485068}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 43.70501823917973, 'accuracy_difference': 12.343488119885635, 'accuracy_ratio': 0.7797713280562885}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 52.07217925837795, 'accuracy_difference': 2.776125322228829, 'accuracy_ratio': 0.9493853940708605}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 58.8662256523337, 'accuracy_difference': 2.5909592061741975, 'accuracy_ratio': 0.9578412318732248}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.302763698957634, 'accuracy_difference': 3.2514105383953336, 'accuracy_ratio': 0.950401167031364}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 52.70725270725271, 'accuracy_difference': 3.958503958503961, 'accuracy_ratio': 0.9301429259675605}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 49.31628135759961, 'accuracy_difference': 2.6561731431382185, 'accuracy_ratio': 0.9488926746166951}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 53.74181921654178, 'accuracy_difference': 2.50403111068956, 'accuracy_ratio': 0.9554806070826306}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 51.515151515151516, 'accuracy_difference': 4.158704158704161, 'accuracy_ratio': 0.9253023864007845}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 56.74885488743787, 'accuracy_difference': 2.904200370334273, 'accuracy_ratio': 0.9513151445842183}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 56.61115661115661, 'accuracy_difference': 6.997906997907002, 'accuracy_ratio': 0.8899856938483547}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 57.907136546578975, 'accuracy_difference': 3.8185923235496233, 'accuracy_ratio': 0.9381361323155216}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 56.74647364513734, 'accuracy_difference': 2.078693392724574, 'accuracy_ratio': 0.964663196087711}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 62.08775172682167, 'accuracy_difference': 1.8387002626714661, 'accuracy_ratio': 0.9712372546035611}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 60.42786069651741, 'accuracy_difference': 2.4577114427860707, 'accuracy_ratio': 0.9609177215189874}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9642857142857143}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 42.22222222222222, 'accuracy_difference': 10.370370370370374, 'accuracy_ratio': 0.8028169014084506}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 40.13157894736842, 'accuracy_difference': 18.421052631578952, 'accuracy_ratio': 0.6853932584269662}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 56.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9824561403508771}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 60.37735849056604, 'accuracy_difference': 3.773584905660371, 'accuracy_ratio': 0.9411764705882354}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 59.02777777777778, 'accuracy_difference': 5.55555555555555, 'accuracy_ratio': 0.913978494623656}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 10.0, 'accuracy_ratio': 0.75}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 48.0, 'accuracy_difference': 6.0, 'accuracy_ratio': 0.8888888888888888}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 35.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0294117647058822}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 32.35294117647059, 'accuracy_difference': 7.843137254901961, 'accuracy_ratio': 0.8048780487804877}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9692307692307692}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 42.5531914893617, 'accuracy_difference': 5.531914893617021, 'accuracy_ratio': 0.8849557522123894}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 31.57894736842105, 'accuracy_difference': 13.157894736842106, 'accuracy_ratio': 0.7058823529411764}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 47.58620689655172, 'accuracy_difference': 11.03448275862069, 'accuracy_ratio': 0.8117647058823529}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 32.53968253968254, 'accuracy_difference': 8.201058201058203, 'accuracy_ratio': 0.7987012987012987}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 37.301587301587304, 'accuracy_difference': 3.1746031746031704, 'accuracy_ratio': 0.9215686274509804}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9090909090909091}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 60.96774193548387, 'accuracy_difference': 5.161290322580641, 'accuracy_ratio': 0.9219512195121952}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 35.467980295566505, 'accuracy_difference': 11.822660098522164, 'accuracy_ratio': 0.7500000000000001}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9354838709677419}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 57.57575757575758, 'accuracy_difference': 12.62626262626263, 'accuracy_ratio': 0.8201438848920863}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 75.64766839378238, 'accuracy_difference': 6.735751295336783, 'accuracy_ratio': 0.9182389937106918}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 52.82051282051282, 'accuracy_difference': 2.051282051282051, 'accuracy_ratio': 0.9626168224299065}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 30.74074074074074, 'accuracy_difference': 4.814814814814817, 'accuracy_ratio': 0.8645833333333333}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 53.78151260504202, 'accuracy_difference': 6.30252100840336, 'accuracy_ratio': 0.8951048951048951}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 29.13907284768212, 'accuracy_difference': 5.960264900662249, 'accuracy_ratio': 0.8301886792452831}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 65.3211009174312, 'accuracy_difference': 9.174311926605498, 'accuracy_ratio': 0.8768472906403941}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 42.592592592592595, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9583333333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 55.15695067264574, 'accuracy_difference': 5.381165919282509, 'accuracy_ratio': 0.9111111111111111}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 63.3587786259542, 'accuracy_difference': 6.106870229007626, 'accuracy_ratio': 0.9120879120879122}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 72.72727272727273, 'accuracy_difference': 1.6528925619834638, 'accuracy_ratio': 0.9777777777777779}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 65.6441717791411, 'accuracy_difference': 6.134969325153378, 'accuracy_ratio': 0.9145299145299145}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 35.714285714285715, 'accuracy_difference': 11.607142857142854, 'accuracy_ratio': 0.7547169811320755}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 66.99029126213593, 'accuracy_difference': 3.883495145631059, 'accuracy_ratio': 0.9452054794520549}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 79.05982905982906, 'accuracy_difference': 4.7008547008547055, 'accuracy_ratio': 0.9438775510204082}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9206349206349206}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 60.40868454661558, 'accuracy_difference': 14.431673052362704, 'accuracy_ratio': 0.8071672354948806}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 64.73988439306359, 'accuracy_difference': 1.7341040462427628, 'accuracy_ratio': 0.973913043478261}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 37.76536312849162, 'accuracy_difference': -2.9050279329608983, 'accuracy_ratio': 1.0833333333333335}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 61.43790849673203, 'accuracy_difference': 3.594771241830067, 'accuracy_ratio': 0.9447236180904522}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 59.48553054662379, 'accuracy_difference': 2.8938906752411597, 'accuracy_ratio': 0.9536082474226804}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 57.71604938271605, 'accuracy_difference': 7.716049382716051, 'accuracy_ratio': 0.8820754716981132}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.326241134751776, 'accuracy_difference': 2.1276595744680833, 'accuracy_ratio': 0.9541984732824428}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 57.720588235294116, 'accuracy_difference': 2.57352941176471, 'accuracy_ratio': 0.9573170731707317}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 52.77777777777778, 'accuracy_difference': 4.901960784313722, 'accuracy_ratio': 0.9150141643059491}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 53.63636363636363, 'accuracy_difference': 11.81818181818182, 'accuracy_ratio': 0.8194444444444444}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 68.57142857142857, 'accuracy_difference': -1.224489795918359, 'accuracy_ratio': 1.018181818181818}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 79.60199004975124, 'accuracy_difference': 2.985074626865682, 'accuracy_ratio': 0.9638554216867469}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 77.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9625}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 42.16867469879518, 'accuracy_difference': 4.216867469879517, 'accuracy_ratio': 0.9090909090909091}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 71.34502923976608, 'accuracy_difference': 9.941520467836256, 'accuracy_ratio': 0.8776978417266187}}
,"pile_Enron_Emails": {'unpruned_accuracy': 54.84830458060678, 'target_accuracy': 43.87864366448542, 'ff_frac': 0.020083984374999996, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 70.15143222039774, 'accuracy_difference': 6.3218390804597675, 'accuracy_ratio': 0.9173326971251342}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 77.69872958257713, 'accuracy_difference': 3.629764065335749, 'accuracy_ratio': 0.9553690975631528}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 84.77892756349954, 'accuracy_difference': 0.7619943555973663, 'accuracy_ratio': 0.9910920488287693}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 78.00038160656364, 'accuracy_difference': 1.0589582140812723, 'accuracy_ratio': 0.9866055267286112}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.6531950288678, 'accuracy_difference': 0.36207065270573935, 'accuracy_ratio': 0.9952368692070032}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 54.80627033422064, 'accuracy_difference': 1.242236024844722, 'accuracy_ratio': 0.9778364116094986}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 45.27067221891731, 'accuracy_difference': 9.577632361689467, 'accuracy_ratio': 0.8253796095444687}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 59.84932010290334, 'accuracy_difference': 1.6078647556045595, 'accuracy_ratio': 0.9738376438929586}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 58.37238213636798, 'accuracy_difference': 7.181792100984985, 'accuracy_ratio': 0.8904449307075127}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 45.327145327145324, 'accuracy_difference': 11.338611338611344, 'accuracy_ratio': 0.7999036454151276}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 48.657156910969015, 'accuracy_difference': 3.315297589768811, 'accuracy_ratio': 0.9362104864660231}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.02228967087167, 'accuracy_difference': 1.2235606563596662, 'accuracy_ratio': 0.9782462057335582}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 52.752752752752755, 'accuracy_difference': 2.9211029211029214, 'accuracy_ratio': 0.9475318731611638}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 58.132735600818634, 'accuracy_difference': 1.520319656953511, 'accuracy_ratio': 0.9745139683058324}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 61.62526162526162, 'accuracy_difference': 1.983801983801989, 'accuracy_ratio': 0.9688125894134477}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 60.42014331991754, 'accuracy_difference': 1.305585550211056, 'accuracy_ratio': 0.9788486005089058}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 55.688567186340016, 'accuracy_difference': 3.1365998515219005, 'accuracy_ratio': 0.9466792869537782}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 62.87576612510944, 'accuracy_difference': 1.050685864383695, 'accuracy_ratio': 0.9835641454877492}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.134328358208954, 'accuracy_difference': 1.75124378109453, 'accuracy_ratio': 0.9721518987341772}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 30.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0714285714285714}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 52.592592592592595, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 54.60526315789474, 'accuracy_difference': 3.94736842105263, 'accuracy_ratio': 0.9325842696629214}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 60.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0526315789473684}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 61.886792452830186, 'accuracy_difference': 2.264150943396224, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 65.97222222222223, 'accuracy_difference': -1.3888888888889, 'accuracy_ratio': 1.0215053763440862}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 36.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 52.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9629629629629629}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 29.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.8529411764705882}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 44.11764705882353, 'accuracy_difference': -3.9215686274509807, 'accuracy_ratio': 1.0975609756097562}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 68.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0461538461538462}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 49.787234042553195, 'accuracy_difference': -1.7021276595744723, 'accuracy_ratio': 1.0353982300884956}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 40.35087719298246, 'accuracy_difference': 4.3859649122806985, 'accuracy_ratio': 0.9019607843137256}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 53.793103448275865, 'accuracy_difference': 4.827586206896548, 'accuracy_ratio': 0.9176470588235295}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.62433862433863, 'accuracy_difference': 2.1164021164021136, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 37.301587301587304, 'accuracy_difference': 3.1746031746031704, 'accuracy_ratio': 0.9215686274509804}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 35.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0606060606060606}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 66.45161290322581, 'accuracy_difference': -0.32258064516129537, 'accuracy_ratio': 1.0048780487804878}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 44.33497536945813, 'accuracy_difference': 2.955665024630541, 'accuracy_ratio': 0.9375}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 63.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0161290322580645}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.20202020202021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 80.82901554404145, 'accuracy_difference': 1.5544041450777115, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.58974358974359, 'accuracy_difference': 1.2820512820512775, 'accuracy_ratio': 0.9766355140186916}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 35.18518518518518, 'accuracy_difference': 0.3703703703703738, 'accuracy_ratio': 0.9895833333333333}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 57.983193277310924, 'accuracy_difference': 2.1008403361344534, 'accuracy_ratio': 0.965034965034965}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 36.42384105960265, 'accuracy_difference': -1.3245033112582831, 'accuracy_ratio': 1.037735849056604}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.94495412844037, 'accuracy_difference': 0.5504587155963208, 'accuracy_ratio': 0.9926108374384238}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 45.370370370370374, 'accuracy_difference': -0.9259259259259309, 'accuracy_ratio': 1.0208333333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 62.780269058295964, 'accuracy_difference': -2.2421524663677133, 'accuracy_ratio': 1.037037037037037}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 70.99236641221374, 'accuracy_difference': -1.5267175572519136, 'accuracy_ratio': 1.0219780219780221}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 72.72727272727273, 'accuracy_difference': 1.6528925619834638, 'accuracy_ratio': 0.9777777777777779}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9600000000000001}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 69.93865030674847, 'accuracy_difference': 1.8404907975460105, 'accuracy_ratio': 0.9743589743589743}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 48.214285714285715, 'accuracy_difference': -0.8928571428571459, 'accuracy_ratio': 1.0188679245283019}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 71.84466019417475, 'accuracy_difference': -0.9708737864077648, 'accuracy_ratio': 1.0136986301369864}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.42735042735043294, 'accuracy_ratio': 0.9948979591836734}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 73.30779054916987, 'accuracy_difference': 1.5325670498084207, 'accuracy_ratio': 0.9795221843003414}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.47398843930635, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.86033519553072, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.05228758169935, 'accuracy_difference': 0.9803921568627487, 'accuracy_ratio': 0.9849246231155778}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 63.98713826366559, 'accuracy_difference': -1.6077170418006403, 'accuracy_ratio': 1.0257731958762886}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.35802469135803, 'accuracy_difference': -0.9259259259259238, 'accuracy_ratio': 1.0141509433962264}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.39007092198582, 'accuracy_difference': 1.0638297872340416, 'accuracy_ratio': 0.9770992366412214}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 63.23529411764706, 'accuracy_difference': -2.941176470588232, 'accuracy_ratio': 1.048780487804878}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.51633986928105, 'accuracy_difference': 0.16339869281045338, 'accuracy_ratio': 0.9971671388101984}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 67.34693877551021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 84.07960199004975, 'accuracy_difference': -1.492537313432834, 'accuracy_ratio': 1.0180722891566265}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 79.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9875}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 40.36144578313253, 'accuracy_difference': 6.024096385542165, 'accuracy_ratio': 0.8701298701298702}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 78.94736842105263, 'accuracy_difference': 2.339181286549703, 'accuracy_ratio': 0.9712230215827339}},
"pile_EuroParl": {'unpruned_accuracy': 61.4571848585079, 'target_accuracy': 49.16574788680632, 'ff_frac': 0.0025, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 76.38204707170225, 'accuracy_difference': 0.09122422915525874, 'accuracy_ratio': 0.9988071096266253}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 81.2994555353902, 'accuracy_difference': 0.0290381125226844, 'accuracy_ratio': 0.9996429527805052}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 85.68203198494825, 'accuracy_difference': -0.14111006585135044, 'accuracy_ratio': 1.0016496205872647}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 79.00209883609998, 'accuracy_difference': 0.05724098454493287, 'accuracy_ratio': 0.9992759744177627}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 76.03483706820629, 'accuracy_difference': -0.019571386632748045, 'accuracy_ratio': 1.0002574665293513}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 56.078083407275955, 'accuracy_difference': -0.029577048210590817, 'accuracy_ratio': 1.0005277044854881}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.739242514376365, 'accuracy_difference': 0.1090620662304147, 'accuracy_ratio': 0.9980115690527839}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 48.02462330025726, 'accuracy_difference': 13.43256155825064, 'accuracy_ratio': 0.7814322021228883}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 65.61155207038348, 'accuracy_difference': -0.05737783303051458, 'accuracy_ratio': 1.000875273522976}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 56.55655655655656, 'accuracy_difference': 0.10920010920010981, 'accuracy_ratio': 0.9980729083025534}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 51.84456468273488, 'accuracy_difference': 0.12788981800294863, 'accuracy_ratio': 0.9975392769259891}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 56.25533529355971, 'accuracy_difference': -0.00948496632837248, 'accuracy_ratio': 1.000168634064081}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.254254254254256, 'accuracy_difference': 1.4196014196014204, 'accuracy_ratio': 0.9745014710689768}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.47763375889289, 'accuracy_difference': 0.17542149887925262, 'accuracy_ratio': 0.9970593040352883}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 63.58176358176358, 'accuracy_difference': 0.027300027300029228, 'accuracy_ratio': 0.9995708154506437}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.833709629920484, 'accuracy_difference': -0.10798075979188582, 'accuracy_ratio': 1.0017493638676844}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 57.29398663697105, 'accuracy_difference': 1.531180400890868, 'accuracy_ratio': 0.9739706578324657}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 64.04319486331354, 'accuracy_difference': -0.1167428738204066, 'accuracy_ratio': 1.0018262060569167}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.756218905472636, 'accuracy_difference': 0.12935323383084807, 'accuracy_ratio': 0.9979430379746835}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 28.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 52.592592592592595, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 59.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0350877192982457}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 64.52830188679245, 'accuracy_difference': -0.37735849056603854, 'accuracy_ratio': 1.0058823529411764}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 0.6944444444444429, 'accuracy_ratio': 0.989247311827957}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 37.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.925}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 54.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 40.19607843137255, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 65.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 48.08510638297872, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 44.73684210526316, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 59.310344827586206, 'accuracy_difference': -0.6896551724137936, 'accuracy_ratio': 1.011764705882353}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 40.21164021164021, 'accuracy_difference': 0.529100529100532, 'accuracy_ratio': 0.9870129870129869}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 40.476190476190474, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 35.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0606060606060606}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 66.12903225806451, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 46.30541871921182, 'accuracy_difference': 0.985221674876847, 'accuracy_ratio': 0.9791666666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 63.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0161290322580645}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 69.6969696969697, 'accuracy_difference': 0.5050505050505052, 'accuracy_ratio': 0.9928057553956835}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.86528497409327, 'accuracy_difference': 0.5181347150258944, 'accuracy_ratio': 0.9937106918238995}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 54.87179487179487, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 35.55555555555556, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.924369747899156, 'accuracy_difference': -0.8403361344537785, 'accuracy_ratio': 1.013986013986014}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 35.09933774834437, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 74.4954128440367, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.2962962962963, 'accuracy_difference': -1.8518518518518547, 'accuracy_ratio': 1.0416666666666667}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 61.43497757847533, 'accuracy_difference': -0.8968609865470825, 'accuracy_ratio': 1.0148148148148148}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 69.46564885496183, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 75.20661157024793, 'accuracy_difference': -0.8264462809917319, 'accuracy_ratio': 1.011111111111111}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 71.29629629629629, 'accuracy_difference': -1.8518518518518476, 'accuracy_ratio': 1.0266666666666666}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 72.39263803680981, 'accuracy_difference': -0.6134969325153321, 'accuracy_ratio': 1.0085470085470085}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 47.32142857142857, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 70.87378640776699, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 84.1880341880342, 'accuracy_difference': -0.42735042735043294, 'accuracy_ratio': 1.0051020408163267}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 74.58492975734355, 'accuracy_difference': 0.2554278416347415, 'accuracy_ratio': 0.9965870307167235}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.76300578034682, 'accuracy_difference': -0.28901734104046284, 'accuracy_ratio': 1.0043478260869565}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.63687150837989, 'accuracy_difference': 0.22346368715083287, 'accuracy_ratio': 0.9935897435897437}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.37908496732027, 'accuracy_difference': 0.6535947712418277, 'accuracy_ratio': 0.9899497487437187}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.057877813504824, 'accuracy_difference': 0.32154340836012807, 'accuracy_ratio': 0.9948453608247423}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.4320987654321, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 46.09929078014184, 'accuracy_difference': 0.35460992907801625, 'accuracy_ratio': 0.9923664122137404}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 61.029411764705884, 'accuracy_difference': -0.735294117647058, 'accuracy_ratio': 1.0121951219512195}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.6797385620915, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 67.75510204081633, 'accuracy_difference': -0.4081632653061149, 'accuracy_ratio': 1.0060606060606059}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.08955223880596, 'accuracy_difference': 0.4975124378109541, 'accuracy_ratio': 0.9939759036144578}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 79.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9875}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 46.3855421686747, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.70175438596492, 'accuracy_difference': 0.5847953216374151, 'accuracy_ratio': 0.9928057553956836}},
"pile_FreeLaw": {'unpruned_accuracy': 65.55417423735297, 'target_accuracy': 52.443339389882375, 'ff_frac': 0.007, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.2599890530925, 'accuracy_difference': 1.213282247765008, 'accuracy_ratio': 0.9841345580341166}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.34845735027223, 'accuracy_difference': 0.9800362976406518, 'accuracy_ratio': 0.9879496563420512}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 85.6161806208843, 'accuracy_difference': -0.07525870178739069, 'accuracy_ratio': 1.0008797976465413}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 78.86853653882847, 'accuracy_difference': 0.1908032818164429, 'accuracy_ratio': 0.9975865813925426}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 76.07397984147177, 'accuracy_difference': -0.05871415989822992, 'accuracy_ratio': 1.0007723995880535}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 55.89076210194223, 'accuracy_difference': 0.15774425712313445, 'accuracy_ratio': 0.9971855760773968}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 54.30299424945469, 'accuracy_difference': 0.5453103311520877, 'accuracy_ratio': 0.990057845263919}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 61.089672914369714, 'accuracy_difference': 0.36751194413818666, 'accuracy_ratio': 0.9940200328898191}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 51.228841924070004, 'accuracy_difference': 14.325332313282964, 'accuracy_ratio': 0.7814733770970096}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 52.525252525252526, 'accuracy_difference': 4.140504140504142, 'accuracy_ratio': 0.9269311064718163}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 51.824889326119035, 'accuracy_difference': 0.1475651746187907, 'accuracy_ratio': 0.997160704145372}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.94233140472351, 'accuracy_difference': 0.30351892250782697, 'accuracy_ratio': 0.9946037099494097}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.62735462735463, 'accuracy_difference': 1.0465010465010494, 'accuracy_ratio': 0.981203007518797}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.33144917649352, 'accuracy_difference': 0.3216060812786239, 'accuracy_ratio': 0.9946087240646954}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 63.41796341796342, 'accuracy_difference': 0.1911001911001904, 'accuracy_ratio': 0.9969957081545064}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.77481103367037, 'accuracy_difference': -0.049082163541768864, 'accuracy_ratio': 1.000795165394402}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 58.500371195248704, 'accuracy_difference': 0.3247958426132129, 'accuracy_ratio': 0.9944786243887048}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.86808055258294, 'accuracy_difference': 0.05837143691019975, 'accuracy_ratio': 0.9990868969715417}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.517412935323385, 'accuracy_difference': 0.36815920398009894, 'accuracy_ratio': 0.9941455696202531}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 30.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0714285714285714}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 51.851851851851855, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9859154929577465}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 59.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0350877192982457}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.77358490566038, 'accuracy_difference': 0.37735849056603143, 'accuracy_ratio': 0.9941176470588237}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 64.58333333333333, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 42.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.05}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 53.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9814814814814815}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 34.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 41.1764705882353, 'accuracy_difference': -0.9803921568627487, 'accuracy_ratio': 1.024390243902439}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 67.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0307692307692307}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.53191489361702, 'accuracy_difference': 2.5531914893617014, 'accuracy_ratio': 0.9469026548672567}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 44.73684210526316, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 56.55172413793103, 'accuracy_difference': 2.068965517241381, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.682539682539684, 'accuracy_difference': 1.0582010582010568, 'accuracy_ratio': 0.974025974025974}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 36.507936507936506, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 65.80645161290323, 'accuracy_difference': 0.32258064516128115, 'accuracy_ratio': 0.9951219512195123}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 45.320197044334975, 'accuracy_difference': 1.970443349753694, 'accuracy_ratio': 0.9583333333333334}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 65.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0483870967741935}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.70707070707071, 'accuracy_difference': -0.5050505050505052, 'accuracy_ratio': 1.0071942446043165}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 74.09326424870466, 'accuracy_difference': 8.290155440414509, 'accuracy_ratio': 0.89937106918239}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 56.41025641025641, 'accuracy_difference': -1.53846153846154, 'accuracy_ratio': 1.0280373831775702}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 35.925925925925924, 'accuracy_difference': -0.3703703703703667, 'accuracy_ratio': 1.0104166666666665}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.50420168067227, 'accuracy_difference': -0.42016806722688926, 'accuracy_ratio': 1.0069930069930069}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 32.450331125827816, 'accuracy_difference': 2.649006622516552, 'accuracy_ratio': 0.9245283018867926}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.76146788990826, 'accuracy_difference': 0.7339449541284324, 'accuracy_ratio': 0.9901477832512317}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 43.98148148148148, 'accuracy_difference': 0.4629629629629619, 'accuracy_ratio': 0.9895833333333334}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 61.88340807174888, 'accuracy_difference': -1.3452914798206308, 'accuracy_ratio': 1.0222222222222224}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 70.99236641221374, 'accuracy_difference': -1.5267175572519136, 'accuracy_ratio': 1.0219780219780221}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 70.24793388429752, 'accuracy_difference': 4.132231404958674, 'accuracy_ratio': 0.9444444444444445}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 70.5521472392638, 'accuracy_difference': 1.2269938650306784, 'accuracy_ratio': 0.9829059829059829}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 45.535714285714285, 'accuracy_difference': 1.7857142857142847, 'accuracy_ratio': 0.9622641509433962}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 69.90291262135922, 'accuracy_difference': 0.9708737864077648, 'accuracy_ratio': 0.9863013698630138}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.76068376068376, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 74.32950191570882, 'accuracy_difference': 0.5108556832694688, 'accuracy_ratio': 0.9931740614334472}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 65.3179190751445, 'accuracy_difference': 1.1560693641618514, 'accuracy_ratio': 0.9826086956521739}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.41340782122905, 'accuracy_difference': 0.44692737430167284, 'accuracy_ratio': 0.9871794871794872}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 60.77170418006431, 'accuracy_difference': 1.6077170418006403, 'accuracy_ratio': 0.9742268041237114}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.4320987654321, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 42.90780141843972, 'accuracy_difference': 3.546099290780141, 'accuracy_ratio': 0.9236641221374046}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 59.9264705882353, 'accuracy_difference': 0.367647058823529, 'accuracy_ratio': 0.9939024390243902}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.84313725490196, 'accuracy_difference': -0.1633986928104605, 'accuracy_ratio': 1.0028328611898019}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 65.45454545454545, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 66.53061224489795, 'accuracy_difference': 0.8163265306122582, 'accuracy_ratio': 0.9878787878787877}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 83.58208955223881, 'accuracy_difference': -0.995024875621894, 'accuracy_ratio': 1.0120481927710845}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 83.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0375}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.28654970760233, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}},
"pile_Github": {'unpruned_accuracy': 76.4732713008575, 'target_accuracy': 61.17861704068601, 'ff_frac': 0.022, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 60.73709177157453, 'accuracy_difference': 15.736179529282971, 'accuracy_ratio': 0.7942264105928666}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 65.85117967332124, 'accuracy_difference': 15.477313974591638, 'accuracy_ratio': 0.8096938320092834}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 83.44308560677328, 'accuracy_difference': 2.097836312323622, 'accuracy_ratio': 0.9754756406026612}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 77.53291356611334, 'accuracy_difference': 1.5264262545315717, 'accuracy_ratio': 0.9806926511403403}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.69233780213328, 'accuracy_difference': 0.32292787944025747, 'accuracy_ratio': 0.9957518022657055}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 53.66262447007789, 'accuracy_difference': 2.385881888987477, 'accuracy_ratio': 0.9574318381706245}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 51.38806266111442, 'accuracy_difference': 3.4602419194923613, 'accuracy_ratio': 0.9369125090383226}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 60.859977949283355, 'accuracy_difference': 0.5972069092245462, 'accuracy_ratio': 0.9902825534459561}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.62790475279717, 'accuracy_difference': 2.926269484555796, 'accuracy_ratio': 0.9553610503282276}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 50.732550732550735, 'accuracy_difference': 5.933205933205933, 'accuracy_ratio': 0.8952946844387345}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 48.991637973438266, 'accuracy_difference': 2.9808165272995595, 'accuracy_ratio': 0.9426462237365133}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.86645167409656, 'accuracy_difference': 0.3793986531347784, 'accuracy_ratio': 0.9932546374367622}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.044954044954046, 'accuracy_difference': 1.6289016289016303, 'accuracy_ratio': 0.9707420725727361}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.00984309521489, 'accuracy_difference': 0.6432121625572549, 'accuracy_ratio': 0.9892174481293906}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 60.87906087906088, 'accuracy_difference': 2.730002730002731, 'accuracy_ratio': 0.9570815450643777}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 54.49101796407186, 'accuracy_difference': 7.2347109060567405, 'accuracy_ratio': 0.8827926208651399}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 56.12472160356347, 'accuracy_difference': 2.7004454342984445, 'accuracy_ratio': 0.9540937056318031}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.20653760093394, 'accuracy_difference': 0.7199143885591965, 'accuracy_ratio': 0.9887383959823467}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 61.6318407960199, 'accuracy_difference': 1.253731343283583, 'accuracy_ratio': 0.9800632911392405}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 32.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.1428571428571428}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 51.851851851851855, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9859154929577465}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 55.26315789473684, 'accuracy_difference': 3.2894736842105274, 'accuracy_ratio': 0.9438202247191011}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 56.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9824561403508771}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.39622641509434, 'accuracy_difference': 0.75471698113207, 'accuracy_ratio': 0.9882352941176471}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 65.27777777777777, 'accuracy_difference': -0.6944444444444429, 'accuracy_ratio': 1.010752688172043}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 46.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.15}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 51.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9444444444444444}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.088235294117647}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 33.333333333333336, 'accuracy_difference': 6.862745098039213, 'accuracy_ratio': 0.8292682926829269}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 69.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.0615384615384615}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 47.659574468085104, 'accuracy_difference': 0.4255319148936181, 'accuracy_ratio': 0.9911504424778761}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 43.85964912280702, 'accuracy_difference': 0.8771929824561369, 'accuracy_ratio': 0.9803921568627452}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 55.86206896551724, 'accuracy_difference': 2.7586206896551744, 'accuracy_ratio': 0.9529411764705882}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.35978835978836, 'accuracy_difference': 2.3809523809523796, 'accuracy_ratio': 0.9415584415584416}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 37.301587301587304, 'accuracy_difference': 3.1746031746031704, 'accuracy_ratio': 0.9215686274509804}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 67.09677419354838, 'accuracy_difference': -0.9677419354838719, 'accuracy_ratio': 1.0146341463414634}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 41.87192118226601, 'accuracy_difference': 5.418719211822662, 'accuracy_ratio': 0.8854166666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 71.71717171717172, 'accuracy_difference': -1.5151515151515156, 'accuracy_ratio': 1.0215827338129497}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.86528497409327, 'accuracy_difference': 0.5181347150258944, 'accuracy_ratio': 0.9937106918238995}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.38461538461539, 'accuracy_difference': -0.5128205128205181, 'accuracy_ratio': 1.0093457943925235}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 33.7037037037037, 'accuracy_difference': 1.8518518518518547, 'accuracy_ratio': 0.9479166666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 59.2436974789916, 'accuracy_difference': 0.8403361344537785, 'accuracy_ratio': 0.986013986013986}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 33.11258278145695, 'accuracy_difference': 1.9867549668874176, 'accuracy_ratio': 0.9433962264150944}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.57798165137615, 'accuracy_difference': 0.9174311926605441, 'accuracy_ratio': 0.9876847290640395}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 45.833333333333336, 'accuracy_difference': -1.3888888888888928, 'accuracy_ratio': 1.03125}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 63.228699551569505, 'accuracy_difference': -2.6905829596412545, 'accuracy_ratio': 1.0444444444444445}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 69.46564885496183, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 73.00613496932516, 'accuracy_difference': -1.2269938650306784, 'accuracy_ratio': 1.017094017094017}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 44.642857142857146, 'accuracy_difference': 2.6785714285714235, 'accuracy_ratio': 0.9433962264150945}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 72.81553398058253, 'accuracy_difference': -1.9417475728155438, 'accuracy_ratio': 1.0273972602739727}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 85.04273504273505, 'accuracy_difference': -1.2820512820512846, 'accuracy_ratio': 1.0153061224489797}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9682539682539683}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.73435504469987, 'accuracy_difference': -0.8939974457215811, 'accuracy_ratio': 1.0119453924914676}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.18497109826589, 'accuracy_difference': 0.28901734104046284, 'accuracy_ratio': 0.9956521739130435}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.85474860335196, 'accuracy_difference': 1.0055865921787657, 'accuracy_ratio': 0.9711538461538463}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 66.01307189542484, 'accuracy_difference': -0.9803921568627487, 'accuracy_ratio': 1.015075376884422}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 60.450160771704184, 'accuracy_difference': 1.9292604501607684, 'accuracy_ratio': 0.9690721649484536}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.35802469135803, 'accuracy_difference': -0.9259259259259238, 'accuracy_ratio': 1.0141509433962264}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.0354609929078, 'accuracy_difference': 1.418439716312058, 'accuracy_ratio': 0.9694656488549618}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 62.5, 'accuracy_difference': -2.205882352941174, 'accuracy_ratio': 1.0365853658536586}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.02614379084967, 'accuracy_difference': 0.6535947712418277, 'accuracy_ratio': 0.9886685552407932}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 64.54545454545455, 'accuracy_difference': 0.9090909090909065, 'accuracy_ratio': 0.9861111111111112}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.08163265306122, 'accuracy_difference': 3.2653061224489903, 'accuracy_ratio': 0.9515151515151513}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.08955223880596, 'accuracy_difference': 0.4975124378109541, 'accuracy_ratio': 0.9939759036144578}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 84.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.05}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.28654970760233, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}},

"pile_Gutenberg": {'unpruned_accuracy': 56.66575666575667, 'target_accuracy': 45.33260533260534, 'ff_frac': 0.008, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 72.15836526181354, 'accuracy_difference': 4.3149060390439615, 'accuracy_ratio': 0.9435762853393774}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 79.52813067150635, 'accuracy_difference': 1.8003629764065323, 'accuracy_ratio': 0.9778630723913238}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 85.6632173095014, 'accuracy_difference': -0.12229539040450277, 'accuracy_ratio': 1.0014296711756294}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 78.61095210837627, 'accuracy_difference': 0.4483877122686408, 'accuracy_ratio': 0.9943284662724751}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.94676582835893, 'accuracy_difference': 0.06849985321460395, 'accuracy_ratio': 0.9990988671472708}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 55.64428670018732, 'accuracy_difference': 0.40421965887804134, 'accuracy_ratio': 0.992788038698329}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 53.12314098750743, 'accuracy_difference': 1.7251635930993459, 'accuracy_ratio': 0.9685466377440347}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 60.951855935317894, 'accuracy_difference': 0.5053289231900067, 'accuracy_ratio': 0.9917775452235013}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 61.317777565267285, 'accuracy_difference': 4.236396672085682, 'accuracy_ratio': 0.9353756382202773}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 45.227045227045224, 'accuracy_difference': 11.438711438711444, 'accuracy_ratio': 0.7981371446924682}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 50.398425971470736, 'accuracy_difference': 1.574028529267089, 'accuracy_ratio': 0.9697141775506342}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.847481741439815, 'accuracy_difference': 0.39836858579152334, 'accuracy_ratio': 0.9929173693086003}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 53.90845390845391, 'accuracy_difference': 1.7654017654017693, 'accuracy_ratio': 0.9682902909447532}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.29246662118702, 'accuracy_difference': 0.36058863658512763, 'accuracy_ratio': 0.9939552360725372}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 62.95386295386295, 'accuracy_difference': 0.6552006552006588, 'accuracy_ratio': 0.9896995708154506}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.38215372533621, 'accuracy_difference': 0.34357514479238915, 'accuracy_ratio': 0.9944338422391856}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 58.32405345211581, 'accuracy_difference': 0.5011135857461042, 'accuracy_ratio': 0.991481306199716}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.76106625158089, 'accuracy_difference': 0.16538573791224565, 'accuracy_ratio': 0.9974128747527014}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.35820895522388, 'accuracy_difference': 0.5273631840796043, 'accuracy_ratio': 0.9916139240506329}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 30.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0714285714285714}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 52.592592592592595, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 59.21052631578947, 'accuracy_difference': -0.6578947368421026, 'accuracy_ratio': 1.0112359550561798}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 61.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.0701754385964912}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 61.509433962264154, 'accuracy_difference': 2.6415094339622556, 'accuracy_ratio': 0.9588235294117649}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 0.6944444444444429, 'accuracy_ratio': 0.989247311827957}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 36.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 55.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0185185185185186}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9117647058823529}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 39.21568627450981, 'accuracy_difference': 0.9803921568627416, 'accuracy_ratio': 0.9756097560975611}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 66.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0153846153846153}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 47.234042553191486, 'accuracy_difference': 0.8510638297872362, 'accuracy_ratio': 0.9823008849557522}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 42.98245614035088, 'accuracy_difference': 1.7543859649122808, 'accuracy_ratio': 0.9607843137254902}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 53.793103448275865, 'accuracy_difference': 4.827586206896548, 'accuracy_ratio': 0.9176470588235295}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.94708994708995, 'accuracy_difference': 0.7936507936507908, 'accuracy_ratio': 0.9805194805194806}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 34.92063492063492, 'accuracy_difference': 5.555555555555557, 'accuracy_ratio': 0.8627450980392156}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 35.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0606060606060606}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 65.16129032258064, 'accuracy_difference': 0.9677419354838719, 'accuracy_ratio': 0.9853658536585366}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 44.33497536945813, 'accuracy_difference': 2.955665024630541, 'accuracy_ratio': 0.9375}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 65.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0483870967741935}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.20202020202021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 80.82901554404145, 'accuracy_difference': 1.5544041450777115, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.84615384615385, 'accuracy_difference': 1.025641025641022, 'accuracy_ratio': 0.9813084112149534}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 36.666666666666664, 'accuracy_difference': -1.1111111111111072, 'accuracy_ratio': 1.0312499999999998}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 57.983193277310924, 'accuracy_difference': 2.1008403361344534, 'accuracy_ratio': 0.965034965034965}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 37.086092715231786, 'accuracy_difference': -1.9867549668874176, 'accuracy_ratio': 1.0566037735849056}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.57798165137615, 'accuracy_difference': 0.9174311926605441, 'accuracy_ratio': 0.9876847290640395}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 43.98148148148148, 'accuracy_difference': 0.4629629629629619, 'accuracy_ratio': 0.9895833333333334}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 61.88340807174888, 'accuracy_difference': -1.3452914798206308, 'accuracy_ratio': 1.0222222222222224}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 72.51908396946565, 'accuracy_difference': -3.053435114503827, 'accuracy_ratio': 1.043956043956044}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 72.39263803680981, 'accuracy_difference': -0.6134969325153321, 'accuracy_ratio': 1.0085470085470085}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 44.642857142857146, 'accuracy_difference': 2.6785714285714235, 'accuracy_ratio': 0.9433962264150945}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 70.87378640776699, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.42735042735043294, 'accuracy_ratio': 0.9948979591836734}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 59.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9365079365079365}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 74.07407407407408, 'accuracy_difference': 0.7662835249042104, 'accuracy_ratio': 0.9897610921501707}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 66.76300578034682, 'accuracy_difference': -0.28901734104046284, 'accuracy_ratio': 1.0043478260869565}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 32.737430167597765, 'accuracy_difference': 2.1229050279329584, 'accuracy_ratio': 0.9391025641025642}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 63.39869281045752, 'accuracy_difference': 1.6339869281045765, 'accuracy_ratio': 0.9748743718592965}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 61.09324758842444, 'accuracy_difference': 1.2861736334405123, 'accuracy_ratio': 0.9793814432989691}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 1.5432098765432158, 'accuracy_ratio': 0.9764150943396226}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.326241134751776, 'accuracy_difference': 2.1276595744680833, 'accuracy_ratio': 0.9541984732824428}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 60.294117647058826, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 58.333333333333336, 'accuracy_difference': -0.6535947712418348, 'accuracy_ratio': 1.0113314447592068}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.89795918367346, 'accuracy_difference': 2.4489795918367463, 'accuracy_ratio': 0.9636363636363635}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 83.08457711442786, 'accuracy_difference': -0.4975124378109399, 'accuracy_ratio': 1.006024096385542}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 81.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0125}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 79.53216374269006, 'accuracy_difference': 1.7543859649122737, 'accuracy_ratio': 0.9784172661870505}},
"pile_HackerNews": {'unpruned_accuracy': 51.972454500737825, 'target_accuracy': 41.577963600590266, 'ff_frac': 0.048, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 70.87210363072433, 'accuracy_difference': 5.601167670133179, 'accuracy_ratio': 0.9267565310747943}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 77.08166969147005, 'accuracy_difference': 4.2468239564428245, 'accuracy_ratio': 0.9477818441488888}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 83.7158984007526, 'accuracy_difference': 1.8250235183443095, 'accuracy_ratio': 0.9786649070713735}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 76.98912421293646, 'accuracy_difference': 2.070215607708448, 'accuracy_ratio': 0.9738144081090866}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 74.48869752421959, 'accuracy_difference': 1.5265681573539496, 'accuracy_ratio': 0.9799176107106076}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 52.92319826481317, 'accuracy_difference': 3.1253080942521905, 'accuracy_ratio': 0.9442392260334214}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 47.72952607574856, 'accuracy_difference': 7.11877850485822, 'accuracy_ratio': 0.8702096890817064}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 58.80191106210952, 'accuracy_difference': 2.655273796398383, 'accuracy_ratio': 0.9567947376289431}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.07325236683561, 'accuracy_difference': 3.4809218705173564, 'accuracy_ratio': 0.9469000729394602}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 48.11174811174811, 'accuracy_difference': 8.554008554008554, 'accuracy_ratio': 0.8490444837000161}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 40.58042302016724, 'accuracy_difference': 11.392031480570587, 'accuracy_ratio': 0.7808063600227143}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 54.69980081570711, 'accuracy_difference': 1.546049511524231, 'accuracy_ratio': 0.9725126475548062}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 53.01665301665302, 'accuracy_difference': 2.65720265720266, 'accuracy_ratio': 0.9522719843085975}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 58.14248123964526, 'accuracy_difference': 1.5105740181268885, 'accuracy_ratio': 0.9746773403038719}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 60.61516061516061, 'accuracy_difference': 2.9939029939029993, 'accuracy_ratio': 0.9529327610872674}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 57.5831942672033, 'accuracy_difference': 4.142534602925302, 'accuracy_ratio': 0.9328880407124681}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 51.06718634001485, 'accuracy_difference': 7.757980697847067, 'accuracy_ratio': 0.8681179996844929}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 62.36988033855433, 'accuracy_difference': 1.5565716509388068, 'accuracy_ratio': 0.9756505859077766}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 60.288557213930346, 'accuracy_difference': 2.597014925373138, 'accuracy_ratio': 0.9587025316455695}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 32.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.1428571428571428}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 54.81481481481482, 'accuracy_difference': -2.2222222222222214, 'accuracy_ratio': 1.0422535211267605}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 64.15094339622641, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 67.36111111111111, 'accuracy_difference': -2.7777777777777857, 'accuracy_ratio': 1.0430107526881722}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 47.0, 'accuracy_difference': -7.0, 'accuracy_ratio': 1.175}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 53.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9814814814814815}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 32.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9411764705882353}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 37.254901960784316, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.926829268292683}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 71.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.0923076923076922}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 3.4042553191489375, 'accuracy_ratio': 0.9292035398230089}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 38.59649122807018, 'accuracy_difference': 6.140350877192979, 'accuracy_ratio': 0.8627450980392157}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 56.55172413793103, 'accuracy_difference': 2.068965517241381, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.15343915343915, 'accuracy_difference': 1.5873015873015888, 'accuracy_ratio': 0.961038961038961}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 37.301587301587304, 'accuracy_difference': 3.1746031746031704, 'accuracy_ratio': 0.9215686274509804}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.121212121212121}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 66.7741935483871, 'accuracy_difference': -0.6451612903225907, 'accuracy_ratio': 1.0097560975609758}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 44.827586206896555, 'accuracy_difference': 2.463054187192114, 'accuracy_ratio': 0.9479166666666667}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 65.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0483870967741935}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 73.73737373737374, 'accuracy_difference': -3.5353535353535364, 'accuracy_ratio': 1.0503597122302157}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.86528497409327, 'accuracy_difference': 0.5181347150258944, 'accuracy_ratio': 0.9937106918238995}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.12820512820513, 'accuracy_difference': -0.2564102564102626, 'accuracy_ratio': 1.0046728971962617}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 36.666666666666664, 'accuracy_difference': -1.1111111111111072, 'accuracy_ratio': 1.0312499999999998}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.50420168067227, 'accuracy_difference': -0.42016806722688926, 'accuracy_ratio': 1.0069930069930069}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 35.76158940397351, 'accuracy_difference': -0.6622516556291416, 'accuracy_ratio': 1.0188679245283019}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.76146788990826, 'accuracy_difference': 0.7339449541284324, 'accuracy_ratio': 0.9901477832512317}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 44.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 63.228699551569505, 'accuracy_difference': -2.6905829596412545, 'accuracy_ratio': 1.0444444444444445}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 71.7557251908397, 'accuracy_difference': -2.2900763358778704, 'accuracy_ratio': 1.032967032967033}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.90082644628099, 'accuracy_difference': 2.47933884297521, 'accuracy_ratio': 0.9666666666666667}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 64.81481481481481, 'accuracy_difference': 4.629629629629633, 'accuracy_ratio': 0.9333333333333332}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 70.5521472392638, 'accuracy_difference': 1.2269938650306784, 'accuracy_ratio': 0.9829059829059829}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 41.964285714285715, 'accuracy_difference': 5.357142857142854, 'accuracy_ratio': 0.8867924528301887}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 73.7864077669903, 'accuracy_difference': -2.9126213592233086, 'accuracy_ratio': 1.041095890410959}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 84.1880341880342, 'accuracy_difference': -0.42735042735043294, 'accuracy_ratio': 1.0051020408163267}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 66.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0476190476190477}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.35121328224777, 'accuracy_difference': -0.510855683269483, 'accuracy_ratio': 1.006825938566553}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 65.02890173410404, 'accuracy_difference': 1.4450867052023142, 'accuracy_ratio': 0.9782608695652174}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.86033519553072, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 62.745098039215684, 'accuracy_difference': 2.2875816993464113, 'accuracy_ratio': 0.964824120603015}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.057877813504824, 'accuracy_difference': 0.32154340836012807, 'accuracy_ratio': 0.9948453608247423}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 64.19753086419753, 'accuracy_difference': 1.2345679012345698, 'accuracy_ratio': 0.9811320754716981}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 1.7730496453900741, 'accuracy_ratio': 0.9618320610687022}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 61.39705882352941, 'accuracy_difference': -1.102941176470587, 'accuracy_ratio': 1.0182926829268293}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 59.47712418300654, 'accuracy_difference': -1.797385620915037, 'accuracy_ratio': 1.0311614730878187}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 67.27272727272727, 'accuracy_difference': -1.818181818181813, 'accuracy_ratio': 1.0277777777777777}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 66.53061224489795, 'accuracy_difference': 0.8163265306122582, 'accuracy_ratio': 0.9878787878787877}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 83.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0375}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.975903614457835, 'accuracy_difference': 2.409638554216862, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.70175438596492, 'accuracy_difference': 0.5847953216374151, 'accuracy_ratio': 0.9928057553956836}},

"pile_NIH_ExPorter": {'unpruned_accuracy': 56.24585032723134, 'target_accuracy': 44.99668026178507, 'ff_frac': 0.048, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.62488596971356, 'accuracy_difference': 0.8483853311439447, 'accuracy_ratio': 0.9889061195276155}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.51542649727767, 'accuracy_difference': 0.8130671506352058, 'accuracy_ratio': 0.9900026778541462}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 84.30856067732832, 'accuracy_difference': 1.2323612417685865, 'accuracy_ratio': 0.9855933135378862}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 67.830566685747, 'accuracy_difference': 11.228773134897907, 'accuracy_ratio': 0.8579703149511284}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 66.9732850572463, 'accuracy_difference': 9.041980624327238, 'accuracy_ratio': 0.8810504634397528}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 52.321798284531205, 'accuracy_difference': 3.7267080745341588, 'accuracy_ratio': 0.9335092348284961}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 53.16279992068213, 'accuracy_difference': 1.6855046599246464, 'accuracy_ratio': 0.9692697035430224}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 58.23226754869533, 'accuracy_difference': 3.224917309812568, 'accuracy_ratio': 0.9475257886081627}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 62.9339198622932, 'accuracy_difference': 2.6202543750597656, 'accuracy_ratio': 0.9600291757840993}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 54.23605423605424, 'accuracy_difference': 2.4297024297024308, 'accuracy_ratio': 0.9571222097318131}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 50.41810132808657, 'accuracy_difference': 1.554353172651254, 'accuracy_ratio': 0.9700927503312512}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 44.332732618799206, 'accuracy_difference': 11.913117708432132, 'accuracy_ratio': 0.7881956155143339}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 52.90745290745291, 'accuracy_difference': 2.76640276640277, 'accuracy_ratio': 0.9503105590062111}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 48.02650813760842, 'accuracy_difference': 11.626547120163728, 'accuracy_ratio': 0.8050972063388335}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 55.1005551005551, 'accuracy_difference': 8.508508508508513, 'accuracy_ratio': 0.8662374821173103}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 60.79316776283498, 'accuracy_difference': 0.9325611072936155, 'accuracy_ratio': 0.9848918575063612}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 57.516703786191535, 'accuracy_difference': 1.308463251670382, 'accuracy_ratio': 0.9777567439659252}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 61.01760871680125, 'accuracy_difference': 2.9088432726918896, 'accuracy_ratio': 0.9544970324151576}, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 60.84577114427861, 'accuracy_difference': 2.0398009950248763, 'accuracy_ratio': 0.9675632911392404}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 25.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.8928571428571429}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 42.96296296296296, 'accuracy_difference': 9.629629629629633, 'accuracy_ratio': 0.8169014084507041}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 60.526315789473685, 'accuracy_difference': -1.973684210526315, 'accuracy_ratio': 1.0337078651685394}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 50.18867924528302, 'accuracy_difference': 13.96226415094339, 'accuracy_ratio': 0.7823529411764707}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 52.083333333333336, 'accuracy_difference': 12.499999999999993, 'accuracy_ratio': 0.8064516129032259}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 34.0, 'accuracy_difference': 6.0, 'accuracy_ratio': 0.85}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 53.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9814814814814815}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 37.254901960784316, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.926829268292683}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 66.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0153846153846153}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.53191489361702, 'accuracy_difference': 2.5531914893617014, 'accuracy_ratio': 0.9469026548672567}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 35.96491228070175, 'accuracy_difference': 8.771929824561404, 'accuracy_ratio': 0.803921568627451}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 51.724137931034484, 'accuracy_difference': 6.896551724137929, 'accuracy_ratio': 0.8823529411764707}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 40.21164021164021, 'accuracy_difference': 0.529100529100532, 'accuracy_ratio': 0.9870129870129869}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 41.26984126984127, 'accuracy_difference': -0.7936507936507979, 'accuracy_ratio': 1.019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 32.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9696969696969697}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 55.483870967741936, 'accuracy_difference': 10.645161290322577, 'accuracy_ratio': 0.8390243902439025}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 40.39408866995074, 'accuracy_difference': 6.896551724137929, 'accuracy_ratio': 0.8541666666666667}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 64.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.032258064516129}, 'mmlu:high_school_european_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.20202020202021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 80.31088082901555, 'accuracy_difference': 2.07253886010362, 'accuracy_ratio': 0.9748427672955976}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.333333333333336, 'accuracy_difference': 1.538461538461533, 'accuracy_ratio': 0.97196261682243}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 34.81481481481482, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9791666666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 60.08403361344538, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 32.450331125827816, 'accuracy_difference': 2.649006622516552, 'accuracy_ratio': 0.9245283018867926}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 68.25688073394495, 'accuracy_difference': 6.2385321100917395, 'accuracy_ratio': 0.916256157635468}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 44.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_us_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 57.847533632286996, 'accuracy_difference': 2.6905829596412545, 'accuracy_ratio': 0.9555555555555556}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 58.01526717557252, 'accuracy_difference': 11.45038167938931, 'accuracy_ratio': 0.8351648351648352}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 73.55371900826447, 'accuracy_difference': 0.8264462809917319, 'accuracy_ratio': 0.9888888888888889}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 65.74074074074075, 'accuracy_difference': 3.7037037037036953, 'accuracy_ratio': 0.9466666666666668}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 73.00613496932516, 'accuracy_difference': -1.2269938650306784, 'accuracy_ratio': 1.017094017094017}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 40.17857142857143, 'accuracy_difference': 7.142857142857139, 'accuracy_ratio': 0.8490566037735849}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 74.75728155339806, 'accuracy_difference': -3.8834951456310733, 'accuracy_ratio': 1.0547945205479452}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 82.90598290598291, 'accuracy_difference': 0.8547008547008517, 'accuracy_ratio': 0.9897959183673469}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 45.0, 'accuracy_difference': 18.0, 'accuracy_ratio': 0.7142857142857143}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 73.05236270753512, 'accuracy_difference': 1.7879948914431623, 'accuracy_ratio': 0.9761092150170649}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 63.58381502890173, 'accuracy_difference': 2.8901734104046213, 'accuracy_ratio': 0.9565217391304348}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.07821229050279, 'accuracy_difference': 0.7821229050279328, 'accuracy_ratio': 0.9775641025641025}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 52.94117647058823, 'accuracy_difference': 12.091503267973863, 'accuracy_ratio': 0.8140703517587938}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.057877813504824, 'accuracy_difference': 0.32154340836012807, 'accuracy_ratio': 0.9948453608247423}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.74074074074075, 'accuracy_difference': -0.308641975308646, 'accuracy_ratio': 1.0047169811320755}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 46.808510638297875, 'accuracy_difference': -0.35460992907801625, 'accuracy_ratio': 1.0076335877862597}, 'mmlu:professional_law': {'unpruned_accuracy': -1, 'pruned_accuracy': -1, 'accuracy_difference': 0, 'accuracy_ratio': 1.0}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 47.4264705882353, 'accuracy_difference': 12.867647058823529, 'accuracy_ratio': 0.7865853658536586}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 53.59477124183007, 'accuracy_difference': 4.084967320261434, 'accuracy_ratio': 0.9291784702549576}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 67.75510204081633, 'accuracy_difference': -0.4081632653061149, 'accuracy_ratio': 1.0060606060606059}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 80.59701492537313, 'accuracy_difference': 1.990049751243788, 'accuracy_ratio': 0.9759036144578312}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 81.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0125}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 44.57831325301205, 'accuracy_difference': 1.8072289156626482, 'accuracy_ratio': 0.9610389610389611}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.11695906432749, 'accuracy_difference': 1.1695906432748444, 'accuracy_ratio': 0.985611510791367}},
"pile_PhilPapers": {'unpruned_accuracy': 55.64655564655565, 'target_accuracy': 44.51724451724452, 'ff_frac': 0.064, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 56.93402202514375, 'accuracy_difference': 2.6605593996686494, 'accuracy_ratio': 0.9553556827473426}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 60.98826098826099, 'accuracy_difference': 2.620802620802621, 'accuracy_ratio': 0.9587982832618026}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 43.37064337064337, 'accuracy_difference': 12.275912275912276, 'accuracy_ratio': 0.7793949304987735}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 60.48885834887602, 'accuracy_difference': 1.2368705212525768, 'accuracy_ratio': 0.9799618320610687}, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 52.114758947057084, 'accuracy_difference': 3.9534654441486765, 'accuracy_ratio': 0.9294883066643221}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 52.59766012294269, 'accuracy_difference': 2.2704739242514407, 'accuracy_ratio': 0.9586194434405493}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 26.92943770672547, 'accuracy_difference': 34.536934950385884, 'accuracy_ratio': 0.43811659192825114}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 60.26585062637468, 'accuracy_difference': 5.2787606388065385, 'accuracy_ratio': 0.9194630872483222}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 73.71829958036855, 'accuracy_difference': 2.7367268746579043, 'accuracy_ratio': 0.9642047488366544}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 49.686049686049685, 'accuracy_difference': 6.997906997907002, 'accuracy_ratio': 0.8765451918445978}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 50.11313330054107, 'accuracy_difference': 1.8494835218888355, 'accuracy_ratio': 0.964407421431276}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 53.15375130418287, 'accuracy_difference': 3.0826140567200966, 'accuracy_ratio': 0.9451846854444257}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 52.654046028210836, 'accuracy_difference': 6.134001484780995, 'accuracy_ratio': 0.8956590370955012}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 62.75902325128904, 'accuracy_difference': 1.196614456659205, 'accuracy_ratio': 0.9812899300273806}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 58.90547263681592, 'accuracy_difference': 3.9402985074626855, 'accuracy_ratio': 0.9373020899303357}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 71.25941872981701, 'accuracy_difference': 4.706918485174668, 'accuracy_ratio': 0.9380394177508696}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 76.67429879793933, 'accuracy_difference': 2.3659606945239346, 'accuracy_ratio': 0.9700663850331926}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 84.23330197554093, 'accuracy_difference': 1.2982126058325463, 'accuracy_ratio': 0.9848218213814343}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 78.63520871143376, 'accuracy_difference': 2.6787658802177816, 'accuracy_ratio': 0.9670565128113562}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 31.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.1071428571428572}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 52.592592592592595, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 57.23684210526316, 'accuracy_difference': 1.3157894736842124, 'accuracy_ratio': 0.9775280898876404}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 64.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.103448275862069}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.77358490566038, 'accuracy_difference': 0.37735849056603143, 'accuracy_ratio': 0.9941176470588237}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 61.80555555555556, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9569892473118281}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 40.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 54.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 7.0, 'accuracy_ratio': 0.7941176470588235}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 52.02312138728324, 'accuracy_difference': -1.734104046242777, 'accuracy_ratio': 1.0344827586206897}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 37.254901960784316, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.926829268292683}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 69.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.0615384615384615}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 47.234042553191486, 'accuracy_difference': 0.8510638297872362, 'accuracy_ratio': 0.9823008849557522}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 43.85964912280702, 'accuracy_difference': 0.8771929824561369, 'accuracy_ratio': 0.9803921568627452}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 53.10344827586207, 'accuracy_difference': 5.517241379310342, 'accuracy_ratio': 0.9058823529411765}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.682539682539684, 'accuracy_difference': 1.0582010582010568, 'accuracy_ratio': 0.974025974025974}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 34.12698412698413, 'accuracy_difference': 5.555555555555557, 'accuracy_ratio': 0.86}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 36.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0909090909090908}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 63.225806451612904, 'accuracy_difference': 3.225806451612904, 'accuracy_ratio': 0.9514563106796117}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 42.857142857142854, 'accuracy_difference': 4.433497536945815, 'accuracy_ratio': 0.90625}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 63.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0161290322580645}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 68.48484848484848, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 66.16161616161617, 'accuracy_difference': 4.0404040404040416, 'accuracy_ratio': 0.9424460431654677}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 77.20207253886011, 'accuracy_difference': 5.181347150259057, 'accuracy_ratio': 0.9371069182389938}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.07692307692308, 'accuracy_difference': 1.7948717948717885, 'accuracy_ratio': 0.9672897196261684}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 35.55555555555556, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 59.66386554621849, 'accuracy_difference': 0.8403361344537785, 'accuracy_ratio': 0.9861111111111112}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 31.125827814569536, 'accuracy_difference': 3.9735099337748316, 'accuracy_ratio': 0.8867924528301887}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 69.35779816513761, 'accuracy_difference': 4.954128440366972, 'accuracy_ratio': 0.9333333333333333}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 41.666666666666664, 'accuracy_difference': 2.7777777777777786, 'accuracy_ratio': 0.9375}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 73.52941176470588, 'accuracy_difference': 3.9215686274509807, 'accuracy_ratio': 0.9493670886075949}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 70.46413502109705, 'accuracy_difference': 5.063291139240505, 'accuracy_ratio': 0.9329608938547487}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 58.74439461883408, 'accuracy_difference': 2.2421524663677133, 'accuracy_ratio': 0.9632352941176471}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 67.93893129770993, 'accuracy_difference': 1.5267175572518994, 'accuracy_ratio': 0.9780219780219781}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.07438016528926, 'accuracy_difference': 3.305785123966942, 'accuracy_ratio': 0.9555555555555556}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 56.48148148148148, 'accuracy_difference': 12.962962962962962, 'accuracy_ratio': 0.8133333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 68.71165644171779, 'accuracy_difference': 3.067484662576689, 'accuracy_ratio': 0.9572649572649572}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 45.535714285714285, 'accuracy_difference': 1.7857142857142847, 'accuracy_ratio': 0.9622641509433962}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 70.87378640776699, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 79.91452991452991, 'accuracy_difference': 4.273504273504287, 'accuracy_ratio': 0.9492385786802029}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9523809523809523}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 73.05236270753512, 'accuracy_difference': 1.915708812260533, 'accuracy_ratio': 0.9744463373083476}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 56.358381502890175, 'accuracy_difference': 10.115606936416178, 'accuracy_ratio': 0.8478260869565218}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.85474860335196, 'accuracy_difference': 1.0055865921787657, 'accuracy_ratio': 0.9711538461538463}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 62.745098039215684, 'accuracy_difference': 2.2875816993464113, 'accuracy_ratio': 0.964824120603015}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 48.231511254019296, 'accuracy_difference': 14.147909967845656, 'accuracy_ratio': 0.7731958762886598}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 59.5679012345679, 'accuracy_difference': 5.864197530864203, 'accuracy_ratio': 0.910377358490566}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 47.163120567375884, 'accuracy_difference': -0.7092198581560254, 'accuracy_ratio': 1.015267175572519}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 41.329856584093875, 'accuracy_difference': 1.8252933507170752, 'accuracy_ratio': 0.9577039274924473}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 57.720588235294116, 'accuracy_difference': 2.57352941176471, 'accuracy_ratio': 0.9573170731707317}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 54.57516339869281, 'accuracy_difference': 3.1045751633986924, 'accuracy_ratio': 0.9461756373937678}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 63.63636363636363, 'accuracy_difference': 1.8181818181818201, 'accuracy_ratio': 0.9722222222222222}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.89795918367346, 'accuracy_difference': 2.4489795918367463, 'accuracy_ratio': 0.9636363636363635}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 77.61194029850746, 'accuracy_difference': 4.975124378109456, 'accuracy_ratio': 0.9397590361445782}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 41.566265060240966, 'accuracy_difference': 4.819277108433731, 'accuracy_ratio': 0.8961038961038962}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 77.77777777777777, 'accuracy_difference': 3.5087719298245617, 'accuracy_ratio': 0.9568345323741008}},
"pile_PubMed_Abstracts": {'unpruned_accuracy': 59.5945814248124, 'target_accuracy': 47.67566513984992, 'ff_frac': 0.032, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 47.51973491862392, 'accuracy_difference': 12.074846506188479, 'accuracy_ratio': 0.7973834832379395}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 55.64655564655565, 'accuracy_difference': 7.9625079625079636, 'accuracy_ratio': 0.8748211731044349}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 54.463554463554466, 'accuracy_difference': 1.1830011830011813, 'accuracy_ratio': 0.9787408013082584}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.33307156179444, 'accuracy_difference': 0.392657308334158, 'accuracy_ratio': 0.9936386768447836}, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 53.958394952183774, 'accuracy_difference': 2.1098294390219863, 'accuracy_ratio': 0.962370318269738}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 54.11461431687488, 'accuracy_difference': 0.7535197303192547, 'accuracy_ratio': 0.986266714853632}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 60.02388827636898, 'accuracy_difference': 1.4424843807423784, 'accuracy_ratio': 0.9765321375186845}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 64.14841732810558, 'accuracy_difference': 1.3961939370756369, 'accuracy_ratio': 0.9786985701779983}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 76.08100711548987, 'accuracy_difference': 0.37401933953658784, 'accuracy_ratio': 0.9951079823410094}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 55.69205569205569, 'accuracy_difference': 0.991900991900998, 'accuracy_ratio': 0.982501204045593}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 51.28381701918347, 'accuracy_difference': 0.6787998032464344, 'accuracy_ratio': 0.9869367663763726}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 47.05491795504126, 'accuracy_difference': 9.181447405861704, 'accuracy_ratio': 0.8367346938775511}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 58.157015590200444, 'accuracy_difference': 0.6310319227913865, 'accuracy_ratio': 0.9892659826361484}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 61.562408794629825, 'accuracy_difference': 2.393228913318417, 'accuracy_ratio': 0.9625798600547611}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 61.90049751243781, 'accuracy_difference': 0.9452736318407986, 'accuracy_ratio': 0.9849588347055098}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 71.30834719639887, 'accuracy_difference': 4.6579900185928125, 'accuracy_ratio': 0.9386834986474302}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 65.32150352986072, 'accuracy_difference': 13.718755962602543, 'accuracy_ratio': 0.8264333132166568}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 84.00752587017874, 'accuracy_difference': 1.5239887111947326, 'accuracy_ratio': 0.9821821381434228}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 80.84210526315789, 'accuracy_difference': 0.4718693284936535, 'accuracy_ratio': 0.9941969467011873}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 29.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0357142857142858}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 39.25925925925926, 'accuracy_difference': 13.333333333333336, 'accuracy_ratio': 0.7464788732394366}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 62.5, 'accuracy_difference': -3.94736842105263, 'accuracy_ratio': 1.0674157303370786}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 61.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0517241379310345}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 47.924528301886795, 'accuracy_difference': 16.226415094339615, 'accuracy_ratio': 0.7470588235294119}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 52.77777777777778, 'accuracy_difference': 11.80555555555555, 'accuracy_ratio': 0.8172043010752689}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 10.0, 'accuracy_ratio': 0.75}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 56.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.037037037037037}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 39.884393063583815, 'accuracy_difference': 10.404624277456648, 'accuracy_ratio': 0.7931034482758621}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 40.19607843137255, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 71.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.0923076923076922}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.95744680851064, 'accuracy_difference': 2.1276595744680833, 'accuracy_ratio': 0.9557522123893806}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 39.473684210526315, 'accuracy_difference': 5.2631578947368425, 'accuracy_ratio': 0.8823529411764706}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 52.41379310344828, 'accuracy_difference': 6.206896551724135, 'accuracy_ratio': 0.8941176470588236}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 35.97883597883598, 'accuracy_difference': 4.761904761904759, 'accuracy_ratio': 0.8831168831168832}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 38.095238095238095, 'accuracy_difference': 1.5873015873015888, 'accuracy_ratio': 0.96}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 39.0, 'accuracy_difference': -6.0, 'accuracy_ratio': 1.1818181818181819}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 57.74193548387097, 'accuracy_difference': 8.70967741935484, 'accuracy_ratio': 0.8689320388349514}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 40.88669950738916, 'accuracy_difference': 6.403940886699509, 'accuracy_ratio': 0.8645833333333333}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 1.818181818181813, 'accuracy_ratio': 0.9734513274336284}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 71.21212121212122, 'accuracy_difference': -1.0101010101010104, 'accuracy_ratio': 1.014388489208633}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 80.82901554404145, 'accuracy_difference': 1.5544041450777115, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.07692307692308, 'accuracy_difference': 1.7948717948717885, 'accuracy_ratio': 0.9672897196261684}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 32.22222222222222, 'accuracy_difference': 3.3333333333333357, 'accuracy_ratio': 0.9062499999999999}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 62.18487394957983, 'accuracy_difference': -1.6806722689075642, 'accuracy_ratio': 1.027777777777778}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 34.437086092715234, 'accuracy_difference': 0.6622516556291345, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 67.88990825688073, 'accuracy_difference': 6.422018348623851, 'accuracy_ratio': 0.9135802469135803}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 46.75925925925926, 'accuracy_difference': -2.3148148148148167, 'accuracy_ratio': 1.0520833333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 75.98039215686275, 'accuracy_difference': 1.470588235294116, 'accuracy_ratio': 0.9810126582278481}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 75.9493670886076, 'accuracy_difference': -0.4219409282700468, 'accuracy_ratio': 1.005586592178771}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 56.95067264573991, 'accuracy_difference': 4.035874439461885, 'accuracy_ratio': 0.9338235294117647}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 59.541984732824424, 'accuracy_difference': 9.923664122137403, 'accuracy_ratio': 0.8571428571428572}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 71.07438016528926, 'accuracy_difference': 3.305785123966942, 'accuracy_ratio': 0.9555555555555556}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 2.7777777777777715, 'accuracy_ratio': 0.9600000000000001}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 70.5521472392638, 'accuracy_difference': 1.2269938650306784, 'accuracy_ratio': 0.9829059829059829}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 43.75, 'accuracy_difference': 3.5714285714285694, 'accuracy_ratio': 0.9245283018867925}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 72.81553398058253, 'accuracy_difference': -1.9417475728155438, 'accuracy_ratio': 1.0273972602739727}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.8547008547008659, 'accuracy_ratio': 0.9898477157360405}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 41.0, 'accuracy_difference': 22.0, 'accuracy_ratio': 0.6507936507936508}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 74.84035759897829, 'accuracy_difference': 0.12771392081737076, 'accuracy_ratio': 0.9982964224872232}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 64.73988439306359, 'accuracy_difference': 1.7341040462427628, 'accuracy_ratio': 0.973913043478261}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 35.977653631284916, 'accuracy_difference': -1.1173184357541928, 'accuracy_ratio': 1.0320512820512822}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 50.326797385620914, 'accuracy_difference': 14.705882352941181, 'accuracy_ratio': 0.7738693467336683}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 60.450160771704184, 'accuracy_difference': 1.9292604501607684, 'accuracy_ratio': 0.9690721649484536}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 63.58024691358025, 'accuracy_difference': 1.8518518518518547, 'accuracy_ratio': 0.9716981132075472}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 45.0354609929078, 'accuracy_difference': 1.418439716312058, 'accuracy_ratio': 0.9694656488549618}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 43.089960886571056, 'accuracy_difference': 0.06518904823989402, 'accuracy_ratio': 0.9984894259818732}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 37.5, 'accuracy_difference': 22.794117647058826, 'accuracy_ratio': 0.6219512195121951}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 51.30718954248366, 'accuracy_difference': 6.372549019607838, 'accuracy_ratio': 0.8895184135977338}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 67.27272727272727, 'accuracy_difference': -1.818181818181813, 'accuracy_ratio': 1.0277777777777777}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 68.57142857142857, 'accuracy_difference': -1.224489795918359, 'accuracy_ratio': 1.018181818181818}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.08955223880596, 'accuracy_difference': 0.4975124378109541, 'accuracy_ratio': 0.9939759036144578}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.11695906432749, 'accuracy_difference': 1.1695906432748444, 'accuracy_ratio': 0.985611510791367}},
"pile_PubMed_Central": {'unpruned_accuracy': 63.60906360906361, 'target_accuracy': 50.88725088725089, 'ff_frac': 0.04, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 50.13156612415944, 'accuracy_difference': 9.463015300652955, 'accuracy_ratio': 0.841210139002453}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 50.013650013650015, 'accuracy_difference': 13.595413595413596, 'accuracy_ratio': 0.7862660944206008}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 52.50705250705251, 'accuracy_difference': 3.139503139503141, 'accuracy_ratio': 0.9435813573180702}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 58.86914695199764, 'accuracy_difference': 2.8565819181309564, 'accuracy_ratio': 0.9537213740458015}, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 51.0302671793355, 'accuracy_difference': 5.037957211870257, 'accuracy_ratio': 0.9101459468964305}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 52.617489589530045, 'accuracy_difference': 2.2506444576640874, 'accuracy_ratio': 0.9589808456812432}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 58.91216464535098, 'accuracy_difference': 2.5542080117603803, 'accuracy_ratio': 0.9584454409566517}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 62.27407478244238, 'accuracy_difference': 3.2705364827388337, 'accuracy_ratio': 0.9501021301429822}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 73.05236270753512, 'accuracy_difference': 3.4026637474913315, 'accuracy_ratio': 0.9554945710535736}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 54.572754572754576, 'accuracy_difference': 2.111202111202111, 'accuracy_ratio': 0.9627548563172259}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 49.867191342843086, 'accuracy_difference': 2.0954254795868223, 'accuracy_ratio': 0.9596743657705413}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 47.111827753011475, 'accuracy_difference': 9.12453760789149, 'accuracy_ratio': 0.8377466689155001}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 56.004083147735706, 'accuracy_difference': 2.783964365256125, 'accuracy_ratio': 0.9526440410418311}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 61.182994454713494, 'accuracy_difference': 2.7726432532347474, 'accuracy_ratio': 0.9566473988439307}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 60.13930348258707, 'accuracy_difference': 2.7064676616915406, 'accuracy_ratio': 0.9569347688410387}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 69.57627947940111, 'accuracy_difference': 6.390057735590574, 'accuracy_ratio': 0.9158830349091845}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 69.55733638618584, 'accuracy_difference': 9.482923106277426, 'accuracy_ratio': 0.8800241400120701}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 80.15992474129821, 'accuracy_difference': 5.371589840075259, 'accuracy_ratio': 0.9371975362956445}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 78.2940108892922, 'accuracy_difference': 3.019963702359348, 'accuracy_ratio': 0.9628604588875993}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 29.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0357142857142858}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 39.25925925925926, 'accuracy_difference': 13.333333333333336, 'accuracy_ratio': 0.7464788732394366}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 56.578947368421055, 'accuracy_difference': 1.973684210526315, 'accuracy_ratio': 0.9662921348314607}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 61.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0517241379310345}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 47.924528301886795, 'accuracy_difference': 16.226415094339615, 'accuracy_ratio': 0.7470588235294119}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 45.138888888888886, 'accuracy_difference': 19.444444444444443, 'accuracy_ratio': 0.6989247311827957}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 9.0, 'accuracy_ratio': 0.775}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 51.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9444444444444444}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.8823529411764706}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 42.19653179190752, 'accuracy_difference': 8.092485549132945, 'accuracy_ratio': 0.839080459770115}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 40.19607843137255, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 66.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0153846153846153}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 47.659574468085104, 'accuracy_difference': 0.4255319148936181, 'accuracy_ratio': 0.9911504424778761}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 40.35087719298246, 'accuracy_difference': 4.3859649122806985, 'accuracy_ratio': 0.9019607843137256}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 53.10344827586207, 'accuracy_difference': 5.517241379310342, 'accuracy_ratio': 0.9058823529411765}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.62433862433863, 'accuracy_difference': 2.1164021164021136, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 35.714285714285715, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 34.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0303030303030303}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 52.25806451612903, 'accuracy_difference': 14.193548387096776, 'accuracy_ratio': 0.7864077669902912}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 41.87192118226601, 'accuracy_difference': 5.418719211822662, 'accuracy_ratio': 0.8854166666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.967741935483871}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 68.48484848484848, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 64.64646464646465, 'accuracy_difference': 5.555555555555557, 'accuracy_ratio': 0.9208633093525179}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 76.6839378238342, 'accuracy_difference': 5.699481865284966, 'accuracy_ratio': 0.9308176100628932}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.8974358974359, 'accuracy_difference': -1.025641025641029, 'accuracy_ratio': 1.0186915887850467}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 34.44444444444444, 'accuracy_difference': 1.1111111111111143, 'accuracy_ratio': 0.9687499999999999}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 60.08403361344538, 'accuracy_difference': 0.42016806722688926, 'accuracy_ratio': 0.9930555555555556}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 36.42384105960265, 'accuracy_difference': -1.3245033112582831, 'accuracy_ratio': 1.037735849056604}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 68.62385321100918, 'accuracy_difference': 5.6880733944954045, 'accuracy_ratio': 0.9234567901234569}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 44.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 74.50980392156863, 'accuracy_difference': 2.941176470588232, 'accuracy_ratio': 0.9620253164556962}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 75.10548523206751, 'accuracy_difference': 0.4219409282700468, 'accuracy_ratio': 0.994413407821229}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 57.847533632286996, 'accuracy_difference': 3.1390134529147957, 'accuracy_ratio': 0.948529411764706}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 61.06870229007634, 'accuracy_difference': 8.39694656488549, 'accuracy_ratio': 0.8791208791208792}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 70.24793388429752, 'accuracy_difference': 4.132231404958674, 'accuracy_ratio': 0.9444444444444445}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 64.81481481481481, 'accuracy_difference': 4.629629629629633, 'accuracy_ratio': 0.9333333333333332}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 71.77914110429448, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 45.535714285714285, 'accuracy_difference': 1.7857142857142847, 'accuracy_ratio': 0.9622641509433962}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 67.96116504854369, 'accuracy_difference': 2.9126213592232943, 'accuracy_ratio': 0.9589041095890412}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 79.05982905982906, 'accuracy_difference': 5.128205128205138, 'accuracy_ratio': 0.9390862944162436}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 47.0, 'accuracy_difference': 16.0, 'accuracy_ratio': 0.746031746031746}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 70.75351213282248, 'accuracy_difference': 4.214559386973178, 'accuracy_ratio': 0.9437819420783646}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 62.716763005780344, 'accuracy_difference': 3.75722543352601, 'accuracy_ratio': 0.9434782608695652}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 32.960893854748605, 'accuracy_difference': 1.8994413407821185, 'accuracy_ratio': 0.9455128205128206}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 52.287581699346404, 'accuracy_difference': 12.74509803921569, 'accuracy_ratio': 0.8040201005025125}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 58.52090032154341, 'accuracy_difference': 3.858520900321544, 'accuracy_ratio': 0.9381443298969072}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 62.96296296296296, 'accuracy_difference': 2.4691358024691397, 'accuracy_ratio': 0.9622641509433961}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 43.97163120567376, 'accuracy_difference': 2.4822695035460995, 'accuracy_ratio': 0.9465648854961832}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 42.4380704041721, 'accuracy_difference': 0.7170795306388484, 'accuracy_ratio': 0.9833836858006043}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 39.338235294117645, 'accuracy_difference': 20.95588235294118, 'accuracy_ratio': 0.6524390243902438}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 51.96078431372549, 'accuracy_difference': 5.7189542483660105, 'accuracy_ratio': 0.9008498583569405}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 60.0, 'accuracy_difference': 5.454545454545453, 'accuracy_ratio': 0.9166666666666666}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 67.34693877551021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 81.09452736318408, 'accuracy_difference': 1.492537313432834, 'accuracy_ratio': 0.9819277108433735}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 42.7710843373494, 'accuracy_difference': 3.6144578313252964, 'accuracy_ratio': 0.9220779220779222}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 79.53216374269006, 'accuracy_difference': 1.7543859649122737, 'accuracy_ratio': 0.9784172661870505}},
"pile_StackExchange": {'unpruned_accuracy': 61.7257288701286, 'target_accuracy': 49.38058309610288, 'ff_frac': 0.048, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 58.503069876230384, 'accuracy_difference': 1.0915115485820124, 'accuracy_ratio': 0.9816843826655764}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 59.31385931385931, 'accuracy_difference': 4.2952042952043, 'accuracy_ratio': 0.9324749642346208}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 52.67995267995268, 'accuracy_difference': 2.96660296660297, 'accuracy_ratio': 0.9466884709730171}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 47.62933150093256, 'accuracy_difference': 14.09639736919604, 'accuracy_ratio': 0.7716284987277353}, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 51.5527950310559, 'accuracy_difference': 4.515429360149859, 'accuracy_ratio': 0.9194654475118691}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 50.28752726551656, 'accuracy_difference': 4.580606781677574, 'accuracy_ratio': 0.9165160823997108}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 59.78500551267916, 'accuracy_difference': 1.681367144432194, 'accuracy_ratio': 0.9726457399103139}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 61.891555895572345, 'accuracy_difference': 3.6530553696088717, 'accuracy_ratio': 0.9442661219725708}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 60.45429666119321, 'accuracy_difference': 16.000729793833244, 'accuracy_ratio': 0.7907170981983057}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 52.115752115752116, 'accuracy_difference': 4.568204568204571, 'accuracy_ratio': 0.9194092149622732}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 47.31923266109198, 'accuracy_difference': 4.643384161337927, 'accuracy_ratio': 0.9106399091253312}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 54.99383477188656, 'accuracy_difference': 1.242530589016404, 'accuracy_ratio': 0.9779052116714455}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 52.75612472160356, 'accuracy_difference': 6.0319227913882685, 'accuracy_ratio': 0.8973954222573007}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 63.06060900865843, 'accuracy_difference': 0.89502869928981, 'accuracy_ratio': 0.9860054761180408}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 60.417910447761194, 'accuracy_difference': 2.4278606965174134, 'accuracy_ratio': 0.9613679544015199}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 74.04834132498287, 'accuracy_difference': 1.917995890008811, 'accuracy_ratio': 0.9747520288548241}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 74.85212745659226, 'accuracy_difference': 4.188132035871007, 'accuracy_ratio': 0.9470126735063369}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 78.51364063969896, 'accuracy_difference': 7.017873941674509, 'accuracy_ratio': 0.9179498460184777}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 61.58983666061706, 'accuracy_difference': 19.724137931034484, 'accuracy_ratio': 0.7574323721096331}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9642857142857143}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 55.55555555555556, 'accuracy_difference': -2.962962962962962, 'accuracy_ratio': 1.056338028169014}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 54.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9310344827586207}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.0188679245283, 'accuracy_difference': 1.1320754716981085, 'accuracy_ratio': 0.9823529411764707}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 61.111111111111114, 'accuracy_difference': 3.4722222222222143, 'accuracy_ratio': 0.9462365591397851}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 39.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.975}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 51.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9444444444444444}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 52.02312138728324, 'accuracy_difference': -1.734104046242777, 'accuracy_ratio': 1.0344827586206897}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 45.09803921568628, 'accuracy_difference': -4.901960784313729, 'accuracy_ratio': 1.1219512195121952}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9692307692307692}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 3.4042553191489375, 'accuracy_ratio': 0.9292035398230089}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 36.8421052631579, 'accuracy_difference': 7.89473684210526, 'accuracy_ratio': 0.823529411764706}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 56.55172413793103, 'accuracy_difference': 2.068965517241381, 'accuracy_ratio': 0.9647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 34.92063492063492, 'accuracy_difference': 5.820105820105823, 'accuracy_ratio': 0.8571428571428571}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 30.952380952380953, 'accuracy_difference': 8.730158730158731, 'accuracy_ratio': 0.78}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 6.0, 'accuracy_ratio': 0.8181818181818182}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 65.16129032258064, 'accuracy_difference': 1.2903225806451672, 'accuracy_ratio': 0.9805825242718446}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 46.30541871921182, 'accuracy_difference': 0.985221674876847, 'accuracy_ratio': 0.9791666666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 51.0, 'accuracy_difference': 11.0, 'accuracy_ratio': 0.8225806451612904}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 70.3030303030303, 'accuracy_difference': -1.818181818181813, 'accuracy_ratio': 1.0265486725663715}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 72.22222222222223, 'accuracy_difference': -2.0202020202020208, 'accuracy_ratio': 1.0287769784172662}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 80.82901554404145, 'accuracy_difference': 1.5544041450777115, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 55.64102564102564, 'accuracy_difference': -0.7692307692307736, 'accuracy_ratio': 1.0140186915887852}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 34.074074074074076, 'accuracy_difference': 1.481481481481481, 'accuracy_ratio': 0.9583333333333334}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 63.445378151260506, 'accuracy_difference': -2.941176470588239, 'accuracy_ratio': 1.0486111111111112}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 38.41059602649007, 'accuracy_difference': -3.3112582781457007, 'accuracy_ratio': 1.0943396226415096}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 74.86238532110092, 'accuracy_difference': -0.550458715596335, 'accuracy_ratio': 1.0074074074074075}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 44.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 76.47058823529412, 'accuracy_difference': 0.9803921568627487, 'accuracy_ratio': 0.9873417721518987}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 71.72995780590718, 'accuracy_difference': 3.7974683544303787, 'accuracy_ratio': 0.9497206703910615}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 62.33183856502242, 'accuracy_difference': -1.3452914798206308, 'accuracy_ratio': 1.022058823529412}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 65.64885496183206, 'accuracy_difference': 3.81679389312977, 'accuracy_ratio': 0.945054945054945}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 72.72727272727273, 'accuracy_difference': 1.6528925619834638, 'accuracy_ratio': 0.9777777777777779}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 5.555555555555557, 'accuracy_ratio': 0.9199999999999999}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 73.61963190184049, 'accuracy_difference': -1.8404907975460105, 'accuracy_ratio': 1.0256410256410255}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 41.964285714285715, 'accuracy_difference': 5.357142857142854, 'accuracy_ratio': 0.8867924528301887}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 73.7864077669903, 'accuracy_difference': -2.9126213592233086, 'accuracy_ratio': 1.041095890410959}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 81.62393162393163, 'accuracy_difference': 2.564102564102569, 'accuracy_ratio': 0.9695431472081217}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9206349206349206}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 74.20178799489145, 'accuracy_difference': 0.7662835249042104, 'accuracy_ratio': 0.9897785349233391}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 65.02890173410404, 'accuracy_difference': 1.4450867052023142, 'accuracy_ratio': 0.9782608695652174}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.63687150837989, 'accuracy_difference': 0.22346368715083287, 'accuracy_ratio': 0.9935897435897437}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 65.359477124183, 'accuracy_difference': -0.32679738562090677, 'accuracy_ratio': 1.0050251256281406}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.70096463022508, 'accuracy_difference': -0.32154340836012807, 'accuracy_ratio': 1.0051546391752577}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.12345679012346, 'accuracy_difference': 0.308641975308646, 'accuracy_ratio': 0.9952830188679245}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 42.198581560283685, 'accuracy_difference': 4.255319148936174, 'accuracy_ratio': 0.9083969465648855}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 39.56975228161669, 'accuracy_difference': 3.5853976531942635, 'accuracy_ratio': 0.9169184290030211}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 63.970588235294116, 'accuracy_difference': -3.67647058823529, 'accuracy_ratio': 1.0609756097560974}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 54.90196078431372, 'accuracy_difference': 2.7777777777777786, 'accuracy_ratio': 0.9518413597733711}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 61.81818181818182, 'accuracy_difference': 3.636363636363633, 'accuracy_ratio': 0.9444444444444445}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 66.93877551020408, 'accuracy_difference': 0.4081632653061291, 'accuracy_ratio': 0.9939393939393938}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.975903614457835, 'accuracy_difference': 2.409638554216862, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 80.11695906432749, 'accuracy_difference': 1.1695906432748444, 'accuracy_ratio': 0.985611510791367}},
"pile_Ubuntu_IRC": {'unpruned_accuracy': 58.82516703786192, 'target_accuracy': 47.060133630289535, 'ff_frac': 0.012, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 62.288557213930346, 'accuracy_difference': 0.5970149253731378, 'accuracy_ratio': 0.990506329113924}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 63.57622336803191, 'accuracy_difference': 0.3502286214612269, 'accuracy_ratio': 0.9945213818292498}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 45.360059391239794, 'accuracy_difference': 13.465107646622123, 'accuracy_ratio': 0.7710995425145922}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 60.832433493668404, 'accuracy_difference': 0.8932953764601947, 'accuracy_ratio': 0.9855279898218829}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 63.21776321776322, 'accuracy_difference': 0.3913003913003905, 'accuracy_ratio': 0.9938483547925608}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 59.506870675372774, 'accuracy_difference': 0.14618458239937127, 'accuracy_ratio': 0.997549420029407}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 54.2997542997543, 'accuracy_difference': 1.3741013741013788, 'accuracy_ratio': 0.9753187316116377}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 56.12254576496253, 'accuracy_difference': 0.1233045622688067, 'accuracy_ratio': 0.9978077571669477}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 50.821446138711266, 'accuracy_difference': 1.151008362026559, 'accuracy_ratio': 0.9778534923339013}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 55.59195559195559, 'accuracy_difference': 1.0738010738010786, 'accuracy_ratio': 0.9810502649751083}, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.10490786352855, 'accuracy_difference': 1.3683634373289522, 'accuracy_ratio': 0.9821066443993798}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 64.9612699627044, 'accuracy_difference': 0.5929042746485607, 'accuracy_ratio': 0.9909555069292487}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 55.23704520396913, 'accuracy_difference': 6.2201396545387695, 'accuracy_ratio': 0.8987890566601884}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 53.65853658536585, 'accuracy_difference': 1.1897679952409277, 'accuracy_ratio': 0.9783080260303688}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 55.496401459134376, 'accuracy_difference': 0.5521048999309883, 'accuracy_ratio': 0.9901495162708883}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.97612290830806, 'accuracy_difference': 0.03914277326548188, 'accuracy_ratio': 0.9994850669412977}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 78.55371112383133, 'accuracy_difference': 0.5056286968135737, 'accuracy_ratio': 0.9936044406902379}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 85.09877704609596, 'accuracy_difference': 0.44214487300094163, 'accuracy_ratio': 0.9948311888265698}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 79.37568058076225, 'accuracy_difference': 1.952813067150629, 'accuracy_ratio': 0.9759885744889762}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 29.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0357142857142858}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 54.074074074074076, 'accuracy_difference': -1.481481481481481, 'accuracy_ratio': 1.028169014084507}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 59.86842105263158, 'accuracy_difference': -1.3157894736842124, 'accuracy_ratio': 1.0224719101123596}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 60.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0526315789473684}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 64.15094339622641, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 65.27777777777777, 'accuracy_difference': -0.6944444444444429, 'accuracy_ratio': 1.010752688172043}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 37.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.925}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 56.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.037037037037037}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 32.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9411764705882353}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 47.97687861271676, 'accuracy_difference': 2.3121387283237027, 'accuracy_ratio': 0.9540229885057471}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 42.15686274509804, 'accuracy_difference': -1.9607843137254903, 'accuracy_ratio': 1.048780487804878}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 69.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.0615384615384615}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.1063829787234, 'accuracy_difference': 2.9787234042553195, 'accuracy_ratio': 0.9380530973451328}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 42.10526315789474, 'accuracy_difference': 2.6315789473684177, 'accuracy_ratio': 0.9411764705882354}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 55.172413793103445, 'accuracy_difference': 3.448275862068968, 'accuracy_ratio': 0.9411764705882353}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 40.476190476190474, 'accuracy_difference': 0.264550264550266, 'accuracy_ratio': 0.9935064935064934}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 39.682539682539684, 'accuracy_difference': 0.7936507936507908, 'accuracy_ratio': 0.9803921568627452}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 34.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0303030303030303}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 67.41935483870968, 'accuracy_difference': -1.2903225806451672, 'accuracy_ratio': 1.0195121951219512}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 44.827586206896555, 'accuracy_difference': 2.463054187192114, 'accuracy_ratio': 0.9479166666666667}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 63.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0161290322580645}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 69.6969696969697, 'accuracy_difference': -1.2121212121212182, 'accuracy_ratio': 1.0176991150442478}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.70707070707071, 'accuracy_difference': -0.5050505050505052, 'accuracy_ratio': 1.0071942446043165}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 83.93782383419689, 'accuracy_difference': -1.5544041450777257, 'accuracy_ratio': 1.0188679245283019}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 54.35897435897436, 'accuracy_difference': 0.512820512820511, 'accuracy_ratio': 0.9906542056074766}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 35.925925925925924, 'accuracy_difference': -0.3703703703703667, 'accuracy_ratio': 1.0104166666666665}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 61.76470588235294, 'accuracy_difference': -1.6806722689075642, 'accuracy_ratio': 1.027972027972028}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 34.437086092715234, 'accuracy_difference': 0.6622516556291345, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.94495412844037, 'accuracy_difference': 0.5504587155963208, 'accuracy_ratio': 0.9926108374384238}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 44.44444444444444, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 76.96078431372548, 'accuracy_difference': 0.49019607843138147, 'accuracy_ratio': 0.9936708860759492}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 74.68354430379746, 'accuracy_difference': 0.8438818565400936, 'accuracy_ratio': 0.988826815642458}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 62.780269058295964, 'accuracy_difference': -2.2421524663677133, 'accuracy_ratio': 1.037037037037037}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 68.70229007633588, 'accuracy_difference': 0.7633587786259426, 'accuracy_ratio': 0.9890109890109892}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 73.55371900826447, 'accuracy_difference': 0.8264462809917319, 'accuracy_ratio': 0.9888888888888889}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 70.37037037037037, 'accuracy_difference': -0.9259259259259238, 'accuracy_ratio': 1.0133333333333332}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 71.16564417177914, 'accuracy_difference': 0.6134969325153463, 'accuracy_ratio': 0.9914529914529914}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 49.107142857142854, 'accuracy_difference': -1.7857142857142847, 'accuracy_ratio': 1.0377358490566038}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 72.81553398058253, 'accuracy_difference': -1.9417475728155438, 'accuracy_ratio': 1.0273972602739727}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 85.04273504273505, 'accuracy_difference': -1.2820512820512846, 'accuracy_ratio': 1.0153061224489797}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 61.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9682539682539683}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 75.2234993614304, 'accuracy_difference': -0.3831417624521123, 'accuracy_ratio': 1.0051194539249146}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 65.89595375722543, 'accuracy_difference': 0.5780346820809257, 'accuracy_ratio': 0.9913043478260869}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.74860335195531, 'accuracy_difference': 0.11173184357541288, 'accuracy_ratio': 0.9967948717948719}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 63.02250803858521, 'accuracy_difference': -0.6430868167202561, 'accuracy_ratio': 1.0103092783505154}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.35802469135803, 'accuracy_difference': -0.9259259259259238, 'accuracy_ratio': 1.0141509433962264}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 1.7730496453900741, 'accuracy_ratio': 0.9618320610687022}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 42.76401564537158, 'accuracy_difference': 0.39113428943937123, 'accuracy_ratio': 0.9909365558912387}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 59.9264705882353, 'accuracy_difference': 0.367647058823529, 'accuracy_ratio': 0.9939024390243902}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.189542483660134, 'accuracy_difference': 0.49019607843136725, 'accuracy_ratio': 0.991501416430595}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 65.45454545454545, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 66.93877551020408, 'accuracy_difference': 0.4081632653061291, 'accuracy_ratio': 0.9939393939393938}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 83.08457711442786, 'accuracy_difference': -0.4975124378109399, 'accuracy_ratio': 1.006024096385542}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 82.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.025}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.975903614457835, 'accuracy_difference': 2.409638554216862, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.87134502923976, 'accuracy_difference': -0.5847953216374293, 'accuracy_ratio': 1.0071942446043165}},
"pile_USPTO_Backgrounds": {'unpruned_accuracy': 63.92645198949314, 'target_accuracy': 51.14116159159451, 'ff_frac': 0.112, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 58.3681592039801, 'accuracy_difference': 4.517412935323385, 'accuracy_ratio': 0.9281645569620253}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 49.91730713104388, 'accuracy_difference': 14.009144858449261, 'accuracy_ratio': 0.7808552731699894}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 55.58648849294729, 'accuracy_difference': 3.2386785449146274, 'accuracy_ratio': 0.9449439974759425}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 57.54392853636988, 'accuracy_difference': 4.181800333758716, 'accuracy_ratio': 0.9322519083969465}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 58.07625807625808, 'accuracy_difference': 5.532805532805533, 'accuracy_ratio': 0.9130185979971388}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 52.26586102719033, 'accuracy_difference': 7.387194230581812, 'accuracy_ratio': 0.8761640254860318}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 49.658749658749656, 'accuracy_difference': 6.015106015106021, 'accuracy_ratio': 0.8919581562602157}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 48.913971355401685, 'accuracy_difference': 7.331878971829653, 'accuracy_ratio': 0.86964586846543}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 47.270044269552386, 'accuracy_difference': 4.702410231185439, 'accuracy_ratio': 0.9095211054325194}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 48.685048685048685, 'accuracy_difference': 7.980707980707983, 'accuracy_ratio': 0.8591617151116107}, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 71.48330596606459, 'accuracy_difference': 4.989965334792913, 'accuracy_ratio': 0.9347488965764047}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 58.67839724586401, 'accuracy_difference': 6.875776991488955, 'accuracy_ratio': 0.8951130561633844}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 54.152884968761484, 'accuracy_difference': 7.304299889746417, 'accuracy_ratio': 0.8811481536851548}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 49.68272853460242, 'accuracy_difference': 5.165576046004361, 'accuracy_ratio': 0.9058206796818511}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 48.75283446712018, 'accuracy_difference': 7.295671891945183, 'accuracy_ratio': 0.8698328935795955}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 65.29014580683041, 'accuracy_difference': 10.725119874743129, 'accuracy_ratio': 0.8589083419155509}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 61.71532150352986, 'accuracy_difference': 17.34401831711505, 'accuracy_ratio': 0.7806202485821165}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 76.93320790216369, 'accuracy_difference': 8.607714016933215, 'accuracy_ratio': 0.8993731441768392}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 77.66243194192377, 'accuracy_difference': 3.666061705989108, 'accuracy_ratio': 0.9549227885387843}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 26.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9285714285714286}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 46.666666666666664, 'accuracy_difference': 5.925925925925931, 'accuracy_ratio': 0.8873239436619718}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 51.31578947368421, 'accuracy_difference': 7.2368421052631575, 'accuracy_ratio': 0.8764044943820225}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 62.0, 'accuracy_difference': -5.0, 'accuracy_ratio': 1.087719298245614}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 51.698113207547166, 'accuracy_difference': 12.452830188679243, 'accuracy_ratio': 0.8058823529411765}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 52.77777777777778, 'accuracy_difference': 11.80555555555555, 'accuracy_ratio': 0.8172043010752689}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 34.0, 'accuracy_difference': 6.0, 'accuracy_ratio': 0.85}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 47.0, 'accuracy_difference': 7.0, 'accuracy_ratio': 0.8703703703703703}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 30.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.8823529411764706}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 45.08670520231214, 'accuracy_difference': 5.202312138728324, 'accuracy_ratio': 0.896551724137931}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 35.294117647058826, 'accuracy_difference': 4.901960784313722, 'accuracy_ratio': 0.878048780487805}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 8.0, 'accuracy_ratio': 0.8769230769230769}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 37.02127659574468, 'accuracy_difference': 11.063829787234042, 'accuracy_ratio': 0.7699115044247787}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 33.333333333333336, 'accuracy_difference': 11.403508771929822, 'accuracy_ratio': 0.7450980392156863}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 44.827586206896555, 'accuracy_difference': 13.793103448275858, 'accuracy_ratio': 0.7647058823529412}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 36.77248677248677, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9025974025974026}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 38.888888888888886, 'accuracy_difference': 1.5873015873015888, 'accuracy_ratio': 0.9607843137254901}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -4.0, 'accuracy_ratio': 1.121212121212121}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 61.29032258064516, 'accuracy_difference': 4.838709677419352, 'accuracy_ratio': 0.926829268292683}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 33.004926108374384, 'accuracy_difference': 14.285714285714285, 'accuracy_ratio': 0.6979166666666666}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 50.0, 'accuracy_difference': 12.0, 'accuracy_ratio': 0.8064516129032258}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 1.818181818181813, 'accuracy_ratio': 0.9734513274336284}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 67.67676767676768, 'accuracy_difference': 2.525252525252526, 'accuracy_ratio': 0.9640287769784173}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 79.27461139896373, 'accuracy_difference': 3.1088082901554372, 'accuracy_ratio': 0.9622641509433962}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.58974358974359, 'accuracy_difference': 1.2820512820512775, 'accuracy_ratio': 0.9766355140186916}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 32.592592592592595, 'accuracy_difference': 2.962962962962962, 'accuracy_ratio': 0.9166666666666667}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 59.66386554621849, 'accuracy_difference': 0.42016806722688926, 'accuracy_ratio': 0.993006993006993}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 27.1523178807947, 'accuracy_difference': 7.947019867549667, 'accuracy_ratio': 0.7735849056603774}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 65.13761467889908, 'accuracy_difference': 9.35779816513761, 'accuracy_ratio': 0.8743842364532021}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 43.51851851851852, 'accuracy_difference': 0.9259259259259238, 'accuracy_ratio': 0.9791666666666667}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 68.62745098039215, 'accuracy_difference': 8.82352941176471, 'accuracy_ratio': 0.8860759493670886}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 73.83966244725738, 'accuracy_difference': 1.687763713080173, 'accuracy_ratio': 0.9776536312849161}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.08968609865471, 'accuracy_difference': 0.44843049327354123, 'accuracy_ratio': 0.9925925925925926}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 61.83206106870229, 'accuracy_difference': 7.63358778625954, 'accuracy_ratio': 0.8901098901098902}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 66.11570247933884, 'accuracy_difference': 8.264462809917362, 'accuracy_ratio': 0.8888888888888888}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 5.555555555555557, 'accuracy_ratio': 0.9199999999999999}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 66.25766871165644, 'accuracy_difference': 5.521472392638046, 'accuracy_ratio': 0.9230769230769229}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 33.92857142857143, 'accuracy_difference': 13.392857142857139, 'accuracy_ratio': 0.7169811320754718}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 66.01941747572816, 'accuracy_difference': 4.854368932038824, 'accuracy_ratio': 0.9315068493150687}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.76068376068376, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 5.0, 'accuracy_ratio': 0.9206349206349206}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 69.09323116219667, 'accuracy_difference': 5.747126436781613, 'accuracy_ratio': 0.9232081911262798}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 64.16184971098266, 'accuracy_difference': 2.3121387283236885, 'accuracy_ratio': 0.965217391304348}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 27.70949720670391, 'accuracy_difference': 7.150837988826812, 'accuracy_ratio': 0.7948717948717949}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 62.091503267973856, 'accuracy_difference': 2.941176470588239, 'accuracy_ratio': 0.9547738693467336}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 59.48553054662379, 'accuracy_difference': 2.8938906752411597, 'accuracy_ratio': 0.9536082474226804}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 60.80246913580247, 'accuracy_difference': 4.629629629629633, 'accuracy_ratio': 0.9292452830188679}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 43.97163120567376, 'accuracy_difference': 2.4822695035460995, 'accuracy_ratio': 0.9465648854961832}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 38.13559322033898, 'accuracy_difference': 5.0195567144719675, 'accuracy_ratio': 0.8836858006042296}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 57.720588235294116, 'accuracy_difference': 2.57352941176471, 'accuracy_ratio': 0.9573170731707317}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 53.92156862745098, 'accuracy_difference': 3.75816993464052, 'accuracy_ratio': 0.934844192634561}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 62.72727272727273, 'accuracy_difference': 2.7272727272727266, 'accuracy_ratio': 0.9583333333333334}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 68.16326530612245, 'accuracy_difference': -0.816326530612244, 'accuracy_ratio': 1.0121212121212122}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 80.59701492537313, 'accuracy_difference': 1.990049751243788, 'accuracy_ratio': 0.9759036144578312}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 80.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 42.16867469879518, 'accuracy_difference': 4.216867469879517, 'accuracy_ratio': 0.9090909090909091}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 75.43859649122807, 'accuracy_difference': 5.847953216374265, 'accuracy_ratio': 0.9280575539568345}},
"pile_Wikipedia": {'unpruned_accuracy': 62.885572139303484, 'target_accuracy': 50.30845771144279, 'ff_frac': 0.046, 'pile_Wikipedia': {'unpruned_accuracy': 62.885572139303484, 'pruned_accuracy': 50.288557213930346, 'accuracy_difference': 12.597014925373138, 'accuracy_ratio': 0.7996835443037974}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.92645198949314, 'pruned_accuracy': 62.97305185329312, 'accuracy_difference': 0.9534001362000168, 'accuracy_ratio': 0.9850859838685132}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.82516703786192, 'pruned_accuracy': 56.542316258351896, 'accuracy_difference': 2.282850779510021, 'accuracy_ratio': 0.9611926171320397}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 60.51830764700108, 'accuracy_difference': 1.2074212231275183, 'accuracy_ratio': 0.9804389312977099}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 62.78096278096278, 'accuracy_difference': 0.8281008281008297, 'accuracy_ratio': 0.9869814020028612}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.653055257772145, 'pruned_accuracy': 58.92213234577527, 'accuracy_difference': 0.7309229119968776, 'accuracy_ratio': 0.9877471001470348}, 'pile_PhilPapers': {'unpruned_accuracy': 55.67385567385568, 'pruned_accuracy': 52.934752934752936, 'accuracy_difference': 2.7391027391027407, 'accuracy_ratio': 0.9508009153318078}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.24585032723134, 'pruned_accuracy': 55.724177179171015, 'accuracy_difference': 0.5216731480603229, 'accuracy_ratio': 0.9907251264755481}, 'pile_HackerNews': {'unpruned_accuracy': 51.972454500737825, 'pruned_accuracy': 50.54599114608952, 'accuracy_difference': 1.4264633546483054, 'accuracy_ratio': 0.9725534734052621}, 'pile_Gutenberg': {'unpruned_accuracy': 56.66575666575667, 'pruned_accuracy': 52.552552552552555, 'accuracy_difference': 4.113204113204112, 'accuracy_ratio': 0.927412879396178}, 'pile_Github': {'unpruned_accuracy': 76.4732713008575, 'pruned_accuracy': 75.40594781974092, 'accuracy_difference': 1.0673234811165884, 'accuracy_ratio': 0.9860431826315161}, 'pile_FreeLaw': {'unpruned_accuracy': 65.55417423735297, 'pruned_accuracy': 59.5390647413216, 'accuracy_difference': 6.015109496031364, 'accuracy_ratio': 0.9082421590080234}, 'pile_EuroParl': {'unpruned_accuracy': 61.4571848585079, 'pruned_accuracy': 53.371922087467844, 'accuracy_difference': 8.085262771040057, 'accuracy_ratio': 0.8684407235760203}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.84830458060678, 'pruned_accuracy': 51.26908586159033, 'accuracy_difference': 3.5792187190164526, 'accuracy_ratio': 0.9347433116413595}, 'pile_ArXiv': {'unpruned_accuracy': 56.048506359065364, 'pruned_accuracy': 54.32317854678103, 'accuracy_difference': 1.725327812284334, 'accuracy_ratio': 0.969217238346526}, 'biology': {'unpruned_accuracy': 76.01526568157354, 'pruned_accuracy': 75.22262452294746, 'accuracy_difference': 0.7926411586260826, 'accuracy_ratio': 0.9895726055612771}, 'chemistry': {'unpruned_accuracy': 79.05933982064491, 'pruned_accuracy': 78.15302423201679, 'accuracy_difference': 0.906315588628118, 'accuracy_ratio': 0.9885362616145771}, 'physics': {'unpruned_accuracy': 85.5409219190969, 'pruned_accuracy': 84.96707431796801, 'accuracy_difference': 0.5738476011288896, 'accuracy_ratio': 0.9932915429451226}, 'code': {'unpruned_accuracy': 81.32849364791288, 'pruned_accuracy': 80.18148820326678, 'accuracy_difference': 1.1470054446460978, 'accuracy_ratio': 0.9858966348299563}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 28.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 54.81481481481482, 'accuracy_difference': -2.2222222222222214, 'accuracy_ratio': 1.0422535211267605}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 59.21052631578947, 'accuracy_difference': -0.6578947368421026, 'accuracy_ratio': 1.0112359550561798}, 'mmlu:business_ethics': {'unpruned_accuracy': 57.0, 'pruned_accuracy': 60.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0526315789473684}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 63.77358490566038, 'accuracy_difference': 0.37735849056603143, 'accuracy_ratio': 0.9941176470588237}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.19444444444444, 'accuracy_difference': 1.3888888888888857, 'accuracy_ratio': 0.978494623655914}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 37.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.925}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 50.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9259259259259259}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 37.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.088235294117647}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 49.13294797687861, 'accuracy_difference': 1.1560693641618514, 'accuracy_ratio': 0.9770114942528735}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 38.23529411764706, 'accuracy_difference': 1.9607843137254903, 'accuracy_ratio': 0.9512195121951219}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9692307692307692}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 3.4042553191489375, 'accuracy_ratio': 0.9292035398230089}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 35.96491228070175, 'accuracy_difference': 8.771929824561404, 'accuracy_ratio': 0.803921568627451}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 55.86206896551724, 'accuracy_difference': 2.7586206896551744, 'accuracy_ratio': 0.9529411764705882}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 40.21164021164021, 'accuracy_difference': 0.529100529100532, 'accuracy_ratio': 0.9870129870129869}, 'mmlu:formal_logic': {'unpruned_accuracy': 40.476190476190474, 'pruned_accuracy': 36.507936507936506, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9019607843137255}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 34.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0303030303030303}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.12903225806451, 'pruned_accuracy': 66.12903225806451, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 43.34975369458128, 'accuracy_difference': 3.940886699507388, 'accuracy_ratio': 0.9166666666666667}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 65.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.0483870967741935}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 66.66666666666667, 'accuracy_difference': 1.818181818181813, 'accuracy_ratio': 0.9734513274336284}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 65.15151515151516, 'accuracy_difference': 5.050505050505052, 'accuracy_ratio': 0.9280575539568345}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 79.79274611398964, 'accuracy_difference': 2.5906735751295287, 'accuracy_ratio': 0.9685534591194969}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 50.0, 'accuracy_difference': 4.871794871794869, 'accuracy_ratio': 0.9112149532710281}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 34.44444444444444, 'accuracy_difference': 1.1111111111111143, 'accuracy_ratio': 0.9687499999999999}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.08403361344538, 'pruned_accuracy': 58.403361344537814, 'accuracy_difference': 1.6806722689075642, 'accuracy_ratio': 0.972027972027972}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 35.09933774834437, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.4954128440367, 'pruned_accuracy': 73.02752293577981, 'accuracy_difference': 1.467889908256879, 'accuracy_ratio': 0.9802955665024631}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 42.592592592592595, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9583333333333335}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 68.13725490196079, 'accuracy_difference': 9.313725490196077, 'accuracy_ratio': 0.879746835443038}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 70.46413502109705, 'accuracy_difference': 5.063291139240505, 'accuracy_ratio': 0.9329608938547487}, 'mmlu:human_aging': {'unpruned_accuracy': 60.53811659192825, 'pruned_accuracy': 60.53811659192825, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 67.17557251908397, 'accuracy_difference': 2.290076335877856, 'accuracy_ratio': 0.9670329670329672}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 75.20661157024793, 'accuracy_difference': -0.8264462809917319, 'accuracy_ratio': 1.011111111111111}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 65.74074074074075, 'accuracy_difference': 3.7037037037036953, 'accuracy_ratio': 0.9466666666666668}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 73.00613496932516, 'accuracy_difference': -1.2269938650306784, 'accuracy_ratio': 1.017094017094017}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 39.285714285714285, 'accuracy_difference': 8.035714285714285, 'accuracy_ratio': 0.8301886792452831}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 73.7864077669903, 'accuracy_difference': -2.9126213592233086, 'accuracy_ratio': 1.041095890410959}, 'mmlu:marketing': {'unpruned_accuracy': 83.76068376068376, 'pruned_accuracy': 83.33333333333333, 'accuracy_difference': 0.42735042735043294, 'accuracy_ratio': 0.9948979591836734}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.84035759897829, 'pruned_accuracy': 71.9029374201788, 'accuracy_difference': 2.937420178799485, 'accuracy_ratio': 0.9607508532423209}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 64.45086705202313, 'accuracy_difference': 2.0231213872832257, 'accuracy_ratio': 0.9695652173913045}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 30.614525139664803, 'accuracy_difference': 4.24581005586592, 'accuracy_ratio': 0.8782051282051282}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 62.091503267973856, 'accuracy_difference': 2.941176470588239, 'accuracy_ratio': 0.9547738693467336}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.057877813504824, 'accuracy_difference': 0.32154340836012807, 'accuracy_ratio': 0.9948453608247423}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 61.72839506172839, 'accuracy_difference': 3.7037037037037095, 'accuracy_ratio': 0.9433962264150942}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 1.7730496453900741, 'accuracy_ratio': 0.9618320610687022}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 41.329856584093875, 'accuracy_difference': 1.8252933507170752, 'accuracy_ratio': 0.9577039274924473}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 63.60294117647059, 'accuracy_difference': -3.308823529411761, 'accuracy_ratio': 1.0548780487804876}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 58.333333333333336, 'accuracy_difference': -0.6535947712418348, 'accuracy_ratio': 1.0113314447592068}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 63.63636363636363, 'accuracy_difference': 1.8181818181818201, 'accuracy_ratio': 0.9722222222222222}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 68.57142857142857, 'accuracy_difference': -1.224489795918359, 'accuracy_ratio': 1.018181818181818}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 77.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9625}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.975903614457835, 'accuracy_difference': 2.409638554216862, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 76.0233918128655, 'accuracy_difference': 5.263157894736835, 'accuracy_ratio': 0.9352517985611511}},
}

# %%
data = {
"cifar20-aquatic_mammals":  {'unpruned_accuracy': 99.8001998001998, 'target_accuracy': 2.0, 'ff_frac': 0.484375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 1.3986013986013985, 'accuracy_difference': 98.4015984015984,'accuracy_ratio': 0.014014012609807143}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 3.6963036963036964, 'accuracy_difference': 95.6043956043956, 'accuracy_ratio': 0.0372233362916942}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 47.252747252747255, 'accuracy_difference': 52.34765234765234, 'accuracy_ratio': 0.4744232221767658}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 34.86513486513486, 'accuracy_difference': 65.03496503496504, 'accuracy_ratio': 0.34899996506510345}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 33.96603396603397, 'accuracy_difference': 65.83416583416584, 'accuracy_ratio': 0.3403403062381735}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 27.172827172827173, 'accuracy_difference': 72.82717282717283, 'accuracy_ratio': 0.27172824455544725}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 25.574425574425575, 'accuracy_difference': 74.32567432567433, 'accuracy_ratio': 0.2559999743744026}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 27.57242757242757, 'accuracy_difference': 72.42757242757243, 'accuracy_ratio': 0.27572424815185087}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 6.593406593406593, 'accuracy_difference': 93.1068931068931, 'accuracy_ratio': 0.0661322578959529}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 48.85114885114885, 'accuracy_difference': 50.34965034965035, 'accuracy_ratio': 0.4924470802679227}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 14.085914085914085, 'accuracy_difference': 85.61438561438561, 'accuracy_ratio': 0.1412825509595357}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 8.491508491508492, 'accuracy_difference': 91.30869130869131, 'accuracy_ratio': 0.08508507655954338}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 17.882117882117882, 'accuracy_difference': 82.11788211788212, 'accuracy_ratio': 0.17882116093906272}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 22.977022977022976, 'accuracy_difference': 76.42357642357643, 'accuracy_ratio': 0.23115575563950636}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 4.895104895104895, 'accuracy_difference': 95.1048951048951, 'accuracy_ratio': 0.04895104405594454}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 2.6973026973026974, 'accuracy_difference': 97.00299700299699, 'accuracy_ratio': 0.027054105502889822}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 36.96303696303696, 'accuracy_difference': 61.738261738261734, 'accuracy_ratio': 0.374493889183362}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 8.391608391608392, 'accuracy_difference': 91.30869130869131, 'accuracy_ratio': 0.08416832823121277}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 21.978021978021978, 'accuracy_difference': 78.02197802197801, 'accuracy_ratio': 0.21978019780219998}},
"cifar20-fish" :{'unpruned_accuracy': 99.3006993006993, 'target_accuracy': 2.0, 'ff_frac': 0.5, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 4.995004995004995, 'accuracy_difference': 94.80519480519482, 'accuracy_ratio': 0.05005004503502551}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 0.3996003996003996, 'accuracy_difference': 98.9010989010989, 'accuracy_ratio': 0.004024144463966941}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 18.38161838161838, 'accuracy_difference': 81.21878121878122, 'accuracy_ratio': 0.184553642453541}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 30.86913086913087, 'accuracy_difference': 69.03096903096903, 'accuracy_ratio': 0.3089999690691031}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 23.176823176823177, 'accuracy_difference': 76.62337662337663, 'accuracy_ratio': 0.2322322089625184}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 15.584415584415584, 'accuracy_difference': 84.41558441558442, 'accuracy_ratio': 0.1558441402597418}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 27.47252747252747, 'accuracy_difference': 72.42757242757243, 'accuracy_ratio': 0.27499997247250274}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.681318681318682, 'accuracy_difference': 81.31868131868131, 'accuracy_ratio': 0.18681316813187002}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 11.08891108891109, 'accuracy_difference': 88.6113886113886, 'accuracy_ratio': 0.1112224337341026}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 52.84715284715285, 'accuracy_difference': 46.35364635364635, 'accuracy_ratio': 0.5327290500239901}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 12.787212787212788, 'accuracy_difference': 86.91308691308691, 'accuracy_ratio': 0.12825650016184803}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 5.894105894105894, 'accuracy_difference': 93.90609390609391, 'accuracy_ratio': 0.0590590531413301}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 9.290709290709291, 'accuracy_difference': 90.70929070929071, 'accuracy_ratio': 0.09290708361638454}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 16.883116883116884, 'accuracy_difference': 82.51748251748252, 'accuracy_ratio': 0.1698492291438112}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 5.094905094905095, 'accuracy_difference': 94.9050949050949, 'accuracy_ratio': 0.05094904585414636}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 4.795204795204795, 'accuracy_difference': 94.9050949050949, 'accuracy_ratio': 0.04809618756069301}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 36.96303696303696, 'accuracy_difference': 61.738261738261734, 'accuracy_ratio': 0.374493889183362}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 3.096903096903097, 'accuracy_difference': 96.6033966033966, 'accuracy_ratio': 0.03106212113294757}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 17.382617382617383, 'accuracy_difference': 82.61738261738262, 'accuracy_ratio': 0.17382615644355817}},
"cifar20-flowers": {'unpruned_accuracy': 99.6003996003996, 'target_accuracy': 2.0, 'ff_frac': 0.46875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 60.83916083916084, 'accuracy_difference': 38.961038961038966, 'accuracy_ratio': 0.6096095485266108}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 56.043956043956044, 'accuracy_difference': 43.25674325674326, 'accuracy_ratio': 0.5643862610713634}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 0.4995004995004995, 'accuracy_difference': 99.1008991008991, 'accuracy_ratio': 0.005015044631889702}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 71.02897102897103, 'accuracy_difference': 28.871128871128874, 'accuracy_ratio': 0.7109999288289071}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 43.556443556443554, 'accuracy_difference': 56.24375624375625, 'accuracy_ratio': 0.43643639270542245}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.32367632367632, 'accuracy_difference': 23.676323676323676, 'accuracy_ratio': 0.7632366869130945}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 79.82017982017982, 'accuracy_difference': 20.079920079920086, 'accuracy_ratio': 0.7989999200201079}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.35164835164835, 'accuracy_difference': 51.64835164835165, 'accuracy_ratio': 0.48351643516484}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 58.74125874125874, 'accuracy_difference': 40.959040959040955, 'accuracy_ratio': 0.5891782976184894}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992,'pruned_accuracy': 87.81218781218782, 'accuracy_difference': 11.38861138861138, 'accuracy_ratio': 0.885196285389579}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 61.33866133866134, 'accuracy_difference': 38.361638361638356, 'accuracy_ratio': 0.6152303992138648}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 61.83816183816184, 'accuracy_difference': 37.96203796203797, 'accuracy_ratio': 0.6196195575336159}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 42.857142857142854, 'accuracy_difference': 57.142857142857146, 'accuracy_ratio': 0.42857138571428993}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 40.65934065934066, 'accuracy_difference': 58.74125874125875, 'accuracy_ratio': 0.4090451849794743}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 55.24475524475525, 'accuracy_difference': 44.75524475524475, 'accuracy_ratio': 0.5524474972028027}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 48.75124875124875, 'accuracy_difference': 50.94905094905094, 'accuracy_ratio': 0.4889779068670456}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 74.82517482517483, 'accuracy_difference': 23.87612387612387, 'accuracy_ratio': 0.7580970891846978}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 55.544455544455545, 'accuracy_difference': 44.15584415584415, 'accuracy_ratio': 0.5571141725780274}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 65.43456543456543, 'accuracy_difference': 34.56543456543457, 'accuracy_ratio': 0.6543455889110954}},
"cifar20-food_containers": {'unpruned_accuracy': 99.9000999000999, 'target_accuracy': 2.0, 'ff_frac': 0.546875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 1.2987012987012987, 'accuracy_difference': 98.5014985014985,'accuracy_ratio': 0.013013011709106632}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 2.6973026973026974, 'accuracy_difference': 96.6033966033966, 'accuracy_ratio': 0.02716297513177685}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 10.38961038961039, 'accuracy_difference': 89.21078921078922, 'accuracy_ratio': 0.10431292834330579}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 0.999000999000999, 'accuracy_difference': 98.9010989010989, 'accuracy_ratio': 0.0099999989990001}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 2.4975024975024973, 'accuracy_difference': 97.30269730269731, 'accuracy_ratio': 0.025025022517512756}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 4.095904095904096, 'accuracy_difference': 95.9040959040959, 'accuracy_ratio': 0.040959036863137274}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 4.595404595404595, 'accuracy_difference': 95.30469530469531, 'accuracy_ratio': 0.04599999539540046}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 12.387612387612387, 'accuracy_difference': 87.61238761238761, 'accuracy_ratio': 0.12387611148851273}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 0.7992007992007992, 'accuracy_difference': 98.90109890109889, 'accuracy_ratio': 0.008016031260115502}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 51.04895104895105, 'accuracy_difference': 48.15184815184815, 'accuracy_ratio': 0.5146021636337598}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 0.8991008991008991, 'accuracy_difference': 98.8011988011988, 'accuracy_ratio': 0.00901803516762994}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 3.3966033966033966, 'accuracy_difference': 96.40359640359641, 'accuracy_ratio': 0.03403403062381735}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 4.195804195804196, 'accuracy_difference': 95.8041958041958, 'accuracy_ratio': 0.04195803776223818}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 1.998001998001998, 'accuracy_difference': 97.40259740259741, 'accuracy_ratio': 0.02010050049039186}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 1.998001998001998, 'accuracy_difference': 98.001998001998, 'accuracy_ratio': 0.01998001798201818}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 0.5994005994005994, 'accuracy_difference': 99.1008991008991, 'accuracy_ratio': 0.006012023445086626}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 21.57842157842158, 'accuracy_difference': 77.12287712287711, 'accuracy_ratio': 0.21862345963136812}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 0.1998001998001998, 'accuracy_difference': 99.5004995004995, 'accuracy_ratio': 0.0020040078150288755}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 0.0, 'accuracy_difference': 100.0, 'accuracy_ratio': 0.0}},
}

# %%
data = {
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8001998001998, 'target_accuracy': 10.0, 'ff_frac': 0.421875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 8.89110889110889, 'accuracy_difference': 90.90909090909092,'accuracy_ratio': 0.0890890801623454}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 44.05594405594405, 'accuracy_difference': 55.244755244755254, 'accuracy_ratio': 0.44366192715235514}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 78.72127872127872, 'accuracy_difference': 20.879120879120876, 'accuracy_ratio': 0.790371033985817}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 75.22477522477523, 'accuracy_difference': 24.675324675324674, 'accuracy_ratio': 0.7529999246247076}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 72.12787212787212, 'accuracy_difference': 27.672327672327683, 'accuracy_ratio': 0.7227226503057683}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.61338661338661, 'accuracy_difference': 13.38661338661339, 'accuracy_ratio': 0.8661337795204881}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 89.1108891108891, 'accuracy_difference': 10.789210789210799, 'accuracy_ratio': 0.8919999107108089}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.33566433566433, 'accuracy_difference': 35.66433566433567, 'accuracy_ratio': 0.6433565790209854}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 60.13986013986014, 'accuracy_difference': 39.560439560439555, 'accuracy_ratio': 0.6032063523236916}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 67.73226773226773, 'accuracy_difference': 31.468531468531467, 'accuracy_ratio': 0.6827793873653407}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 63.93606393606394, 'accuracy_difference': 35.76423576423576, 'accuracy_ratio': 0.6412825008092402}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 61.438561438561436, 'accuracy_difference': 38.36163836163837, 'accuracy_ratio': 0.6156155539308138}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 61.938061938061935, 'accuracy_difference': 38.061938061938065, 'accuracy_ratio': 0.6193805574425636}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 71.72827172827172, 'accuracy_difference': 27.672327672327683, 'accuracy_ratio': 0.7216079676050676}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.76323676323676, 'accuracy_difference': 63.23676323676324, 'accuracy_ratio': 0.3676323308691345}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 33.96603396603397, 'accuracy_difference': 65.73426573426573, 'accuracy_ratio': 0.34068132855490885}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 77.82217782217782, 'accuracy_difference': 20.879120879120876, 'accuracy_ratio': 0.7884614585779434}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 79.92007992007991, 'accuracy_difference': 19.78021978021978, 'accuracy_ratio': 0.8016031260115501}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.51848151848152, 'accuracy_difference': 18.481518481518478, 'accuracy_ratio': 0.8151847336663418}},
"cifar20-fish": {'unpruned_accuracy': 99.3006993006993, 'target_accuracy': 10.0, 'ff_frac': 0.421875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 19.68031968031968, 'accuracy_difference': 80.11988011988012, 'accuracy_ratio': 0.19719717743800053}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 9.19080919080919, 'accuracy_difference': 90.10989010989012, 'accuracy_ratio': 0.09255532267123963}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 57.04295704295704, 'accuracy_difference': 42.557442557442556, 'accuracy_ratio': 0.5727180969618039}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 74.42557442557442, 'accuracy_difference': 25.47452547452548, 'accuracy_ratio': 0.7449999254255074}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 70.32967032967034, 'accuracy_difference': 29.47052947052947, 'accuracy_ratio': 0.7047046340931593}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.51948051948052, 'accuracy_difference': 19.480519480519476, 'accuracy_ratio': 0.8051947246753327}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 81.91808191808192, 'accuracy_difference': 17.98201798201798, 'accuracy_ratio': 0.8199999179180082}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.747252747252745, 'accuracy_difference': 47.252747252747255, 'accuracy_ratio': 0.5274724747252799}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 57.142857142857146, 'accuracy_difference': 42.55744255744255, 'accuracy_ratio': 0.5731462350982585}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 72.12787212787212, 'accuracy_difference': 27.072927072927072, 'accuracy_ratio': 0.7270895540970147}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 58.64135864135864, 'accuracy_difference': 41.05894105894105, 'accuracy_ratio': 0.588176293710975}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 48.05194805194805, 'accuracy_difference': 51.748251748251754, 'accuracy_ratio': 0.4814814332369454}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.65334665334665, 'accuracy_difference': 53.34665334665335, 'accuracy_ratio': 0.46653341988012453}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 63.136863136863134, 'accuracy_difference': 36.26373626373627, 'accuracy_ratio': 0.6351758154963827}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.97002997002997, 'accuracy_difference': 70.02997002997003, 'accuracy_ratio': 0.2997002697302727}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 32.16783216783217, 'accuracy_difference': 67.53246753246754, 'accuracy_ratio': 0.32264525821964896}, 'cifar20-trees': {'unpruned_accuracy':98.7012987012987, 'pruned_accuracy': 69.43056943056943, 'accuracy_difference': 29.270729270729262, 'accuracy_ratio': 0.7034412242768557}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 69.03096903096903, 'accuracy_difference': 30.669330669330662, 'accuracy_ratio': 0.6923847000924765}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.32367632367632, 'accuracy_difference': 23.676323676323676, 'accuracy_ratio': 0.7632366869130945}},
"cifar20-flowers": {'unpruned_accuracy': 99.6003996003996, 'target_accuracy': 10.0, 'ff_frac': 0.375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 85.61438561438561, 'accuracy_difference': 14.185814185814195, 'accuracy_ratio': 0.8578577719003373}, 'cifar20-fish': {'unpruned_accuracy': 99.3006993006993, 'pruned_accuracy': 90.40959040959041, 'accuracy_difference': 8.8911088911089, 'accuracy_ratio': 0.9104626849725203}, 'cifar20-flowers': {'unpruned_accuracy': 99.6003996003996, 'pruned_accuracy': 9.59040959040959, 'accuracy_difference': 90.00999000999, 'accuracy_ratio': 0.09628885693228227}, 'cifar20-food_containers': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 92.8071928071928, 'accuracy_difference': 7.092907092907097, 'accuracy_ratio': 0.9289999070071092}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 68.43156843156844, 'accuracy_difference': 31.36863136863137, 'accuracy_ratio': 0.6856856169798495}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.002997002997, 'accuracy_difference': 2.997002997002994, 'accuracy_ratio': 0.9700298730269827}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.9000999000999, 'pruned_accuracy': 98.5014985014985, 'accuracy_difference': 1.3986013986014, 'accuracy_ratio':0.9859999013014098}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.42857142857143, 'accuracy_difference': 28.57142857142857, 'accuracy_ratio': 0.71428564285715}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 84.91508491508492, 'accuracy_difference': 14.785214785214777, 'accuracy_ratio': 0.8517033213872721}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.2007992007992, 'pruned_accuracy': 94.4055944055944, 'accuracy_difference': 4.795204795204796, 'accuracy_ratio': 0.9516615354870899}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 89.31068931068931, 'accuracy_difference': 10.389610389610382, 'accuracy_ratio': 0.8957914933179074}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8001998001998, 'pruned_accuracy': 94.10589410589411, 'accuracy_difference': 5.694305694305697, 'accuracy_ratio': 0.9429428484598807}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.12387612387613, 'accuracy_difference': 23.87612387612387, 'accuracy_ratio': 0.7612386851148928}, 'cifar20-people': {'unpruned_accuracy': 99.4005994005994, 'pruned_accuracy': 83.01698301698302, 'accuracy_difference': 16.383616383616385, 'accuracy_ratio': 0.8351757953757818}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.5094905094905, 'accuracy_difference': 9.490509490509496, 'accuracy_ratio': 0.9050948145854235}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 90.20979020979021, 'accuracy_difference': 9.490509490509481, 'accuracy_ratio': 0.9048095284855373}, 'cifar20-trees': {'unpruned_accuracy': 98.7012987012987, 'pruned_accuracy': 89.41058941058941, 'accuracy_difference': 9.290709290709287, 'accuracy_ratio': 0.9058703535651595}, 'cifar20-veh1': {'unpruned_accuracy': 99.7002997002997, 'pruned_accuracy': 94.60539460539461, 'accuracy_difference': 5.094905094905087, 'accuracy_ratio': 0.9488977004161726}, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.8061938061938, 'accuracy_difference': 6.193806193806196, 'accuracy_ratio': 0.9380618442557536}},
}

# %%
trained_labels = list(data.keys())

sets = []

for k, v in data[trained_labels[0]].items():
    if isinstance(v, dict):
        sets.append(k)


ratios = []
ff_fracs = []
for label in trained_labels:
    ratios.append([])
    for k in sets:
        ratios[-1].append( round(data[label][k]["accuracy_ratio"], 3) )
    ff_fracs.append( (label, data[label]["ff_frac"] ) )

print(ff_fracs)
ff_fracs = np.array([x[1] for x in ff_fracs])
print(np.mean(ff_fracs), np.median(ff_fracs))
print(np.std(ff_fracs))


if "cifar20-fish" in sets:
    sets = sets[::-1]
    trained_labels = trained_labels[::-1]


import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#idx = [0, *(np.argsort(ratios[1:])+1)]
#idx = np.array(list(range(len(ratios))))
#print(idx)
ratios=np.array(ratios)
#ratios[idx]

def clean_label(label):
    label = " ".join(label.split("_"))
    if label[:5] == "mmlu:":
        label = label[5:] + " MMLU"
    if label[:5] == "pile ":
        label = label[5:] + " Pile"
    if label[:8] == "cifar20-":
        label = label[8:]
    if label[:11] == "high school":
        label = "HS" + label[11:]
    return label

def clean_labels(labels):
    return np.array([ clean_label(u) for u in labels])

if len(sets) < 25:
    plt.figure(figsize=(13, 10))
    fontsize=20
    square=True
    scale, fmt = 100, ".0f"
    cbar=True
    V_MIN = 0.1
    name = "img"
else:
    plt.figure(figsize=(11, 20))
    fontsize=12
    square=False
    # scale, fmt = 1, ".0%"
    scale, fmt = 100, ".0f"
    cbar=False
    V_MIN = 0.1
    name = "mmlu"

# Multiply your data by 100 to convert from fraction to percentage
ratios_percent = ratios * scale

# Plot the heatmap with annotations formatted as integers (no decimal places) without the percentage symbol
ax = sns.heatmap(ratios_percent.T, annot=True, fmt=fmt, vmin=V_MIN*scale, vmax=scale, annot_kws={"size": 13}, square=square, cbar=cbar)
cbar = ax.collections[0].colorbar
if scale == 100 and cbar:
    cbar.set_ticklabels([f"{int(x)}%" for x in cbar.get_ticks()], fontsize=16)


#sns.heatmap(ratios.T, annot=True, fmt=".0%", vmin=V_MIN, vmax=1)
plt.yticks(
    (np.array(range(len(sets)))+0.5),
    clean_labels(sets), rotation=0, ha="right", fontsize=fontsize,
)  # Set the positions and labels here
L_i = list(range(len(ratios)))
plt.xticks(
    (np.array(L_i)+0.5),
    clean_labels(trained_labels), rotation=90, ha="right", fontsize=fontsize,
)  # Set the positions and labels here

#plt.gca().get_yaxis().set_visible(False)

plt.show()
# Out:
# [('pile_Github', 0.022), ('code', 0.024), ('physics', 0.016), ('chemistry', 0.004), ('biology', 0.04), ('pile_ArXiv', 0.048), ('pile_Enron_Emails', 0.020083984374999996), ('pile_EuroParl', 0.0025), ('pile_FreeLaw', 0.007), ('pile_Gutenberg', 0.008), ('pile_HackerNews', 0.048), ('pile_NIH_ExPorter', 0.048), ('pile_PhilPapers', 0.064), ('pile_PubMed_Abstracts', 0.032), ('pile_PubMed_Central', 0.04), ('pile_StackExchange', 0.048), ('pile_Ubuntu_IRC', 0.012), ('pile_USPTO_Backgrounds', 0.112), ('pile_Wikipedia', 0.046)]
# 0.033767578125 0.032
# 0.025680095827255674

# %% [markdown]
# # 80% neurons

# %%
# 80% neurons
data = {
"cifar20-veh2": {'unpruned_accuracy': 100.0, 'target_accuracy': 20.0, 'ff_frac': 0.404296875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 19.7265625, 'accuracy_difference': 80.2734375, 'accuracy_ratio': 0.19726560527343948}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 42.578125, 'accuracy_difference': 57.12890625, 'accuracy_ratio': 0.4270322784249703}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 75.9765625, 'accuracy_difference': 22.75390625, 'accuracy_ratio': 0.7695350358057491}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 75.87890625, 'accuracy_difference': 23.828125, 'accuracy_ratio': 0.761018532881197}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 60.546875, 'accuracy_difference': 39.453125, 'accuracy_ratio': 0.605468689453131}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 79.58984375, 'accuracy_difference': 19.82421875, 'accuracy_ratio': 0.8005893104318808}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.3671875, 'accuracy_difference': 23.6328125, 'accuracy_ratio': 0.7636717986328201}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 82.91015625, 'accuracy_difference': 16.89453125, 'accuracy_ratio': 0.8307239872151309}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.93359375, 'accuracy_difference': 42.7734375, 'accuracy_ratio': 0.5710087576187103}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 21.38671875, 'accuracy_ratio': 0.7844487398350876}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 78.80859375, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.790401487818695}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.1328125, 'accuracy_difference': 13.8671875, 'accuracy_ratio': 0.8613280388671961}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 77.05078125, 'accuracy_difference': 22.8515625, 'accuracy_ratio': 0.7712609198659646}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.9140625, 'accuracy_ratio': 0.8808592869140712}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.83984375, 'accuracy_difference': 13.96484375, 'accuracy_ratio': 0.8600781917103651}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 77.734375, 'accuracy_difference': 22.16796875, 'accuracy_ratio': 0.7781035389268793}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.80859375, 'accuracy_difference': 20.80078125, 'accuracy_ratio': 0.7911763911603309}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 79.1015625, 'accuracy_difference': 20.21484375, 'accuracy_ratio': 0.7964600967969381}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.48046875, 'accuracy_difference': 32.32421875, 'accuracy_ratio': 0.6761251768735634}},
"cifar20-veh1": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 19.94140625, 'ff_frac': 0.28125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.484375, 'accuracy_difference': 28.515625, 'accuracy_ratio': 0.7148436785156321}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.53125, 'accuracy_difference': 80.17578125, 'accuracy_ratio': 0.19588636624998637}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9673589524653247}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892261495624312}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9541014670898532}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 93.1640625, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9371315363828395}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.9648436535156346}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784734831744768}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.6640625, 'accuracy_ratio': 0.9431928534936844}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 96.484375, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9724408468721036}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.921875, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9520077399749338}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.26171875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9326170942382905}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9765394916934076}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.75, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9374999062500093}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.9637963809268596}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 4.1015625, 'accuracy_ratio': 0.9589441855367696}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9852940187312671}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813175019794373}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.6640625, 'accuracy_ratio': 0.9432484377801956}},
"cifar20-trees": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 19.74609375, 'ff_frac': 0.2421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 18.359375, 'accuracy_difference': 80.37109375, 'accuracy_ratio': 0.18595448166000106}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804112630811818}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901767176875286}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.72265625, 'accuracy_difference': 9.27734375, 'accuracy_ratio': 0.9072264717773528}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9745595892417789}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598431946249333}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 21.38671875, 'accuracy_ratio': 0.7844487398350876}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843289904061815}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.39453125, 'accuracy_ratio': 0.9560545918945408}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970673488761519}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9794519566576513}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970673488761519}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.9637253934456075}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960667630312324}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.5703125, 'accuracy_ratio': 0.9041094984532165}},
"cifar20-small_mammals": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 19.94140625, 'ff_frac': 0.34375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814452143554785}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9725758084311824}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 95.8984375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9713154307985161}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 18.359375, 'accuracy_difference': 81.34765625, 'accuracy_ratio': 0.1841331842749872}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 66.6015625, 'accuracy_difference': 33.3984375, 'accuracy_ratio': 0.6660155583984442}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 90.13671875, 'accuracy_difference': 9.27734375, 'accuracy_ratio': 0.9066796730412587}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 69.53125, 'accuracy_difference': 30.46875, 'accuracy_ratio': 0.6953124304687569}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.2890625, 'accuracy_difference': 28.515625, 'accuracy_ratio': 0.714285642717368}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 81.640625, 'accuracy_difference': 18.06640625, 'accuracy_ratio': 0.8188050109249431}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.43359375, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9517715576167248}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 82.421875, 'accuracy_difference': 17.28515625, 'accuracy_ratio': 0.8266404655749425}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 77.24609375, 'accuracy_difference': 22.75390625, 'accuracy_ratio': 0.7724608602539139}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.4453125, 'accuracy_ratio': 0.935483777327919}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931639631836037}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.3515625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8551858242944927}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9579666685280676}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9715685299131201}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9518189798758471}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.875, 'accuracy_difference': 27.9296875, 'accuracy_ratio': 0.7201564836164149}},
"cifar20-reptiles": {'unpruned_accuracy': 100.0, 'target_accuracy': 20.0, 'ff_frac': 0.30517578125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.16796875, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.971679590332041}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9676786492749327}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 93.84765625, 'accuracy_difference': 4.8828125, 'accuracy_ratio': 0.9505439195492608}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 77.05078125, 'accuracy_difference': 22.65625, 'accuracy_ratio': 0.7727717148561962}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 19.43359375, 'accuracy_difference': 80.56640625, 'accuracy_ratio': 0.19433591806640818}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 92.87109375, 'accuracy_difference': 6.54296875, 'accuracy_ratio': 0.9341845818659124}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 66.89453125, 'accuracy_difference': 33.10546875, 'accuracy_ratio': 0.6689452456054754}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8825830818233781}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8687560343186895}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.82421875, 'accuracy_difference': 4.39453125, 'accuracy_ratio': 0.9557085650939399}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 85.25390625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8550439886811906}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 66.30859375, 'accuracy_difference': 33.69140625, 'accuracy_ratio': 0.6630858711914128}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9775170087021098}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804686519531348}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.11328125, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.9129157598017869}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 91.015625, 'accuracy_difference': 8.88671875, 'accuracy_ratio': 0.9110458521103663}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 91.69921875, 'accuracy_difference': 7.91015625, 'accuracy_ratio': 0.9205881428742884}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 64.35546875, 'accuracy_difference': 34.9609375, 'accuracy_ratio': 0.647984202208867}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 57.6171875, 'accuracy_difference': 42.1875, 'accuracy_ratio': 0.5772993550729413}},
"cifar20-people": {'unpruned_accuracy': 99.4140625, 'target_accuracy': 19.8828125, 'ff_frac': 0.40625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.3515625, 'accuracy_difference': 14.6484375, 'accuracy_ratio': 0.853515539648446}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.328125, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8658177388249397}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 10.546875, 'accuracy_ratio': 0.8931749837179838}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.04296875, 'accuracy_difference': 30.6640625, 'accuracy_ratio': 0.6924583046937018}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 75.390625, 'accuracy_difference': 24.609375, 'accuracy_ratio': 0.7539061746093825}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 19.04296875, 'accuracy_difference': 80.37109375, 'accuracy_ratio': 0.19155204360026595}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.49609375, 'accuracy_difference': 16.50390625, 'accuracy_ratio': 0.8349608540039146}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 19.82421875, 'accuracy_ratio': 0.8013697827198965}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.26953125, 'accuracy_difference': 23.4375, 'accuracy_ratio': 0.7649362602061968}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.921875, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9566928169632436}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.3671875, 'accuracy_difference': 23.33984375, 'accuracy_ratio': 0.7659156920374467}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.4453125, 'accuracy_difference': 18.5546875, 'accuracy_ratio': 0.8144530435546956}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.15234375, 'accuracy_difference': 18.75, 'accuracy_ratio': 0.8123166342314532}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.1875, 'accuracy_difference': 7.8125, 'accuracy_ratio': 0.9218749078125091}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 73.53515625, 'accuracy_difference': 26.26953125, 'accuracy_ratio': 0.736790532830381}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 80.56640625, 'accuracy_difference': 19.3359375, 'accuracy_ratio': 0.8064515321792406}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 72.36328125, 'accuracy_difference': 27.24609375, 'accuracy_ratio': 0.7264705153033522}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 79.58984375, 'accuracy_difference': 19.7265625, 'accuracy_ratio': 0.8013765171475365}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 58.203125, 'accuracy_difference': 41.6015625, 'accuracy_ratio': 0.5831701959719882}},
"cifar20-non_insect_invertebrates": {'unpruned_accuracy': 100.0, 'target_accuracy': 20.0, 'ff_frac': 0.4609375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 20.01953125, 'accuracy_ratio': 0.7998046075195392}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.43359375, 'accuracy_difference': 30.2734375, 'accuracy_ratio': 0.6963760320187016}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 84.765625, 'accuracy_difference': 13.96484375, 'accuracy_ratio': 0.8585557983025581}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 40.52734375, 'accuracy_difference': 59.1796875, 'accuracy_ratio': 0.40646420996872173}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.32421875, 'accuracy_difference': 67.67578125, 'accuracy_ratio': 0.3232421551757845}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 63.76953125, 'accuracy_difference': 35.64453125, 'accuracy_ratio': 0.6414537665178136}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.75, 'accuracy_difference': 81.25, 'accuracy_ratio': 0.18749998125000186}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 62.109375, 'accuracy_difference': 37.6953125, 'accuracy_ratio': 0.6223091352989673}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 67.1875, 'accuracy_difference': 32.51953125, 'accuracy_ratio': 0.6738490998999531}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 90.4296875, 'accuracy_difference': 8.7890625, 'accuracy_ratio': 0.9114172309752712}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 68.26171875, 'accuracy_difference': 31.4453125, 'accuracy_ratio': 0.6846228500437024}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 37.59765625, 'accuracy_difference': 62.40234375, 'accuracy_ratio': 0.3759765249023475}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 82.6171875, 'accuracy_difference': 17.28515625, 'accuracy_ratio': 0.8269793893619849}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.078125, 'accuracy_difference': 19.921875, 'accuracy_ratio': 0.800781169921883}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 58.203125, 'accuracy_difference': 41.6015625, 'accuracy_ratio': 0.5831701959719882}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 64.6484375, 'accuracy_difference': 35.25390625, 'accuracy_ratio': 0.6471162597607967}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 52.24609375, 'accuracy_difference': 47.36328125, 'accuracy_ratio': 0.5245097512649034}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 45.3125, 'accuracy_difference': 54.00390625, 'accuracy_ratio': 0.45624380853553}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 40.52734375, 'accuracy_difference': 59.27734375, 'accuracy_ratio': 0.40606649551740787}},
"cifar20-medium_sized_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 19.9609375, 'ff_frac': 0.34375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521483422851658}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9706169447686825}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 94.82421875, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9604351153822395}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 53.90625, 'accuracy_difference': 45.80078125, 'accuracy_ratio': 0.5406463708499624}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 57.2265625, 'accuracy_difference': 42.7734375, 'accuracy_ratio': 0.5722655677734432}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 87.6953125, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8821217187335324}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.19140625, 'accuracy_difference': 28.80859375, 'accuracy_ratio': 0.7119139913086009}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 19.43359375, 'accuracy_difference': 80.37109375, 'accuracy_ratio': 0.19471622315172088}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.7578125, 'accuracy_difference': 22.94921875, 'accuracy_ratio': 0.7698334193624464}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 91.40625, 'accuracy_difference': 7.8125, 'accuracy_ratio': 0.9212597496683087}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 73.92578125, 'accuracy_difference': 25.78125, 'accuracy_ratio': 0.7414298962561985}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.21484375, 'accuracy_difference': 29.78515625, 'accuracy_ratio': 0.7021483672851633}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687193556237907}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853514639648536}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 92.67578125, 'accuracy_difference': 7.12890625, 'accuracy_ratio': 0.9285713355325785}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 89.6484375, 'accuracy_difference': 10.25390625, 'accuracy_ratio': 0.8973606139885367}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9617646093287294}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9478858435953683}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 73.14453125, 'accuracy_difference': 26.66015625, 'accuracy_ratio': 0.7328766388976832}},
"cifar20-large_omnivores_and_herbivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 19.94140625, 'ff_frac': 0.2734375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.71484375, 'accuracy_ratio': 0.9228514702148529}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902055813936811}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9366962453830905}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.67578125, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.9294808078561854}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.20703125, 'accuracy_difference': 12.79296875, 'accuracy_ratio': 0.8720702252929774}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 93.359375, 'accuracy_difference': 6.0546875, 'accuracy_ratio': 0.9390961727274576}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.9140625, 'accuracy_ratio': 0.8808592869140712}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.65234375, 'accuracy_difference': 6.15234375, 'accuracy_ratio': 0.9383560703643232}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 18.5546875, 'accuracy_difference': 81.15234375, 'accuracy_ratio': 0.18609204793748707}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 86.81640625, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8749999118110324}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.66796875, 'accuracy_difference': 15.0390625, 'accuracy_ratio': 0.849167397693691}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824217767578223}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833658505903492}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941175472572188}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970500471013521}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.796875, 'accuracy_difference': 8.0078125, 'accuracy_ratio': 0.9197650741840082}},
"cifar20-large_natural_outdoor_scenes": {'unpruned_accuracy': 99.21875, 'target_accuracy': 19.84375, 'ff_frac': 0.328125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.3359375, 'accuracy_difference': 5.6640625, 'accuracy_ratio': 0.9433592806640719}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784523994186819}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9070226578841541}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755141039249321}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 77.1484375, 'accuracy_difference': 22.8515625, 'accuracy_ratio': 0.7714842978515702}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9656187633798021}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.82421875, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9482420926757907}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696672218259065}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9666992174436828}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 18.1640625, 'accuracy_difference': 81.0546875, 'accuracy_ratio': 0.18307084769049722}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9676786492749327}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853514639648536}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9785155271484473}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755380627249534}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9608992195541739}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 90.4296875, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9078430461145804}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.23046875, 'accuracy_ratio': 0.8869222312479483}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.58203125, 'accuracy_difference': 28.22265625, 'accuracy_ratio': 0.7172210631668915}},
"cifar20-large_carnivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 19.94140625, 'ff_frac': 0.30859375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804686519531348}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872672858999313}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9545003978824522}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 81.73828125, 'accuracy_difference': 17.96875, 'accuracy_ratio': 0.819784442756193}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 75.09765625, 'accuracy_difference': 24.90234375, 'accuracy_ratio': 0.7509764874023512}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 91.6015625, 'accuracy_difference': 7.8125, 'accuracy_ratio': 0.9214144456258946}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.984375, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.8398436660156333}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 32.03125, 'accuracy_ratio': 0.6790605973230869}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.953125, 'accuracy_difference': 22.75390625, 'accuracy_ratio': 0.7717922830249463}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 92.1875, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.9291337646227387}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.53125, 'accuracy_difference': 80.17578125, 'accuracy_ratio': 0.19588636624998637}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.640625, 'accuracy_difference': 18.359375, 'accuracy_ratio': 0.8164061683593832}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.9637963809268596}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755619746847055}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 4.98046875, 'accuracy_ratio': 0.9499999046274605}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.979350933839198}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.42578125, 'accuracy_ratio': 0.6350292905802355}},
"cifar20-insects": {'unpruned_accuracy': 100.0, 'target_accuracy': 20.0, 'ff_frac': 0.24535369873046875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9404295934570406}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.6796875, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696375129374326}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 94.43359375, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.956478637049048}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 80.46875, 'accuracy_difference': 19.23828125, 'accuracy_ratio': 0.8070518289499439}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 84.47265625, 'accuracy_difference': 15.52734375, 'accuracy_ratio': 0.8447264780273521}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 92.08984375, 'accuracy_difference': 7.32421875, 'accuracy_ratio': 0.9263260364874399}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.38671875, 'accuracy_difference': 28.61328125, 'accuracy_ratio': 0.7138671161132883}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.62109375, 'accuracy_ratio': 0.8835615553065526}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.4765625, 'accuracy_difference': 11.23046875, 'accuracy_ratio': 0.8873652391124383}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 4.98046875, 'accuracy_ratio': 0.9498030538781174}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 77.9296875, 'accuracy_difference': 21.77734375, 'accuracy_ratio': 0.7815866013374456}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 24.90234375, 'accuracy_difference': 75.09765625, 'accuracy_ratio': 0.24902341259765873}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9579666685280676}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9726561527343847}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 83.0078125, 'accuracy_difference': 16.796875, 'accuracy_ratio': 0.8317024606983053}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9481914984410464}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 73.828125, 'accuracy_difference': 25.78125, 'accuracy_ratio': 0.7411763961799382}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 86.03515625, 'accuracy_difference': 13.28125, 'accuracy_ratio': 0.8662732657754352}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 81.93359375, 'accuracy_difference': 17.87109375, 'accuracy_ratio': 0.820939252383386}},
"cifar20-household_furniture": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 19.98046875, 'ff_frac': 0.3125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.94140625, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8994139725586027}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.963760921949933}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9821957462147929}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804112630811818}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814452143554785}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9007857640074045}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833983391601661}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882582180062216}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.6796875, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696375129374326}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 2.63671875, 'accuracy_ratio': 0.9734250987414074}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813906949124317}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9541014670898532}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 19.04296875, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1906158166969114}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.71484375, 'accuracy_ratio': 0.9228514702148529}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 87.109375, 'accuracy_difference': 12.79296875, 'accuracy_ratio': 0.8719451717622819}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9764704902053155}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9842673541897964}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.993150585422094}},
"cifar20-household_electrical_devices": {'unpruned_accuracy': 100.0, 'target_accuracy': 20.0, 'ff_frac': 0.50390625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 34.5703125, 'accuracy_difference': 65.4296875, 'accuracy_ratio': 0.34570309042969094}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 22.55859375, 'accuracy_difference': 77.1484375, 'accuracy_ratio': 0.22624875301873426}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 64.6484375, 'accuracy_difference': 34.08203125, 'accuracy_ratio': 0.6547971641431952}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 42.87109375, 'accuracy_difference': 56.8359375, 'accuracy_ratio': 0.42997057391872007}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 30.859375, 'accuracy_difference': 69.140625, 'accuracy_ratio': 0.30859371914062805}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 32.6171875, 'accuracy_difference': 66.796875, 'accuracy_ratio': 0.3280942695512247}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 45.01953125, 'accuracy_difference': 54.98046875, 'accuracy_ratio': 0.4501952674804732}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 54.98046875, 'accuracy_difference': 44.82421875, 'accuracy_ratio': 0.5508805710272304}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 45.8984375, 'accuracy_difference': 53.80859375, 'accuracy_ratio': 0.460332960687468}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 80.17578125, 'accuracy_difference': 19.04296875, 'accuracy_ratio': 0.8080707846983776}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 57.6171875, 'accuracy_difference': 42.08984375, 'accuracy_ratio': 0.5778647804374598}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 47.8515625, 'accuracy_difference': 52.1484375, 'accuracy_ratio': 0.4785155771484423}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 33.984375, 'accuracy_difference': 65.91796875, 'accuracy_ratio': 0.3401759190283342}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.65234375, 'accuracy_difference': 81.34765625, 'accuracy_ratio': 0.1865234188476581}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.35546875, 'accuracy_difference': 60.44921875, 'accuracy_ratio': 0.39432481371931416}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 38.96484375, 'accuracy_difference': 60.9375, 'accuracy_ratio': 0.3900292864721418}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 59.08203125, 'accuracy_difference': 40.52734375, 'accuracy_ratio': 0.5931371953556384}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 44.43359375, 'accuracy_difference': 54.8828125, 'accuracy_ratio': 0.44739425190445287}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 41.89453125, 'accuracy_difference': 57.91015625, 'accuracy_ratio': 0.41976512428185053}},
"cifar20-fruit_and_vegetables": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 19.9609375, 'ff_frac': 0.359375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9541014670898532}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9545003978824522}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.49609375, 'accuracy_ratio': 0.9147893303874364}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.54296875, 'accuracy_ratio': 0.9345702190429781}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 80.46875, 'accuracy_difference': 18.9453125, 'accuracy_ratio': 0.8094301739826623}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 84.66796875, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8466796028320397}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814089036240002}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9725758084311824}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9625983281790661}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9578843309624334}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.2578125, 'accuracy_ratio': 0.8574217892578211}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843596277630245}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9677733407226659}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 19.53125, 'accuracy_difference': 80.2734375, 'accuracy_ratio': 0.19569469663489536}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8846528928754094}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 63.671875, 'accuracy_difference': 35.9375, 'accuracy_ratio': 0.6392156221022748}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 84.08203125, 'accuracy_difference': 15.234375, 'accuracy_ratio': 0.8466075843730416}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9549901195782894}},
"cifar20-food_containers": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 19.98046875, 'ff_frac': 0.3046875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 68.84765625, 'accuracy_difference': 31.15234375, 'accuracy_ratio': 0.6884764936523506}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 70.01953125, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7022526230062012}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 72.75390625, 'accuracy_difference': 25.9765625, 'accuracy_ratio': 0.736894089556919}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.26953125, 'accuracy_ratio': 0.48579818829996624}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.109375, 'accuracy_difference': 37.890625, 'accuracy_ratio': 0.6210936878906312}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 37.6953125, 'accuracy_difference': 61.71875, 'accuracy_ratio': 0.37917481451129564}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 51.7578125, 'accuracy_difference': 48.2421875, 'accuracy_ratio': 0.5175780732421926}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 57.32421875, 'accuracy_difference': 42.48046875, 'accuracy_ratio': 0.5743639346234178}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.73046875, 'accuracy_difference': 50.9765625, 'accuracy_ratio': 0.488736483793716}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 79.296875, 'accuracy_difference': 19.921875, 'accuracy_ratio': 0.7992125178746439}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 41.89453125, 'accuracy_difference': 57.8125, 'accuracy_ratio': 0.4201762556062208}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 54.00390625, 'accuracy_difference': 45.99609375, 'accuracy_ratio': 0.5400390084960991}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 51.85546875, 'accuracy_difference': 48.046875, 'accuracy_ratio': 0.5190615316208202}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 56.25, 'accuracy_difference': 43.75, 'accuracy_ratio': 0.5624999437500056}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 32.71484375, 'accuracy_difference': 67.08984375, 'accuracy_ratio': 0.32778861686344973}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 19.62890625, 'accuracy_difference': 80.2734375, 'accuracy_ratio': 0.19648091874912407}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 35.25390625, 'accuracy_difference': 64.35546875, 'accuracy_ratio': 0.3539215330965049}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 66.50390625, 'accuracy_difference': 32.8125, 'accuracy_ratio': 0.6696164517514999}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 57.8125, 'accuracy_difference': 41.9921875, 'accuracy_ratio': 0.5792563020392902}},
"cifar20-flowers": {'unpruned_accuracy': 99.609375, 'target_accuracy': 19.921875, 'ff_frac': 0.3125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9658202159179784}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.977472967587432}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9366962453830905}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9676786492749327}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9658202159179784}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 91.50390625, 'accuracy_difference': 7.91015625, 'accuracy_ratio': 0.9204321274535856}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 84.08203125, 'accuracy_difference': 15.91796875, 'accuracy_ratio': 0.8408202284179771}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9716241687922554}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.1171875, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9539666036374337}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9685038393948886}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.52734375, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9079333075686868}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.4921875, 'accuracy_difference': 20.5078125, 'accuracy_ratio': 0.7949217955078204}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941347978500457}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 73.2421875, 'accuracy_difference': 26.5625, 'accuracy_ratio': 0.7338551123808577}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.9648092875889823}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 18.06640625, 'accuracy_difference': 81.54296875, 'accuracy_ratio': 0.18137253081122828}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.484375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9714846612782405}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.0390625, 'accuracy_difference': 9.765625, 'accuracy_ratio': 0.9021525514868676}},
"cifar20-fish": {'unpruned_accuracy': 99.31640625, 'target_accuracy': 19.86328125, 'ff_frac': 0.28333282470703125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.4453125, 'accuracy_difference': 18.5546875, 'accuracy_ratio': 0.8144530435546956}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.84375, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9010772847499373}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 82.51953125, 'accuracy_difference': 16.2109375, 'accuracy_ratio': 0.8358060478867069}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.8359375, 'accuracy_difference': 42.87109375, 'accuracy_ratio': 0.5700293257874604}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.47265625, 'accuracy_difference': 40.52734375, 'accuracy_ratio': 0.5947265030273496}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 78.515625, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7897838105364812}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 72.16796875, 'accuracy_difference': 27.83203125, 'accuracy_ratio': 0.7216796153320384}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 69.53125, 'accuracy_difference': 30.2734375, 'accuracy_ratio': 0.6966731200202275}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 73.33984375, 'accuracy_difference': 26.3671875, 'accuracy_ratio': 0.7355533052686989}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 77.63671875, 'accuracy_difference': 21.58203125, 'accuracy_ratio': 0.7824802360964801}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 68.75, 'accuracy_difference': 30.95703125, 'accuracy_ratio': 0.689520009199952}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 65.52734375, 'accuracy_difference': 34.47265625, 'accuracy_ratio': 0.6552733719726628}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 87.890625, 'accuracy_difference': 12.01171875, 'accuracy_ratio': 0.8797653078318988}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.1875, 'accuracy_difference': 7.8125, 'accuracy_ratio': 0.9218749078125091}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 75.5859375, 'accuracy_difference': 24.21875, 'accuracy_ratio': 0.7573384759770451}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 85.64453125, 'accuracy_difference': 14.2578125, 'accuracy_ratio': 0.8572824166317502}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 72.55859375, 'accuracy_difference': 27.05078125, 'accuracy_ratio': 0.7284312994202303}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 21.09375, 'accuracy_difference': 78.22265625, 'accuracy_ratio': 0.21238935914585017}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.0625, 'accuracy_difference': 60.7421875, 'accuracy_ratio': 0.3913893932697907}},
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 19.9609375, 'ff_frac': 0.25493621826171875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.890625, 'accuracy_difference': 12.109375, 'accuracy_ratio': 0.8789061621093838}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.078125, 'accuracy_ratio': 0.949069444481184}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 87.98828125, 'accuracy_difference': 10.7421875, 'accuracy_ratio': 0.8911967445513881}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 65.33203125, 'accuracy_difference': 34.375, 'accuracy_ratio': 0.6552398951062044}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.47265625, 'accuracy_difference': 40.52734375, 'accuracy_ratio': 0.5947265030273496}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 84.5703125, 'accuracy_difference': 14.84375, 'accuracy_ratio': 0.8506875372196426}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 69.62890625, 'accuracy_difference': 30.37109375, 'accuracy_ratio': 0.6962889928711007}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 76.5625, 'accuracy_difference': 23.2421875, 'accuracy_ratio': 0.7671232108087898}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 77.1484375, 'accuracy_difference': 22.55859375, 'accuracy_ratio': 0.7737511466874462}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 73.53515625, 'accuracy_difference': 25.68359375, 'accuracy_ratio': 0.7411416575857227}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 60.64453125, 'accuracy_difference': 39.0625, 'accuracy_ratio': 0.6082271672062077}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 65.0390625, 'accuracy_difference': 34.9609375, 'accuracy_ratio': 0.650390559960944}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.2734375, 'accuracy_ratio': 0.9472139814323444}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 84.765625, 'accuracy_difference': 15.0390625, 'accuracy_ratio': 0.8493149833954459}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.91796875, 'accuracy_difference': 8.984375, 'accuracy_ratio': 0.9100683351016642}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 13.8671875, 'accuracy_ratio': 0.860784227309505}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 66.2109375, 'accuracy_difference': 33.10546875, 'accuracy_ratio': 0.6666665995411408}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 26.7578125, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.26810173438980667}},
}

# %%
# 50% neurons

data = {
"cifar20-veh2": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.0859375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.828125, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.48828120117187984}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 82.71484375, 'accuracy_difference': 16.9921875, 'accuracy_ratio': 0.8295787610686923}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990107791308568}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9531249046875095}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997052944893692}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9765624023437597}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.991185013224931}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9911416323888748}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990223828935562}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863146617804287}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009802916662922}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.609375, 'accuracy_difference': -0.29296875, 'accuracy_ratio': 1.0029497515220702}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902151649725706}},
"cifar20-veh1": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.0546875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824217767578223}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.390625, 'accuracy_ratio': 0.4946130747812156}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990175812383101}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990156473433048}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941290589052685}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.51171875, 'accuracy_difference': -0.1953125, 'accuracy_ratio': 1.0019664674519506}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}},
"cifar20-trees": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 49.365234375, 'ff_frac': 0.07421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 49.4140625, 'accuracy_ratio': 0.4995053895654284}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9404295934570406}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.8984375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9665353356562811}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997058723432536}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.51171875, 'accuracy_difference': -0.1953125, 'accuracy_ratio': 1.0019664674519506}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628179074436852}},
"cifar20-small_mammals": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.1875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.390625, 'accuracy_ratio': 0.4946130747812156}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.76953125, 'accuracy_difference': 11.23046875, 'accuracy_ratio': 0.8876952237304776}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872297631706014}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.03515625, 'accuracy_difference': 13.96484375, 'accuracy_ratio': 0.8603514764648523}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 5.078125, 'accuracy_ratio': 0.9491192786792425}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.2578125, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8952006937624377}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872046249116598}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.6640625, 'accuracy_ratio': 0.9431928534936844}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.015625, 'accuracy_difference': 8.984375, 'accuracy_ratio': 0.9101561589843841}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9716519066498971}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.948140805196068}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951123148587477}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.998039115490975}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009831833818308}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.65234375, 'accuracy_difference': 6.15234375, 'accuracy_ratio': 0.9383560703643232}},
"cifar20-reptiles": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.992164445056181}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.6328125, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.48632807636719233}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.13671875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9013670973632902}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.993150585422094}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.078125, 'accuracy_ratio': 0.949069444481184}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9404295934570406}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 90.625, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.91248761707106}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.50390625, 'accuracy_difference': 8.30078125, 'accuracy_ratio': 0.9168296537344848}},
"cifar20-people": {'unpruned_accuracy': 99.4140625, 'target_accuracy': 49.70703125, 'ff_frac': 0.21875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.9648436535156346}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.992164445056181}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 48.33984375, 'accuracy_difference': 51.07421875, 'accuracy_ratio': 0.4862474952929828}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892577135742286}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863012710398726}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872672858999313}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950786398660898}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843289904061815}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.2890625, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.9638317705802802}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863012710398726}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9794116663806327}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.2890625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9695180931380012}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.39453125, 'accuracy_ratio': 0.9559685930614639}},
"cifar20-non_insect_invertebrates": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.1875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.955078029492197}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.992164445056181}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950543007976652}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882467177311812}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.95703125, 'accuracy_difference': 19.04296875, 'accuracy_ratio': 0.8095702315429768}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941059903767648}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.73046875, 'accuracy_difference': 51.26953125, 'accuracy_ratio': 0.4873046387695361}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951027405499308}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.37109375, 'accuracy_difference': 19.62890625, 'accuracy_ratio': 0.8037108571289142}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9657533278932086}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833821107543224}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.16796875, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9754900981468764}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891837745403947}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804304301408258}},
"cifar20-medium_sized_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.21875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9940651812143674}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 82.03125, 'accuracy_difference': 17.67578125, 'accuracy_ratio': 0.8227227382499428}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 78.3203125, 'accuracy_difference': 21.6796875, 'accuracy_ratio': 0.7832030466796953}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9754419451028927}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.50390625, 'accuracy_difference': 8.49609375, 'accuracy_ratio': 0.9150389709961029}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.4853228476545405}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 11.328125, 'accuracy_ratio': 0.8863858072811883}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.703125, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.9645668319176736}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.904995012074937}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.81640625, 'accuracy_ratio': 0.881835849316415}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912022468239393}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823873771071747}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9716519066498971}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998993117112}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.91796875, 'accuracy_difference': 8.88671875, 'accuracy_ratio': 0.9109588128354379}},
"cifar20-large_omnivores_and_herbivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.0380859375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998987141546}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 49.51171875, 'accuracy_difference': 50.1953125, 'accuracy_ratio': 0.49657193844371544}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.51171875, 'accuracy_difference': -0.1953125, 'accuracy_ratio': 1.0019664674519506}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960860058716173}},
"cifar20-large_natural_outdoor_scenes": {'unpruned_accuracy': 99.21875, 'target_accuracy': 49.609375, 'ff_frac': 0.09375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998987141546}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.3828125, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9238280326171967}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.998035263066001}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 47.94921875, 'accuracy_difference': 51.26953125, 'accuracy_ratio': 0.48326766782814057}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862744107897061}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931169108208735}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784734831744768}},
"cifar20-large_carnivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.976493535756182}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9306639694336031}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941059903767648}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521483422851658}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.625, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9080233923859145}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8844269436186885}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950786398660898}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.828125, 'accuracy_difference': 50.87890625, 'accuracy_ratio': 0.4897159156249659}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8953032371046463}},
"cifar20-insects": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.05078125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.7890625, 'accuracy_ratio': 0.9121092837890716}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.5625, 'accuracy_ratio': 0.4843749515625048}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843136266728281}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.609375, 'accuracy_difference': -0.29296875, 'accuracy_ratio': 1.0029497515220702}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}},
"cifar20-household_furniture": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.08984375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990175812383101}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.8046875, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49853367443807595}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990166152415915}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.90234375, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009783732874897}},
"cifar20-household_electrical_devices": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.3828125, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9238280326171967}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.796875, 'accuracy_difference': 7.91015625, 'accuracy_ratio': 0.920665921374936}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931639631836037}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9715126724136565}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902342759765723}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872797445230471}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.979492089550791}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.76953125, 'accuracy_difference': 11.1328125, 'accuracy_ratio': 0.8885629609102178}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 60.25390625, 'accuracy_difference': 39.74609375, 'accuracy_ratio': 0.6025390022460998}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814089036240002}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 84.5703125, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.846529729536027}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.65625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9803920584390717}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998993117112}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9579255400278128}},
"cifar20-fruit_and_vegetables": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.09375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997052944893692}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9697264655273534}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990156473433048}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.14453125, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.48238742720501704}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.988269695797833}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833332346143889}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9626351046471635}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}},
"cifar20-food_containers": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.140625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804686519531348}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9518663089674754}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.37109375, 'accuracy_ratio': 0.9462889678711032}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892261495624312}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902247298152371}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.5859375, 'accuracy_ratio': 0.49364608939456545}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882351949065843}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}},
"cifar20-flowers": {'unpruned_accuracy': 99.609375, 'target_accuracy': 49.8046875, 'ff_frac': 0.1484375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891943995152195}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.46875, 'accuracy_ratio': 0.9453124054687594}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.991185013224931}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980313954740011}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9373162625061848}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.0390625, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9003905349609465}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921797638326414}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.4862744609857796}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998993117112}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598824869941618}},
"cifar20-fish": {'unpruned_accuracy': 99.31640625, 'target_accuracy': 49.658203125, 'ff_frac': 0.078125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902342759765723}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823701267436816}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.23046875, 'accuracy_difference': 13.76953125, 'accuracy_ratio': 0.8623046012695399}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941059903767648}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980313954740011}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 49.609375, 'accuracy_difference': 49.70703125, 'accuracy_ratio': 0.49950830762079573}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 87.40234375, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8757337674411567}},
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833983391601661}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.91015625, 'accuracy_difference': 17.08984375, 'accuracy_ratio': 0.829101479589852}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.998035263066001}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.30859375, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.9130858461914153}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9005904604129299}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.96875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9324191033499352}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921874007812599}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.01953125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9567354002264454}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.4853228476545405}},
}

# %%
# Target 10% accuracy
data = {
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 10.0, 'ff_frac': 0.421875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.2109375, 'accuracy_ratio': 0.08610566651935396}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 44.140625, 'accuracy_difference': 55.17578125, 'accuracy_ratio': 0.4444443996940939}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 20.99609375, 'accuracy_ratio': 0.7892156070434527}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 75.29296875, 'accuracy_difference': 24.609375, 'accuracy_ratio': 0.7536656137093266}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.6796875, 'accuracy_difference': 28.125, 'accuracy_ratio': 0.718199536650066}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8662108508789149}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.8671875, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8895404779189199}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 63.76953125, 'accuracy_difference': 36.23046875, 'accuracy_ratio': 0.6376952487304751}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 59.86328125, 'accuracy_difference': 39.84375, 'accuracy_ratio': 0.6003917125562083}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.10546875, 'accuracy_difference': 16.89453125, 'accuracy_ratio': 0.8310546043945395}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 31.4453125, 'accuracy_ratio': 0.6830707972968015}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.96484375, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6415278494687053}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 61.9140625, 'accuracy_difference': 37.890625, 'accuracy_ratio': 0.6203521883326183}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.01171875, 'accuracy_difference': 37.98828125, 'accuracy_ratio': 0.6201171254882875}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 71.875, 'accuracy_difference': 27.5390625, 'accuracy_ratio': 0.7229861748194653}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.5234375, 'accuracy_difference': 63.4765625, 'accuracy_ratio': 0.36523433847656617}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 33.69140625, 'accuracy_difference': 66.015625, 'accuracy_ratio': 0.3379039817812265}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7883283078884088}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 19.7265625, 'accuracy_ratio': 0.8021546697936942}},
"cifar20-fish": {'unpruned_accuracy': 99.31640625, 'target_accuracy': 10.0, 'ff_frac': 0.421875, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.9453125, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1898238557358485}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 9.27734375, 'accuracy_difference': 90.0390625, 'accuracy_ratio': 0.09341198666136928}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 57.2265625, 'accuracy_difference': 42.3828125, 'accuracy_ratio': 0.574509746245296}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 74.0234375, 'accuracy_difference': 25.87890625, 'accuracy_ratio': 0.7409578925961992}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7025439609192743}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.37109375, 'accuracy_difference': 19.62890625, 'accuracy_ratio': 0.8037108571289142}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.8359375, 'accuracy_difference': 18.06640625, 'accuracy_ratio': 0.8191592532923679}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.44140625, 'accuracy_difference': 47.55859375, 'accuracy_ratio': 0.524414010058599}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.93359375, 'accuracy_difference': 42.7734375, 'accuracy_ratio': 0.5710087576187103}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 20.01953125, 'accuracy_ratio': 0.7998046075195392}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 71.97265625, 'accuracy_difference': 27.24609375, 'accuracy_ratio': 0.7253936276768627}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.88671875, 'accuracy_difference': 40.8203125, 'accuracy_ratio': 0.5905973942437089}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4814089537218426}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.2890625, 'accuracy_difference': 53.7109375, 'accuracy_ratio': 0.46289057871094214}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 63.671875, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6404714483455046}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.6875, 'accuracy_difference': 70.3125, 'accuracy_ratio': 0.296874970312503}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.8125, 'accuracy_difference': 66.89453125, 'accuracy_ratio': 0.3290890952999771}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 69.82421875, 'accuracy_difference': 28.90625, 'accuracy_ratio': 0.7072205020579827}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.3359375, 'accuracy_difference': 30.37109375, 'accuracy_ratio': 0.6953966001874516}},
"cifar20-flowers": {'unpruned_accuracy': 99.609375, 'target_accuracy': 10.0, 'ff_frac': 0.375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 90.625, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.91248761707106}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 89.94140625, 'accuracy_ratio': 0.0970588137854681}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 7.421875, 'accuracy_ratio': 0.925708607240898}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.87109375, 'accuracy_difference': 31.93359375, 'accuracy_ratio': 0.6800390708062614}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9707030279296972}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824045937456203}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.19140625, 'accuracy_difference': 28.80859375, 'accuracy_ratio': 0.7119139913086009}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.375, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8462291021999412}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814452143554785}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9527558094860287}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.74609375, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9000978529186874}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9442269112633701}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.46484375, 'accuracy_difference': 23.53515625, 'accuracy_ratio': 0.7646483610351639}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 83.3984375, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.838899719151934}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.52734375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.9052733469726653}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.904995012074937}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9070226578841541}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9480900126499341}},
"cifar20-food_containers": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 10.0, 'ff_frac': 0.484375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.15625, 'accuracy_ratio': 0.14677102247617152}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.194690245883696}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 27.9296875, 'accuracy_difference': 71.6796875, 'accuracy_ratio': 0.2803921287135745}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 8.984375, 'accuracy_difference': 90.91796875, 'accuracy_ratio': 0.0899315648005941}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 13.76953125, 'accuracy_difference': 86.03515625, 'accuracy_ratio': 0.13796476112760123}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 25.0, 'accuracy_difference': 75.0, 'accuracy_ratio': 0.24999997500000248}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 26.85546875, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.2688171773930802}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.32421875, 'accuracy_difference': 67.67578125, 'accuracy_ratio': 0.3232421551757845}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 17.578125, 'accuracy_difference': 82.12890625, 'accuracy_ratio': 0.17629772962498774}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.71484375, 'accuracy_difference': 67.28515625, 'accuracy_ratio': 0.3271484047851595}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 68.9453125, 'accuracy_difference': 30.2734375, 'accuracy_ratio': 0.6948818197284465}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.140625, 'accuracy_difference': 80.56640625, 'accuracy_ratio': 0.19196863892498664}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 28.90625, 'accuracy_difference': 70.8984375, 'accuracy_ratio': 0.2896281510196451}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.01953125, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.20019529248047074}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 13.28125, 'accuracy_difference': 86.1328125, 'accuracy_ratio': 0.13359527143403163}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.21484375, 'accuracy_difference': 79.78515625, 'accuracy_ratio': 0.20214841728515826}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 12.40234375, 'accuracy_difference': 87.3046875, 'accuracy_ratio': 0.12438784256874134}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 44.921875, 'accuracy_difference': 53.80859375, 'accuracy_ratio': 0.4549950083170239}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.16015625, 'accuracy_difference': 85.546875, 'accuracy_ratio': 0.14201761553124012}},
"cifar20-fruit_and_vegetables": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 10.0, 'ff_frac': 0.5, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 60.05859375, 'accuracy_ratio': 0.3982387076520121}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 23.2421875, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23402160868848304}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 11.23046875, 'accuracy_difference': 88.37890625, 'accuracy_ratio': 0.11274508672049326}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 36.03515625, 'accuracy_difference': 63.8671875, 'accuracy_ratio': 0.3607037762110785}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 9.47265625, 'accuracy_difference': 90.33203125, 'accuracy_ratio': 0.09491192786792425}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.33984375, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.4833983891601611}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 55.6640625, 'accuracy_difference': 44.23828125, 'accuracy_ratio': 0.5571846949602025}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.25, 'accuracy_difference': 68.75, 'accuracy_ratio': 0.31249996875000313}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 59.9609375, 'accuracy_ratio': 0.39862875531872227}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 67.67578125, 'accuracy_difference': 32.32421875, 'accuracy_ratio': 0.6767577448242255}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 75.9765625, 'accuracy_difference': 23.2421875, 'accuracy_ratio': 0.7657479543183164}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.2265625, 'accuracy_difference': 67.48046875, 'accuracy_ratio': 0.3232125043124775}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 38.8671875, 'accuracy_difference': 60.9375, 'accuracy_ratio': 0.38943244630344176}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.78515625, 'accuracy_difference': 70.21484375, 'accuracy_ratio': 0.2978515327148467}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 80.95703125, 'accuracy_ratio': 0.18565813456641161}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 30.56640625, 'accuracy_difference': 69.43359375, 'accuracy_ratio': 0.3056640319335968}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 11.62109375, 'accuracy_difference': 88.0859375, 'accuracy_ratio': 0.1165523879187419}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 61.5234375, 'accuracy_difference': 37.20703125, 'accuracy_ratio': 0.6231453374776631}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 24.12109375, 'accuracy_difference': 75.5859375, 'accuracy_ratio': 0.2419196623187332}},
"cifar20-veh1": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 10.0, 'ff_frac': 0.498046875, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.0, 'accuracy_difference': 99.70703125, 'accuracy_ratio': 0.0}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 8.203125, 'accuracy_difference': 90.52734375, 'accuracy_ratio': 0.08308604499702175}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 2.24609375, 'accuracy_difference': 97.4609375, 'accuracy_ratio': 0.022526932118748434}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 0.1953125, 'accuracy_difference': 99.8046875, 'accuracy_ratio': 0.0019531248046875194}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 5.46875, 'accuracy_difference': 93.9453125, 'accuracy_ratio': 0.055009817649307145}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 6.25, 'accuracy_difference': 93.75, 'accuracy_ratio': 0.06249999375000062}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 2.83203125, 'accuracy_difference': 96.97265625, 'accuracy_ratio': 0.028375731012059827}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.29296875, 'accuracy_difference': 99.4140625, 'accuracy_ratio': 0.0029382954937497954}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 48.14453125, 'accuracy_difference': 51.07421875, 'accuracy_ratio': 0.48523617156674803}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 7.12890625, 'accuracy_difference': 92.87109375, 'accuracy_ratio': 0.07128905537109446}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.9765625, 'accuracy_difference': 98.73046875, 'accuracy_ratio': 0.00979431831249932}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 15.4296875, 'accuracy_difference': 84.5703125, 'accuracy_ratio': 0.15429685957031403}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 11.03515625, 'accuracy_difference': 88.8671875, 'accuracy_ratio': 0.1104594219833384}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.10546875, 'accuracy_difference': 91.89453125, 'accuracy_ratio': 0.08105467939453206}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.06640625, 'accuracy_difference': 81.73828125, 'accuracy_ratio': 0.1810175943872782}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 15.234375, 'accuracy_difference': 84.66796875, 'accuracy_ratio': 0.15249265335752912}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 22.4609375, 'accuracy_difference': 77.1484375, 'accuracy_ratio': 0.2254901734409865}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 7.6171875, 'accuracy_difference': 91.69921875, 'accuracy_ratio': 0.07669615746933478}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 4.19921875, 'accuracy_difference': 95.60546875, 'accuracy_ratio': 0.0420743597765025}},
"cifar20-veh2": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 10.0, 'ff_frac': 0.5104141235351562, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 10.7421875, 'accuracy_difference': 88.96484375, 'accuracy_ratio': 0.1077375014374925}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 37.98828125, 'accuracy_difference': 60.7421875, 'accuracy_ratio': 0.38476751790287456}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 29.6875, 'accuracy_difference': 70.01953125, 'accuracy_ratio': 0.2977472766999793}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.5078125, 'accuracy_difference': 79.4921875, 'accuracy_ratio': 0.20507810449218955}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 41.69921875, 'accuracy_difference': 57.71484375, 'accuracy_ratio': 0.419449859575967}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.421875, 'accuracy_difference': 67.578125, 'accuracy_ratio': 0.32421871757812826}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 45.1171875, 'accuracy_difference': 54.6875, 'accuracy_ratio': 0.45205474922660827}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 20.01953125, 'accuracy_difference': 79.6875, 'accuracy_ratio': 0.20078352540623604}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 54.00390625, 'accuracy_difference': 45.21484375, 'accuracy_ratio': 0.5442912837249729}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.15234375, 'accuracy_difference': 68.84765625, 'accuracy_ratio': 0.31152340634765935}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 35.83984375, 'accuracy_difference': 63.8671875, 'accuracy_ratio': 0.359451482068725}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 53.125, 'accuracy_difference': 46.875, 'accuracy_ratio': 0.5312499468750053}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 40.91796875, 'accuracy_difference': 58.984375, 'accuracy_ratio': 0.40957962664618397}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 50.87890625, 'accuracy_difference': 49.12109375, 'accuracy_ratio': 0.5087890116210988}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 42.08984375, 'accuracy_difference': 57.71484375, 'accuracy_ratio': 0.4217220712481995}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 42.48046875, 'accuracy_difference': 57.421875, 'accuracy_ratio': 0.4252198987854177}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 41.2109375, 'accuracy_difference': 58.3984375, 'accuracy_ratio': 0.4137254486612883}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 38.28125, 'accuracy_difference': 61.03515625, 'accuracy_ratio': 0.3854473554869133}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 27.9296875, 'accuracy_difference': 71.875, 'accuracy_ratio': 0.2798434161879004}},
}

# %%
cifar20_subsets_right = [ "aquatic_mammals", "fish", "flowers", "food_containers", "fruit_and_vegetables", "household_electrical_devices", "household_furniture", "insects", "large_carnivores", "large_man-made_outdoor_things", "large_natural_outdoor_scenes", "large_omnivores_and_herbivores", "medium_sized_mammals", "non_insect_invertebrates", "people", "reptiles", "small_mammals", "trees", "veh1", "veh2" ]
cifar20_subsets_wrong = [ "aquatic_mammals", "fish", "flowers", "food_containers", "fruit_and_vegetables", "household_electrical_devices", "household_furniture", "insects", "large_carnivores", "large_natural_outdoor_scenes", "large_omnivores_and_herbivores", "medium_sized_mammals", "non_insect_invertebrates", "people", "reptiles", "small_mammals", "trees", "veh1", "veh2" ]

cifar20_wrong_to_right = {
    "cifar20-"+a: "cifar20-"+b for a,b in zip(cifar20_subsets_wrong, cifar20_subsets_right[:-1])
}

# Target 50% accuracy
orig_data = {
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.4853228476545405}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.01953125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9567354002264454}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921874007812599}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.96875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9324191033499352}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9005904604129299}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.30859375, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.9130858461914153}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.998035263066001}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.91015625, 'accuracy_difference': 17.08984375, 'accuracy_ratio': 0.829101479589852}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-fish": {'unpruned_accuracy': 99.31640625, 'target_accuracy': 49.658203125, 'ff_frac': 0.09375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 84.47265625, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8463795629459224}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 47.75390625, 'accuracy_difference': 51.5625, 'accuracy_ratio': 0.4808259102885219}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990223828935562}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960628917353935}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921413540321466}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.83984375, 'accuracy_difference': 14.16015625, 'accuracy_ratio': 0.8583983516601648}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-flowers": {'unpruned_accuracy': 99.609375, 'target_accuracy': 49.8046875, 'ff_frac': 0.1484375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598824869941618}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998993117112}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.4862744609857796}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921797638326414}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.0390625, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9003905349609465}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9373162625061848}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980313954740011}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.991185013224931}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.46875, 'accuracy_ratio': 0.9453124054687594}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891943995152195}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}},
"cifar20-food_containers": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.140625, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882351949065843}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.5859375, 'accuracy_ratio': 0.49364608939456545}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902247298152371}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892261495624312}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.37109375, 'accuracy_ratio': 0.9462889678711032}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9518663089674754}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-fruit_and_vegetables": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.09375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9626351046471635}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833332346143889}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.988269695797833}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.14453125, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.48238742720501704}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990156473433048}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9697264655273534}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997052944893692}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-household_electrical_devices": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.328125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 92.7734375, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.929549809015753}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813175019794373}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9568626490365341}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 22.0703125, 'accuracy_ratio': 0.7790810559355815}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.359375, 'accuracy_difference': 6.4453125, 'accuracy_ratio': 0.9354206499147998}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 47.94921875, 'accuracy_difference': 52.05078125, 'accuracy_ratio': 0.479492139550786}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 85.546875, 'accuracy_difference': 14.35546875, 'accuracy_ratio': 0.8563048996230481}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882467177311812}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804686519531348}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9881888767809636}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.992164445056181}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804304301408258}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.12890625, 'accuracy_ratio': 0.928290672832058}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9697264655273534}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862878540686814}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901087028811758}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.62109375, 'accuracy_ratio': 0.8834475117874385}},
"cifar20-household_furniture": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.08984375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.90234375, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009783732874897}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990166152415915}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.8046875, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49853367443807595}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990175812383101}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}},
"cifar20-insects": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.05078125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.609375, 'accuracy_difference': -0.29296875, 'accuracy_ratio': 1.0029497515220702}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843136266728281}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.5625, 'accuracy_ratio': 0.4843749515625048}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.7890625, 'accuracy_ratio': 0.9121092837890716}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-large_carnivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8953032371046463}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.828125, 'accuracy_difference': 50.87890625, 'accuracy_ratio': 0.4897159156249659}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950786398660898}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8844269436186885}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.625, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9080233923859145}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521483422851658}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941059903767648}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9306639694336031}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.976493535756182}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}},
"cifar20-non_insect_invertebrates": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853084222374314}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9910978224644738}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.977472967587432}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 75.68359375, 'accuracy_difference': 24.31640625, 'accuracy_ratio': 0.7568358618164138}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862474449982923}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 42.3828125, 'accuracy_difference': 57.6171875, 'accuracy_ratio': 0.42382808261719174}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960628917353935}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882467177311812}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 77.24609375, 'accuracy_difference': 22.75390625, 'accuracy_ratio': 0.7724608602539139}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.69921875, 'accuracy_difference': 8.10546875, 'accuracy_ratio': 0.9187866007008337}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628542535715781}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9578430410949731}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9724679453483602}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.75, 'accuracy_difference': 6.0546875, 'accuracy_ratio': 0.9393345438474977}},
#"cifar20-people": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.4765625, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 28.3203125, 'accuracy_difference': 71.38671875, 'accuracy_ratio': 0.28403523106248024}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 66.11328125, 'accuracy_difference': 32.6171875, 'accuracy_ratio': 0.6696339578926634}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 80.37109375, 'accuracy_ratio': 0.1939275025874865}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 26.85546875, 'accuracy_difference': 73.14453125, 'accuracy_ratio': 0.2685546606445339}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 4.8828125, 'accuracy_difference': 94.53125, 'accuracy_ratio': 0.04911590861545281}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.828125, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.48828120117187984}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 30.2734375, 'accuracy_difference': 69.53125, 'accuracy_ratio': 0.3033267797840878}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 29.1015625, 'accuracy_difference': 70.60546875, 'accuracy_ratio': 0.2918706857124797}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 82.6171875, 'accuracy_difference': 16.6015625, 'accuracy_ratio': 0.8326770814309713}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 65.52734375, 'accuracy_difference': 34.47265625, 'accuracy_ratio': 0.6552733719726628}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 30.859375, 'accuracy_difference': 68.84765625, 'accuracy_ratio': 0.3095004586749785}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.14453125, 'accuracy_difference': 51.85546875, 'accuracy_ratio': 0.4814452643554735}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 44.7265625, 'accuracy_difference': 55.17578125, 'accuracy_ratio': 0.4477027899855663}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.3984375, 'accuracy_difference': 41.6015625, 'accuracy_ratio': 0.5839843166015684}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 35.7421875, 'accuracy_difference': 64.0625, 'accuracy_ratio': 0.3581212948418585}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 53.7109375, 'accuracy_difference': 46.19140625, 'accuracy_ratio': 0.5376343547861604}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 38.0859375, 'accuracy_difference': 61.5234375, 'accuracy_ratio': 0.38235290279123796}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 38.8671875, 'accuracy_difference': 60.44921875, 'accuracy_ratio': 0.3913470599076313}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 16.796875, 'accuracy_difference': 83.0078125, 'accuracy_ratio': 0.16829743910601}},
"cifar20-people": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950543007976652}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931438768874309}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9707030279296972}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 42.7734375, 'accuracy_difference': 56.640625, 'accuracy_ratio': 0.43025535947136656}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863280263671973}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872797445230471}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921258842581786}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687499031250096}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628542535715781}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931639631836037}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823873771071747}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9617646093287294}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9665682409276422}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.84765625, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9403130173306722}},
"cifar20-large_omnivores_and_herbivores": {'unpruned_accuracy': 99.21875, 'target_accuracy': 49.609375, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 93.5546875, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9475765607993671}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9441722853249344}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.13671875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9013670973632902}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9528486271397845}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8955077229492276}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.2734375, 'accuracy_ratio': 0.9471623317128935}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 20.8984375, 'accuracy_difference': 78.80859375, 'accuracy_ratio': 0.20959841188748543}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 87.890625, 'accuracy_difference': 11.328125, 'accuracy_ratio': 0.8858266823733737}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921874007812599}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.328125, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8658177388249397}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863280263671973}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951123148587477}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872797445230471}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951123148587477}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960783313740968}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970500471013521}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.34765625, 'accuracy_ratio': 0.9363991233979743}},
"cifar20-medium_sized_mammals": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951027405499308}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9910978224644738}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 21.09375, 'accuracy_ratio': 0.7884426241561951}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.2421875, 'accuracy_difference': 26.7578125, 'accuracy_ratio': 0.7324218017578198}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9666010815521112}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.94140625, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8994139725586027}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 41.30859375, 'accuracy_difference': 58.49609375, 'accuracy_ratio': 0.4138942833828037}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.5234375, 'accuracy_difference': 13.18359375, 'accuracy_ratio': 0.8677766024874396}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9616140763097624}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 87.109375, 'accuracy_difference': 12.59765625, 'accuracy_ratio': 0.8736531934749392}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 84.86328125, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8486327276367273}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824045937456203}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9774950096913023}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9608992195541739}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941001948909931}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 87.6953125, 'accuracy_difference': 12.109375, 'accuracy_ratio': 0.8786691878906802}},
#"cifar20-reptiles": {'unpruned_accuracy': 99.4140625, 'target_accuracy': 49.70703125, 'ff_frac': 0.455078125, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 35.15625, 'accuracy_difference': 64.55078125, 'accuracy_ratio': 0.3525954592499755}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 57.71484375, 'accuracy_difference': 41.015625, 'accuracy_ratio': 0.5845696737290459}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 81.25, 'accuracy_ratio': 0.18511261610623714}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 1.66015625, 'accuracy_difference': 98.33984375, 'accuracy_ratio': 0.016601560839843914}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.4833005407760556}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 12.109375, 'accuracy_difference': 87.890625, 'accuracy_ratio': 0.1210937378906262}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 37.01171875, 'accuracy_difference': 62.79296875, 'accuracy_ratio': 0.3708414501231267}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 42.1875, 'accuracy_difference': 57.51953125, 'accuracy_ratio': 0.4231145510999706}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 82.8125, 'accuracy_difference': 16.40625, 'accuracy_ratio': 0.8346455851695788}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 68.65234375, 'accuracy_difference': 31.34765625, 'accuracy_ratio': 0.6865233688476631}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 43.84765625, 'accuracy_difference': 55.859375, 'accuracy_ratio': 0.4397648922312194}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.15234375, 'accuracy_difference': 68.84765625, 'accuracy_ratio': 0.31152340634765935}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 61.42578125, 'accuracy_difference': 38.4765625, 'accuracy_ratio': 0.614858198473627}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 53.125, 'accuracy_difference': 46.875, 'accuracy_ratio': 0.5312499468750053}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 46.2890625, 'accuracy_difference': 53.515625, 'accuracy_ratio': 0.463796431024702}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 56.25, 'accuracy_difference': 43.65234375, 'accuracy_ratio': 0.5630497970124152}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 49.8046875, 'accuracy_difference': 49.8046875, 'accuracy_ratio': 0.4999999498039266}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 9.5703125, 'accuracy_difference': 89.74609375, 'accuracy_ratio': 0.09636183887172832}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 17.48046875, 'accuracy_difference': 82.32421875, 'accuracy_ratio': 0.17514675348823136}},
"cifar20-reptiles": {'unpruned_accuracy': 99.4140625, 'target_accuracy': 49.70703125, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901087028811758}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9549460354686836}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 28.41796875, 'accuracy_difference': 71.58203125, 'accuracy_ratio': 0.2841796590820341}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813358541367471}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.59375, 'accuracy_difference': 16.40625, 'accuracy_ratio': 0.8359374164062583}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9745595892417789}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.72265625, 'accuracy_difference': 8.984375, 'accuracy_ratio': 0.9098921712311867}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9881888767809636}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755141039249321}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.0078125, 'accuracy_difference': 16.9921875, 'accuracy_ratio': 0.8300780419921958}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970673488761519}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843443240735237}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9657868045976844}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862744107897061}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 78.125, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7866272560957414}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 75.87890625, 'accuracy_difference': 23.92578125, 'accuracy_ratio': 0.7602738964265685}},
#"cifar20-small_mammals": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.40625, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8844269436186885}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 91.796875, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9297724083000053}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 7.03125, 'accuracy_difference': 92.67578125, 'accuracy_ratio': 0.0705190918499951}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.2421875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4824218267578173}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 75.390625, 'accuracy_difference': 24.0234375, 'accuracy_ratio': 0.7583496290225913}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 56.93359375, 'accuracy_difference': 43.06640625, 'accuracy_ratio': 0.5693358805664119}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 52.05078125, 'accuracy_difference': 47.75390625, 'accuracy_ratio': 0.5215263665319961}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 72.4609375, 'accuracy_difference': 27.24609375, 'accuracy_ratio': 0.7267384187874495}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 91.50390625, 'accuracy_difference': 7.71484375, 'accuracy_ratio': 0.9222440015376124}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.9638670911132908}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 67.48046875, 'accuracy_difference': 32.2265625, 'accuracy_ratio': 0.6767873953937029}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.74609375, 'accuracy_difference': 35.25390625, 'accuracy_ratio': 0.6474608727539127}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.76953125, 'accuracy_difference': 11.1328125, 'accuracy_ratio': 0.8885629609102178}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687499031250096}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 75.9765625, 'accuracy_difference': 23.828125, 'accuracy_ratio': 0.761252369909743}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.52734375, 'accuracy_difference': 9.375, 'accuracy_ratio': 0.9061582670668558}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 86.5234375, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8686273637770175}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 85.25390625, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8584069932144778}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 55.6640625, 'accuracy_difference': 44.140625, 'accuracy_ratio': 0.5577298854094518}},
"cifar20-small_mammals": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9920869420477716}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 38.0859375, 'accuracy_difference': 61.62109375, 'accuracy_ratio': 0.3819784141874734}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.71484375, 'accuracy_difference': 17.28515625, 'accuracy_ratio': 0.8271483547851645}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.2890625, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9685657178967293}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.296875, 'accuracy_difference': 20.703125, 'accuracy_ratio': 0.7929686707031329}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 87.890625, 'accuracy_difference': 11.9140625, 'accuracy_ratio': 0.8806261348570291}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 87.3046875, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8756120571374391}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 97.16796875, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9793306099572299}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.6484375, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8991184210874374}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.4765625, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8847655365234464}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696968726324928}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.6015625, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9178081272176593}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941175472572188}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901670586105145}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 83.3984375, 'accuracy_difference': 16.40625, 'accuracy_ratio': 0.8356163546310031}},
#"cifar20-trees": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.431640625, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 34.1796875, 'accuracy_difference': 65.52734375, 'accuracy_ratio': 0.34280114093747616}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 0.5859375, 'accuracy_difference': 98.14453125, 'accuracy_ratio': 0.005934717499787268}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.92578125, 'accuracy_difference': 50.78125, 'accuracy_ratio': 0.49069534745621585}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.640625, 'accuracy_difference': 68.359375, 'accuracy_ratio': 0.31640621835937816}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 60.15625, 'accuracy_difference': 39.2578125, 'accuracy_ratio': 0.6051079941423786}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.875, 'accuracy_difference': 53.125, 'accuracy_ratio': 0.46874995312500467}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 51.85546875, 'accuracy_difference': 47.94921875, 'accuracy_ratio': 0.5195694195656472}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 31.640625, 'accuracy_difference': 68.06640625, 'accuracy_ratio': 0.3173359133249779}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 43.5546875, 'accuracy_difference': 55.6640625, 'accuracy_ratio': 0.43897633370947187}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 40.234375, 'accuracy_difference': 59.765625, 'accuracy_ratio': 0.402343709765629}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 42.1875, 'accuracy_difference': 57.51953125, 'accuracy_ratio': 0.4231145510999706}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 65.8203125, 'accuracy_difference': 34.1796875, 'accuracy_ratio': 0.658203059179694}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 64.6484375, 'accuracy_difference': 35.25390625, 'accuracy_ratio': 0.6471162597607967}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.55078125, 'accuracy_difference': 35.44921875, 'accuracy_ratio': 0.6455077479492252}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 62.3046875, 'accuracy_difference': 37.5, 'accuracy_ratio': 0.6242660822653162}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 72.75390625, 'accuracy_difference': 27.1484375, 'accuracy_ratio': 0.7282501714830718}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 55.95703125, 'accuracy_difference': 43.65234375, 'accuracy_ratio': 0.5617646494855881}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 40.72265625, 'accuracy_difference': 58.59375, 'accuracy_ratio': 0.4100294572399052}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.453125, 'accuracy_difference': 60.3515625, 'accuracy_ratio': 0.39530328720248864}},
"cifar20-trees": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 17.578125, 'accuracy_difference': 81.15234375, 'accuracy_ratio': 0.17804152499361803}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813906949124317}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9677733407226659}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891943995152195}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.94140625, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8994139725586027}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9726026422754299}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598431946249333}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 78.02734375, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7864172435736951}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.96484375, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8896483485351652}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9541014670898532}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9794519566576513}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598038252118513}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891837745403947}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.84375, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9001956045205186}},
#"cifar20-veh1": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 49.365234375, 'ff_frac': 0.42578125, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.68359375, 'accuracy_difference': 99.0234375, 'accuracy_ratio': 0.006856022818749523}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 48.6328125, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49258155248234325}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 34.27734375, 'accuracy_difference': 65.4296875, 'accuracy_ratio': 0.3437805727687261}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 19.921875, 'accuracy_difference': 80.078125, 'accuracy_ratio': 0.199218730078127}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 33.0078125, 'accuracy_difference': 66.40625, 'accuracy_ratio': 0.332023542240461}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 45.21484375, 'accuracy_difference': 54.78515625, 'accuracy_ratio': 0.45214839228516074}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 42.96875, 'accuracy_difference': 56.8359375, 'accuracy_ratio': 0.4305283325967698}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 22.55859375, 'accuracy_difference': 77.1484375, 'accuracy_ratio': 0.22624875301873426}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 68.75, 'accuracy_difference': 30.46875, 'accuracy_ratio': 0.692913315989839}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 34.1796875, 'accuracy_difference': 65.8203125, 'accuracy_ratio': 0.3417968408203159}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 36.62109375, 'accuracy_difference': 63.0859375, 'accuracy_ratio': 0.3672869367187245}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 51.7578125, 'accuracy_difference': 48.2421875, 'accuracy_ratio': 0.5175780732421926}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 43.45703125, 'accuracy_difference': 56.4453125, 'accuracy_ratio': 0.43499506887243883}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 47.4609375, 'accuracy_difference': 52.5390625, 'accuracy_ratio': 0.4746093275390672}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 53.80859375, 'accuracy_difference': 45.99609375, 'accuracy_ratio': 0.5391388892291367}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 55.95703125, 'accuracy_difference': 43.9453125, 'accuracy_ratio': 0.5601172459863089}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 64.6484375, 'accuracy_difference': 34.9609375, 'accuracy_ratio': 0.6490195426866655}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 47.8515625, 'accuracy_difference': 51.46484375, 'accuracy_ratio': 0.48180919435864156}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 37.5, 'accuracy_difference': 62.3046875, 'accuracy_ratio': 0.3757338175389991}},
"cifar20-veh1": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 49.365234375, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 24.51171875, 'accuracy_difference': 75.1953125, 'accuracy_ratio': 0.2458373896437329}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9831848657980907}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.63671875, 'accuracy_ratio': 0.9736327151367284}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.8828125, 'accuracy_ratio': 0.9508839907951663}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9775389647461035}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892366914893961}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.963760921949933}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9753936024800148}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8662108508789149}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.964740353781183}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.37109375, 'accuracy_ratio': 0.9462889678711032}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912022468239393}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9609374039062596}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9774950096913023}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9745844576760034}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931371551987797}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9911503426806341}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696672218259065}},
#"cifar20-veh2": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.390625, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.92578125, 'accuracy_difference': 50.78125, 'accuracy_ratio': 0.49069534745621585}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 20.1171875, 'accuracy_ratio': 0.7962412645547918}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 78.90625, 'accuracy_difference': 20.80078125, 'accuracy_ratio': 0.791380919649945}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.8828125, 'accuracy_ratio': 0.7011718048828195}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 84.27734375, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8477405827027155}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.78515625, 'accuracy_difference': 20.21484375, 'accuracy_ratio': 0.7978514827148517}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 86.9140625, 'accuracy_difference': 12.890625, 'accuracy_ratio': 0.8708414000252843}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.328125, 'accuracy_ratio': 0.6356512584812057}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 79.8828125, 'accuracy_difference': 19.3359375, 'accuracy_ratio': 0.8051180290904664}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.60546875, 'accuracy_difference': 29.39453125, 'accuracy_ratio': 0.7060546168945383}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 83.203125, 'accuracy_difference': 16.50390625, 'accuracy_ratio': 0.834475920224942}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.96484375, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8896483485351652}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 82.8125, 'accuracy_difference': 17.08984375, 'accuracy_ratio': 0.828934423379389}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.11328125, 'accuracy_difference': 8.88671875, 'accuracy_ratio': 0.9111327213867279}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 88.28125, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.884540028789727}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.640625, 'accuracy_difference': 18.26171875, 'accuracy_ratio': 0.8172042192749638}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 84.47265625, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8480391305497971}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 85.64453125, 'accuracy_difference': 13.671875, 'accuracy_ratio': 0.8623401294949564}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 74.0234375, 'accuracy_difference': 25.78125, 'accuracy_ratio': 0.7416829002462534}},
"cifar20-veh2": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.328125, 'accuracy_ratio': 0.6356512584812057}, 'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9762610287150055}, 'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755141039249321}, 'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.0625, 'accuracy_difference': 10.9375, 'accuracy_ratio': 0.8906249109375088}, 'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862474449982923}, 'cifar20-people': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.859375, 'accuracy_ratio': 0.9414061558593844}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9441722853249344}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 91.015625, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9173227421910937}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.28125, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8828124117187588}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784523994186819}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853514639648536}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.63671875, 'accuracy_ratio': 0.9736069406673014}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9550341175019612}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921567631403406}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980333311714719}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9579255400278128}},
}

data = {
    'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.3671875, 'accuracy_ratio': 0.4853228476545405}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.01953125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9567354002264454}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921874007812599}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.96875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9324191033499352}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9005904604129299}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.30859375, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.9130858461914153}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.998035263066001}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.91015625, 'accuracy_difference': 17.08984375, 'accuracy_ratio': 0.829101479589852}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'target_accuracy': 49.658203125, 'ff_frac': 0.09375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 84.47265625, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8463795629459224}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 47.75390625, 'accuracy_difference': 51.5625, 'accuracy_ratio': 0.4808259102885219}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990223828935562}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960628917353935}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921413540321466}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.83984375, 'accuracy_difference': 14.16015625, 'accuracy_ratio': 0.8583983516601648}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'target_accuracy': 49.8046875, 'ff_frac': 0.1484375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598824869941618}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998993117112}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.4862744609857796}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921797638326414}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.0390625, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9003905349609465}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.25, 'accuracy_ratio': 0.9373162625061848}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980313954740011}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.991185013224931}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.46875, 'accuracy_ratio': 0.9453124054687594}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891943995152195}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960434203809632}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}} ,
    'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.140625, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.4375, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882351949065843}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.5859375, 'accuracy_ratio': 0.49364608939456545}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902247298152371}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912108383789161}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892261495624312}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970471436046973}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.37109375, 'accuracy_ratio': 0.9462889678711032}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9518663089674754}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997032539964261}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.09375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9626351046471635}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833332346143889}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.988269695797833}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.14453125, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.48238742720501704}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990156473433048}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9697264655273534}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997052944893692}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.328125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 92.7734375, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.929549809015753}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813175019794373}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9568626490365341}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 22.0703125, 'accuracy_ratio': 0.7790810559355815}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.359375, 'accuracy_difference': 6.4453125, 'accuracy_ratio': 0.9354206499147998}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 47.94921875, 'accuracy_difference': 52.05078125, 'accuracy_ratio': 0.479492139550786}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 85.546875, 'accuracy_difference': 14.35546875, 'accuracy_ratio': 0.8563048996230481}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882467177311812}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804686519531348}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9881888767809636}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.992164445056181}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.953125, 'accuracy_ratio': 0.9804304301408258}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9746092775390722}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.12890625, 'accuracy_ratio': 0.928290672832058}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9697264655273534}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862878540686814}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901087028811758}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.62109375, 'accuracy_ratio': 0.8834475117874385}} ,
    'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'target_accuracy': 49.951171875, 'ff_frac': 0.08984375, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.90234375, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009783732874897}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990166152415915}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 49.8046875, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49853367443807595}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.8046875, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009793315374305}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990175812383101}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990204678749305}} ,
    'cifar20-insects': {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.05078125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.609375, 'accuracy_difference': -0.29296875, 'accuracy_ratio': 1.0029497515220702}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843136266728281}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.4375, 'accuracy_difference': 51.5625, 'accuracy_ratio': 0.4843749515625048}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998992126086}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.7890625, 'accuracy_ratio': 0.9121092837890716}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970616042124306}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.125, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8953032371046463}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.390625, 'accuracy_ratio': 1.0039330355921898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990195075494142}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980448658848541}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9570311542968846}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 48.828125, 'accuracy_difference': 50.87890625, 'accuracy_ratio': 0.4897159156249659}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950786398660898}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 88.18359375, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8844269436186885}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 90.625, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9080233923859145}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521483422851658}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941059903767648}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9306639694336031}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.976493535756182}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}} ,
    'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.21875, 'target_accuracy': 49.609375, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 93.5546875, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9475765607993671}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9441722853249344}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.13671875, 'accuracy_difference': 9.86328125, 'accuracy_ratio': 0.9013670973632902}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9528486271397845}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8955077229492276}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.2734375, 'accuracy_ratio': 0.9471623317128935}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 20.8984375, 'accuracy_difference': 78.80859375, 'accuracy_ratio': 0.20959841188748543}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 87.890625, 'accuracy_difference': 11.328125, 'accuracy_ratio': 0.8858266823733737}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921874007812599}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.328125, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8658177388249397}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863280263671973}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951123148587477}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872797445230471}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951123148587477}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960783313740968}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970500471013521}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.45703125, 'accuracy_difference': 6.34765625, 'accuracy_ratio': 0.9363991233979743}} ,
    'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951027405499308}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9910978224644738}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 21.09375, 'accuracy_ratio': 0.7884426241561951}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.2421875, 'accuracy_difference': 26.7578125, 'accuracy_ratio': 0.7324218017578198}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9666010815521112}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.94140625, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8994139725586027}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 41.30859375, 'accuracy_difference': 58.49609375, 'accuracy_ratio': 0.4138942833828037}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.5234375, 'accuracy_difference': 13.18359375, 'accuracy_ratio': 0.8677766024874396}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9616140763097624}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 87.109375, 'accuracy_difference': 12.59765625, 'accuracy_ratio': 0.8736531934749392}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 84.86328125, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8486327276367273}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824045937456203}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9774950096913023}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9608992195541739}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941001948909931}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 87.6953125, 'accuracy_difference': 12.109375, 'accuracy_ratio': 0.8786691878906802}} ,
    'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 49.90234375, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853084222374314}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9910978224644738}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.4609375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.977472967587432}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 75.68359375, 'accuracy_difference': 24.31640625, 'accuracy_ratio': 0.7568358618164138}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862474449982923}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 42.3828125, 'accuracy_difference': 57.6171875, 'accuracy_ratio': 0.42382808261719174}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960628917353935}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9882467177311812}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 77.24609375, 'accuracy_difference': 22.75390625, 'accuracy_ratio': 0.7724608602539139}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 100.0, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009774169109604}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9951170879882911}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.69921875, 'accuracy_difference': 8.10546875, 'accuracy_ratio': 0.9187866007008337}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628542535715781}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9578430410949731}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.58203125, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9724679453483602}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.75, 'accuracy_difference': 6.0546875, 'accuracy_ratio': 0.9393345438474977}} ,
    'cifar20-people': {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.9950543007976652}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931438768874309}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9707030279296972}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 42.7734375, 'accuracy_difference': 56.640625, 'accuracy_ratio': 0.43025535947136656}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863280263671973}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9872797445230471}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921258842581786}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687499031250096}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628542535715781}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931639631836037}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823873771071747}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.80078125, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9617646093287294}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9665682409276422}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.84765625, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9403130173306722}} ,
    'cifar20-reptiles': {'unpruned_accuracy': 99.4140625, 'target_accuracy': 49.70703125, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901087028811758}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9549460354686836}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 28.41796875, 'accuracy_difference': 71.58203125, 'accuracy_ratio': 0.2841796590820341}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813358541367471}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.59375, 'accuracy_difference': 16.40625, 'accuracy_ratio': 0.8359374164062583}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9745595892417789}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.72265625, 'accuracy_difference': 8.984375, 'accuracy_ratio': 0.9098921712311867}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.171875, 'accuracy_ratio': 0.9881888767809636}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755141039249321}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 83.0078125, 'accuracy_difference': 16.9921875, 'accuracy_ratio': 0.8300780419921958}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970673488761519}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.5625, 'accuracy_ratio': 0.9843443240735237}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.484375, 'accuracy_difference': 3.41796875, 'accuracy_ratio': 0.9657868045976844}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862744107897061}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 78.125, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7866272560957414}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 75.87890625, 'accuracy_difference': 23.92578125, 'accuracy_ratio': 0.7602738964265685}} ,
    'cifar20-small_mammals': {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.94921875, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9920869420477716}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 38.0859375, 'accuracy_difference': 61.62109375, 'accuracy_ratio': 0.3819784141874734}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.71484375, 'accuracy_difference': 17.28515625, 'accuracy_ratio': 0.8271483547851645}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 96.2890625, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9685657178967293}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 79.296875, 'accuracy_difference': 20.703125, 'accuracy_ratio': 0.7929686707031329}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 87.890625, 'accuracy_difference': 11.9140625, 'accuracy_ratio': 0.8806261348570291}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 87.3046875, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8756120571374391}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 97.16796875, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9793306099572299}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.6484375, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8991184210874374}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.4765625, 'accuracy_difference': 11.5234375, 'accuracy_ratio': 0.8847655365234464}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696968726324928}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 91.6015625, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9178081272176593}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931572808413435}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941175472572188}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9901670586105145}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 83.3984375, 'accuracy_difference': 16.40625, 'accuracy_ratio': 0.8356163546310031}} ,
    #'cifar20-trees': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 17.578125, 'accuracy_difference': 81.15234375, 'accuracy_ratio': 0.17804152499361803}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.8515625, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9813906949124317}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.22265625, 'accuracy_ratio': 0.9677733407226659}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891943995152195}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.94140625, 'accuracy_difference': 10.05859375, 'accuracy_ratio': 0.8994139725586027}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9726026422754299}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.703125, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598431946249333}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 78.02734375, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7864172435736951}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.96484375, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8896483485351652}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9833495585749316}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9541014670898532}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970702127929787}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.05078125, 'accuracy_ratio': 0.9794519566576513}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9598038252118513}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9891837745403947}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.84375, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9001956045205186}} ,
    #'cifar20-veh1': {'unpruned_accuracy': 98.73046875, 'target_accuracy': 49.365234375, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 24.51171875, 'accuracy_difference': 75.1953125, 'accuracy_ratio': 0.2458373896437329}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 1.66015625, 'accuracy_ratio': 0.9831848657980907}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960821723811807}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.63671875, 'accuracy_ratio': 0.9736327151367284}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.8828125, 'accuracy_ratio': 0.9508839907951663}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9775389647461035}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.07421875, 'accuracy_ratio': 0.9892366914893961}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.963760921949933}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9753936024800148}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8662108508789149}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.515625, 'accuracy_ratio': 0.964740353781183}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.62890625, 'accuracy_difference': 5.37109375, 'accuracy_ratio': 0.9462889678711032}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.0234375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9912022468239393}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.90625, 'accuracy_ratio': 0.9609374039062596}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.24609375, 'accuracy_ratio': 0.9774950096913023}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.36328125, 'accuracy_difference': 2.5390625, 'accuracy_ratio': 0.9745844576760034}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.68359375, 'accuracy_ratio': 0.9931371551987797}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 98.4375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9911503426806341}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 3.02734375, 'accuracy_ratio': 0.9696672218259065}} ,
    #'cifar20-veh2': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.25, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.328125, 'accuracy_ratio': 0.6356512584812057}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 96.38671875, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9762610287150055}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.44140625, 'accuracy_ratio': 0.9755141039249321}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.0625, 'accuracy_difference': 10.9375, 'accuracy_ratio': 0.8906249109375088}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9862474449982923}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.859375, 'accuracy_ratio': 0.9414061558593844}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9441722853249344}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 91.015625, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9173227421910937}, 'cifar20-large_man-made_outdoor_things': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.28125, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8828124117187588}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784523994186819}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853514639648536}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.63671875, 'accuracy_ratio': 0.9736069406673014}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960936503906349}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.48828125, 'accuracy_ratio': 0.995107532388443}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9550341175019612}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921567631403406}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980333311714719}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.60546875, 'accuracy_difference': 4.19921875, 'accuracy_ratio': 0.9579255400278128}} ,
    "cifar20-trees": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 49.365234375, 'ff_frac': 0.07421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 49.4140625, 'accuracy_ratio': 0.4995053895654284}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998994106192}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 94.04296875, 'accuracy_difference': 5.95703125, 'accuracy_ratio': 0.9404295934570406}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980429528379663}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980410360436806}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 95.8984375, 'accuracy_difference': 3.3203125, 'accuracy_ratio': 0.9665353356562811}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997058723432536}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.51171875, 'accuracy_difference': -0.1953125, 'accuracy_ratio': 1.0019664674519506}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.7109375, 'accuracy_ratio': 0.9628179074436852}},
    "cifar20-veh1": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 49.853515625, 'ff_frac': 0.0546875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824217767578223}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 49.31640625, 'accuracy_difference': 50.390625, 'accuracy_ratio': 0.4946130747812156}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980216595475588}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.31640625, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990175812383101}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.1953125, 'accuracy_ratio': 0.9980467751953225}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998998043153}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990156473433048}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941233087186808}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998999022582}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.90234375, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990233375976663}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.21875, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941290589052685}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.390625, 'accuracy_ratio': 0.9960898318674498}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.609375, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998996078532}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.51171875, 'accuracy_difference': -0.1953125, 'accuracy_ratio': 1.0019664674519506}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}},
    "cifar20-veh2": {'unpruned_accuracy': 100.0, 'target_accuracy': 50.0, 'ff_frac': 0.0859375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.828125, 'accuracy_difference': 51.171875, 'accuracy_ratio': 0.48828120117187984}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 82.71484375, 'accuracy_difference': 16.9921875, 'accuracy_ratio': 0.8295787610686923}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 98.6328125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990107791308568}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9531249046875095}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.997052944893692}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9765624023437597}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990214263211408}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.991185013224931}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 98.33984375, 'accuracy_difference': 0.87890625, 'accuracy_ratio': 0.9911416323888748}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 99.70703125, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999998997061804}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.8046875, 'accuracy_difference': 0.09765625, 'accuracy_ratio': 0.9990223828935562}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 100.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 0.9999999000000099}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 99.51171875, 'accuracy_difference': 0.29296875, 'accuracy_ratio': 0.9970644793547918}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.53515625, 'accuracy_difference': 1.3671875, 'accuracy_ratio': 0.9863146617804287}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 99.70703125, 'accuracy_difference': -0.09765625, 'accuracy_ratio': 1.0009802916662922}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 99.609375, 'accuracy_difference': -0.29296875, 'accuracy_ratio': 1.0029497515220702}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 98.828125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902151649725706}},
}

# %%
print(len(cifar20_subsets_wrong))
print(len(cifar20_subsets_right))
print(cifar20_wrong_to_right)
print(cifar20_wrong_to_right.keys())
for __k,d in orig_data.items():
    d = [((cifar20_wrong_to_right[k],v) if ("cifar20" in k) else (k,v)) for k,v in d.items()]
    d = {k:v for k,v in d}
    print(f"'{__k}':",d,",")
# Out:
# 19
# 20
# ...

# %%
# 10%

data = {
"cifar20-veh2": {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.4375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 9.86328125, 'accuracy_difference': 90.13671875, 'accuracy_ratio': 0.09863280263671974}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 26.66015625, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.2673848899312314}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 58.49609375, 'accuracy_difference': 40.234375, 'accuracy_ratio': 0.5924826303954289}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 57.12890625, 'accuracy_difference': 42.578125, 'accuracy_ratio': 0.5729676212812101}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.71875, 'accuracy_difference': 63.28125, 'accuracy_ratio': 0.3671874632812537}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 58.59375, 'accuracy_difference': 40.8203125, 'accuracy_ratio': 0.5893909033854337}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.49609375, 'accuracy_difference': 41.50390625, 'accuracy_ratio': 0.584960879003912}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 32.03125, 'accuracy_ratio': 0.6790605973230869}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 35.15625, 'accuracy_difference': 64.55078125, 'accuracy_ratio': 0.3525954592499755}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 66.9921875, 'accuracy_difference': 32.2265625, 'accuracy_ratio': 0.6751967823423716}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.203125, 'accuracy_difference': 41.50390625, 'accuracy_ratio': 0.5837413714249594}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.3125, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7031249296875071}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 60.05859375, 'accuracy_difference': 39.84375, 'accuracy_ratio': 0.6011729603517975}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 74.12109375, 'accuracy_difference': 25.87890625, 'accuracy_ratio': 0.7412108633789136}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.96875, 'accuracy_difference': 31.8359375, 'accuracy_ratio': 0.6810175442894358}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 62.98828125, 'accuracy_difference': 36.9140625, 'accuracy_ratio': 0.6304984706128608}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 53.61328125, 'accuracy_difference': 45.99609375, 'accuracy_ratio': 0.5382352400830503}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 58.7890625, 'accuracy_difference': 40.52734375, 'accuracy_ratio': 0.5919370102120454}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 45.8984375, 'accuracy_difference': 53.90625, 'accuracy_ratio': 0.4598825370920041}},
"cifar20-veh1": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.328125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 53.41796875, 'accuracy_difference': 46.58203125, 'accuracy_ratio': 0.5341796340820366}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.69140625, 'accuracy_difference': 91.015625, 'accuracy_ratio': 0.08716943298124394}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.08984375, 'accuracy_difference': 6.640625, 'accuracy_ratio': 0.9327397670498989}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 4.98046875, 'accuracy_ratio': 0.950048876312434}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.328125, 'accuracy_difference': 13.671875, 'accuracy_ratio': 0.8632811636718836}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 85.25390625, 'accuracy_difference': 14.16015625, 'accuracy_ratio': 0.857563764425806}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.40625, 'accuracy_difference': 8.59375, 'accuracy_ratio': 0.9140624085937591}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9324852294652763}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 13.96484375, 'accuracy_ratio': 0.8599411478374401}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.078125, 'accuracy_ratio': 0.9488188020088136}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.49609375, 'accuracy_ratio': 0.9147893303874364}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.01171875, 'accuracy_difference': 12.98828125, 'accuracy_ratio': 0.8701171004882899}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9237535732234937}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.40234375, 'accuracy_difference': 12.59765625, 'accuracy_ratio': 0.874023350097665}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.51953125, 'accuracy_ratio': 0.9246574415998806}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.8203125, 'accuracy_difference': 9.08203125, 'accuracy_ratio': 0.9090908180929621}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9568626490365341}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 94.82421875, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9547688320862061}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 86.5234375, 'accuracy_difference': 13.28125, 'accuracy_ratio': 0.8669275060925864}},
"cifar20-trees": {'unpruned_accuracy': 98.73046875, 'target_accuracy': 9.873046875, 'ff_frac': 0.296875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 11.62109375, 'accuracy_ratio': 0.8837889741211026}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853084222374314}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 9.47265625, 'accuracy_difference': 89.2578125, 'accuracy_ratio': 0.09594459957989417}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9569048991311835}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.796875, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9179686582031341}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9783888996198199}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.59765625, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8759764749023525}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9569470665446383}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.7734375, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9304602396874353}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 71.58203125, 'accuracy_difference': 27.63671875, 'accuracy_ratio': 0.7214566201996477}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.963760921949933}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.26171875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9326170942382905}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921797638326414}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902247298152371}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 92.08984375, 'accuracy_difference': 7.51953125, 'accuracy_ratio': 0.9245097111080447}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823007860495571}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 86.71875, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8688844530589354}},
"cifar20-small_mammals": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.390625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687499031250096}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.6015625, 'accuracy_difference': 8.10546875, 'accuracy_ratio': 0.9187070577124361}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.96875, 'accuracy_difference': 5.76171875, 'accuracy_ratio': 0.9416418432995798}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.7890625, 'accuracy_difference': 90.91796875, 'accuracy_ratio': 0.08814886481249387}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.05078125, 'accuracy_difference': 47.94921875, 'accuracy_ratio': 0.520507760449224}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 79.58984375, 'accuracy_difference': 19.82421875, 'accuracy_ratio': 0.8005893104318808}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.375, 'accuracy_difference': 40.625, 'accuracy_ratio': 0.593749940625006}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 54.98046875, 'accuracy_difference': 44.82421875, 'accuracy_ratio': 0.5508805710272304}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 75.1953125, 'accuracy_difference': 24.51171875, 'accuracy_ratio': 0.7541625100624475}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9320865202306499}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 72.8515625, 'accuracy_difference': 26.85546875, 'accuracy_ratio': 0.7306561461124492}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 67.578125, 'accuracy_difference': 32.421875, 'accuracy_ratio': 0.6757811824218818}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.66796875, 'accuracy_ratio': 0.9032257160407494}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9765624023437597}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7876711539554538}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 93.1640625, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9325512263018128}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 91.30859375, 'accuracy_difference': 8.30078125, 'accuracy_ratio': 0.9166665746405321}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.23046875, 'accuracy_ratio': 0.8869222312479483}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 59.47265625, 'accuracy_difference': 40.33203125, 'accuracy_ratio': 0.5958903512532564}},
"cifar20-reptiles": {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.3671875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.5, 'accuracy_difference': 12.5, 'accuracy_ratio': 0.8749999125000087}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.1796875, 'accuracy_difference': 15.52734375, 'accuracy_ratio': 0.8442702385374413}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 80.859375, 'accuracy_difference': 17.87109375, 'accuracy_ratio': 0.818991014970643}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 44.3359375, 'accuracy_difference': 55.37109375, 'accuracy_ratio': 0.44466205138746906}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.40625, 'accuracy_ratio': 0.08593749140625086}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 76.85546875, 'accuracy_difference': 22.55859375, 'accuracy_ratio': 0.7730844016072271}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.7890625, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.3378905912109409}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 62.40234375, 'accuracy_difference': 37.40234375, 'accuracy_ratio': 0.6252445557484907}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 34.765625, 'accuracy_ratio': 0.6513221677812047}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.28125, 'accuracy_difference': 10.9375, 'accuracy_ratio': 0.8897636898505887}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 61.1328125, 'accuracy_difference': 38.57421875, 'accuracy_ratio': 0.6131243263624574}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.73046875, 'accuracy_difference': 51.26953125, 'accuracy_ratio': 0.4873046387695361}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.4296875, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.9051807500581537}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8935545981445402}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 73.6328125, 'accuracy_difference': 26.171875, 'accuracy_ratio': 0.7377690063135555}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 75.78125, 'accuracy_difference': 24.12109375, 'accuracy_ratio': 0.7585531987528372}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.7109375, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7901959991018919}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 42.3828125, 'accuracy_difference': 56.93359375, 'accuracy_ratio': 0.4267452864319397}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 28.41796875, 'accuracy_difference': 71.38671875, 'accuracy_ratio': 0.2847357836037728}},
"cifar20-people": {'unpruned_accuracy': 99.4140625, 'target_accuracy': 9.94140625, 'ff_frac': 0.453125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.59375, 'accuracy_difference': 41.40625, 'accuracy_ratio': 0.5859374414062558}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 52.05078125, 'accuracy_difference': 47.65625, 'accuracy_ratio': 0.5220371660562136}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 75.78125, 'accuracy_difference': 22.94921875, 'accuracy_ratio': 0.7675567966391533}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 37.5, 'accuracy_difference': 62.20703125, 'accuracy_ratio': 0.3761018231999738}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 45.60546875, 'accuracy_difference': 54.39453125, 'accuracy_ratio': 0.4560546418945358}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 8.7890625, 'accuracy_difference': 90.625, 'accuracy_ratio': 0.08840863550781505}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.3046875, 'accuracy_difference': 37.6953125, 'accuracy_ratio': 0.6230468126953187}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 50.29296875, 'accuracy_difference': 49.51171875, 'accuracy_ratio': 0.5039138438348556}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 47.16796875, 'accuracy_difference': 52.5390625, 'accuracy_ratio': 0.4730655744937171}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.57421875, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8927164454584999}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 51.26953125, 'accuracy_difference': 48.4375, 'accuracy_ratio': 0.5142017114062143}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.6953125, 'accuracy_difference': 37.3046875, 'accuracy_ratio': 0.6269530623046937}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 62.3046875, 'accuracy_difference': 37.59765625, 'accuracy_ratio': 0.623655851551946}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.828125, 'accuracy_difference': 26.171875, 'accuracy_ratio': 0.7382811761718824}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 49.70703125, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49804300293580867}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.5234375, 'accuracy_ratio': 0.6344085386476692}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 48.6328125, 'accuracy_difference': 50.9765625, 'accuracy_ratio': 0.48823524510265776}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 54.00390625, 'accuracy_difference': 45.3125, 'accuracy_ratio': 0.5437560907761813}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 30.46875, 'accuracy_difference': 69.3359375, 'accuracy_ratio': 0.30528372675043675}},
"cifar20-non_insect_invertebrates": {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.4921875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 35.05859375, 'accuracy_ratio': 0.6494139975586002}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 44.7265625, 'accuracy_difference': 54.98046875, 'accuracy_ratio': 0.4485797787124688}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 72.75390625, 'accuracy_difference': 25.9765625, 'accuracy_ratio': 0.736894089556919}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 25.68359375, 'accuracy_difference': 74.0234375, 'accuracy_ratio': 0.2575905716187321}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.9453125, 'accuracy_difference': 81.0546875, 'accuracy_ratio': 0.1894531060546894}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 51.7578125, 'accuracy_difference': 47.65625, 'accuracy_ratio': 0.5206286313237998}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.40625, 'accuracy_ratio': 0.08593749140625086}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 42.578125, 'accuracy_difference': 57.2265625, 'accuracy_ratio': 0.4266144386640719}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 50.9765625, 'accuracy_difference': 48.73046875, 'accuracy_ratio': 0.5112634159124645}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 84.86328125, 'accuracy_difference': 14.35546875, 'accuracy_ratio': 0.8553148744249575}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 55.078125, 'accuracy_difference': 44.62890625, 'accuracy_ratio': 0.5523995528249616}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 23.92578125, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23925778857422114}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 69.921875, 'accuracy_difference': 29.98046875, 'accuracy_ratio': 0.6999021782307105}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 66.2109375, 'accuracy_difference': 33.7890625, 'accuracy_ratio': 0.6621093087890692}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 45.5078125, 'accuracy_difference': 54.296875, 'accuracy_ratio': 0.4559686431593062}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 54.8828125, 'accuracy_difference': 45.01953125, 'accuracy_ratio': 0.5493645588905857}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 32.51953125, 'accuracy_difference': 67.08984375, 'accuracy_ratio': 0.32647055546021087}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 24.51171875, 'accuracy_difference': 74.8046875, 'accuracy_ratio': 0.24680430160003886}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 24.21875, 'accuracy_difference': 75.5859375, 'accuracy_ratio': 0.24266142382727024}},
"cifar20-medium_sized_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.390625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.16015625, 'accuracy_difference': 10.83984375, 'accuracy_ratio': 0.8916014733398526}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8687560343186895}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.84375, 'accuracy_difference': 8.88671875, 'accuracy_ratio': 0.9099900166340478}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 38.57421875, 'accuracy_difference': 61.1328125, 'accuracy_ratio': 0.3868755733437231}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.09375, 'accuracy_difference': 53.90625, 'accuracy_ratio': 0.46093745390625457}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 77.05078125, 'accuracy_difference': 22.36328125, 'accuracy_ratio': 0.7750490379518453}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.765625, 'accuracy_difference': 40.234375, 'accuracy_ratio': 0.597656190234381}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 90.13671875, 'accuracy_ratio': 0.0968688748342732}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.7265625, 'accuracy_difference': 29.98046875, 'accuracy_ratio': 0.6993143275124514}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.76953125, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8946849491971075}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.4453125, 'accuracy_difference': 43.26171875, 'accuracy_ratio': 0.5661115984624606}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 57.91015625, 'accuracy_difference': 42.08984375, 'accuracy_ratio': 0.5791015045898495}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.87109375, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.9296186752757064}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9599608415039158}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.3515625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8551858242944927}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.34765625, 'accuracy_difference': 18.5546875, 'accuracy_ratio': 0.8142716682488574}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 88.8671875, 'accuracy_difference': 10.7421875, 'accuracy_ratio': 0.8921567731795553}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 84.1796875, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8475908684431613}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 63.4765625, 'accuracy_difference': 36.328125, 'accuracy_ratio': 0.63600776406341}},
"cifar20-large_omnivores_and_herbivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.34375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.05859375, 'accuracy_difference': 14.94140625, 'accuracy_ratio': 0.8505858524414147}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9725758084311824}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 85.9375, 'accuracy_difference': 12.79296875, 'accuracy_ratio': 0.8704252333021326}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 83.49609375, 'accuracy_difference': 16.2109375, 'accuracy_ratio': 0.8374142157186918}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.046875, 'accuracy_difference': 26.953125, 'accuracy_ratio': 0.7304686769531323}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 87.6953125, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8821217187335324}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.51953125, 'accuracy_difference': 17.48046875, 'accuracy_ratio': 0.825195229980477}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 83.0078125, 'accuracy_difference': 16.796875, 'accuracy_ratio': 0.8317024606983053}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 90.0390625, 'accuracy_ratio': 0.09696375129374325}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 81.4453125, 'accuracy_difference': 17.7734375, 'accuracy_ratio': 0.8208660589993263}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.26953125, 'accuracy_difference': 23.4375, 'accuracy_ratio': 0.7649362602061968}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.9921875, 'accuracy_difference': 8.0078125, 'accuracy_ratio': 0.9199217830078217}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784945257108119}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9873045887695411}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9540116460951149}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814270767369182}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9715685299131201}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.484375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9714846612782405}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 80.859375, 'accuracy_difference': 18.9453125, 'accuracy_ratio': 0.8101760440684668}},
"cifar20-large_natural_outdoor_scenes": {'unpruned_accuracy': 99.21875, 'target_accuracy': 9.921875, 'ff_frac': 0.546875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 2.734375, 'accuracy_difference': 97.265625, 'accuracy_ratio': 0.027343747265625273}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.29296875, 'accuracy_difference': 99.4140625, 'accuracy_ratio': 0.0029382954937497954}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 5.76171875, 'accuracy_difference': 92.96875, 'accuracy_ratio': 0.058358055414574804}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 2.24609375, 'accuracy_difference': 97.4609375, 'accuracy_ratio': 0.022526932118748434}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 1.07421875, 'accuracy_difference': 98.92578125, 'accuracy_ratio': 0.010742186425781357}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 5.46875, 'accuracy_difference': 93.9453125, 'accuracy_ratio': 0.055009817649307145}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.88671875, 'accuracy_difference': 91.11328125, 'accuracy_ratio': 0.08886717861328214}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 2.5390625, 'accuracy_difference': 97.265625, 'accuracy_ratio': 0.025440310562536397}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 1.07421875, 'accuracy_difference': 98.6328125, 'accuracy_ratio': 0.01077375014374925}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 8.88671875, 'accuracy_difference': 90.33203125, 'accuracy_ratio': 0.08956692010664112}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 3.80859375, 'accuracy_difference': 95.8984375, 'accuracy_ratio': 0.038197841418747346}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.3515625, 'accuracy_ratio': 0.14648436035156395}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 4.4921875, 'accuracy_difference': 95.41015625, 'accuracy_ratio': 0.04496578240029705}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 3.7109375, 'accuracy_difference': 96.2890625, 'accuracy_ratio': 0.03710937128906287}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 15.72265625, 'accuracy_difference': 84.08203125, 'accuracy_ratio': 0.15753423079109077}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 19.23828125, 'accuracy_difference': 80.6640625, 'accuracy_ratio': 0.19257085071431562}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 14.453125, 'accuracy_difference': 85.15625, 'accuracy_ratio': 0.1450980246489826}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 1.46484375, 'accuracy_difference': 97.8515625, 'accuracy_ratio': 0.014749261051795151}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 0.48828125, 'accuracy_difference': 99.31640625, 'accuracy_ratio': 0.004892367415872384}},
"cifar20-large_carnivores": {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.3828125, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9238280326171967}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.0625, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8932418300999379}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 12.109375, 'accuracy_ratio': 0.8773490703852178}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.7890625, 'accuracy_difference': 40.91796875, 'accuracy_ratio': 0.589617962412459}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.30078125, 'accuracy_difference': 41.69921875, 'accuracy_ratio': 0.5830077541992246}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 77.5390625, 'accuracy_difference': 21.875, 'accuracy_ratio': 0.7799606288133906}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.5078125, 'accuracy_difference': 29.4921875, 'accuracy_ratio': 0.7050780544921945}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 44.04296875, 'accuracy_difference': 55.76171875, 'accuracy_ratio': 0.44129154091168904}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 34.765625, 'accuracy_ratio': 0.6513221677812047}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 10.83984375, 'accuracy_ratio': 0.8907479417198925}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.49609375, 'accuracy_difference': 91.2109375, 'accuracy_ratio': 0.08521056931874407}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 69.140625, 'accuracy_difference': 30.859375, 'accuracy_ratio': 0.6914061808593819}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.1171875, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521015664758549}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9619139663086034}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 10.25390625, 'accuracy_ratio': 0.8972601840709953}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.8359375, 'accuracy_ratio': 0.9315737092931106}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 85.15625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8549018749588706}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 88.96484375, 'accuracy_difference': 10.3515625, 'accuracy_ratio': 0.8957717878790254}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 44.43359375, 'accuracy_difference': 55.37109375, 'accuracy_ratio': 0.44520543484438696}},
"cifar20-insects": {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.46875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 68.45703125, 'accuracy_difference': 31.54296875, 'accuracy_ratio': 0.6845702440429756}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 53.02734375, 'accuracy_difference': 46.6796875, 'accuracy_ratio': 0.531831484368713}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 73.4375, 'accuracy_difference': 25.29296875, 'accuracy_ratio': 0.7438179266400042}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 27.44140625, 'accuracy_difference': 72.265625, 'accuracy_ratio': 0.27522034458123085}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.7890625, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.3378905912109409}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 54.39453125, 'accuracy_difference': 45.01953125, 'accuracy_ratio': 0.5471512219761443}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.640625, 'accuracy_difference': 68.359375, 'accuracy_ratio': 0.31640621835937816}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 46.09375, 'accuracy_difference': 53.7109375, 'accuracy_ratio': 0.46183948405835307}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.0859375, 'accuracy_difference': 36.62109375, 'accuracy_ratio': 0.6327129629874559}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 83.203125, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.8385825926467938}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.16015625, 'accuracy_difference': 35.546875, 'accuracy_ratio': 0.6434867131312052}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.3984375, 'accuracy_difference': 91.6015625, 'accuracy_ratio': 0.08398436660156333}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 73.6328125, 'accuracy_difference': 26.26953125, 'accuracy_ratio': 0.7370478245613907}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.6796875, 'accuracy_difference': 28.3203125, 'accuracy_ratio': 0.7167968033203197}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4814089537218426}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 67.28515625, 'accuracy_difference': 32.6171875, 'accuracy_ratio': 0.6735092189957537}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 30.95703125, 'accuracy_difference': 68.65234375, 'accuracy_ratio': 0.31078428252518575}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 37.98828125, 'accuracy_difference': 61.328125, 'accuracy_ratio': 0.38249750327655424}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 33.59375, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.33659487821202}},
"cifar20-household_furniture": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 9.990234375, 'ff_frac': 0.4375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.1640625, 'accuracy_difference': 81.8359375, 'accuracy_ratio': 0.1816406068359393}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 16.30859375, 'accuracy_difference': 83.3984375, 'accuracy_ratio': 0.16356511581873862}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 46.6796875, 'accuracy_difference': 52.05078125, 'accuracy_ratio': 0.4727991608163857}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 26.171875, 'accuracy_difference': 73.53515625, 'accuracy_ratio': 0.2624877307749817}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.19921875, 'accuracy_difference': 70.80078125, 'accuracy_ratio': 0.2919921583007842}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 20.80078125, 'accuracy_difference': 78.61328125, 'accuracy_ratio': 0.20923377070182894}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 39.55078125, 'accuracy_difference': 60.44921875, 'accuracy_ratio': 0.3955077729492227}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 43.26171875, 'accuracy_difference': 56.54296875, 'accuracy_ratio': 0.4334637530462932}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 27.63671875, 'accuracy_difference': 72.0703125, 'accuracy_ratio': 0.2771792082437307}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 74.21875, 'accuracy_difference': 25.0, 'accuracy_ratio': 0.7480314206708489}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 33.88671875, 'accuracy_difference': 65.8203125, 'accuracy_ratio': 0.33986284544372636}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 43.359375, 'accuracy_difference': 56.640625, 'accuracy_ratio': 0.4335937066406293}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 9.1796875, 'accuracy_difference': 90.72265625, 'accuracy_ratio': 0.09188659881799832}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.69140625, 'accuracy_difference': 66.30859375, 'accuracy_ratio': 0.3369140288085971}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 34.66796875, 'accuracy_difference': 65.13671875, 'accuracy_ratio': 0.3473580865269393}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 25.9765625, 'accuracy_difference': 73.92578125, 'accuracy_ratio': 0.2600195243147612}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 46.875, 'accuracy_difference': 52.734375, 'accuracy_ratio': 0.4705881880507544}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 35.05859375, 'accuracy_difference': 64.2578125, 'accuracy_ratio': 0.3529989811729639}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 36.03515625, 'accuracy_difference': 63.76953125, 'accuracy_ratio': 0.36105671529138195}},
"cifar20-household_electrical_devices": {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.53125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 7.71484375, 'accuracy_difference': 92.28515625, 'accuracy_ratio': 0.07714842978515701}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 3.515625, 'accuracy_difference': 96.19140625, 'accuracy_ratio': 0.03525954592499755}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 42.7734375, 'accuracy_difference': 55.95703125, 'accuracy_ratio': 0.4332343774844706}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.16015625, 'accuracy_difference': 85.546875, 'accuracy_ratio': 0.14201761553124012}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 11.62109375, 'accuracy_difference': 88.37890625, 'accuracy_ratio': 0.11621092587890741}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 12.59765625, 'accuracy_difference': 86.81640625, 'accuracy_ratio': 0.12671904422786823}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 21.58203125, 'accuracy_difference': 78.41796875, 'accuracy_ratio': 0.2158202909179709}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 26.66015625, 'accuracy_difference': 73.14453125, 'accuracy_ratio': 0.2671232609066322}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.05859375, 'accuracy_ratio': 0.14691477468748979}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.1015625, 'accuracy_ratio': 0.7066928421600914}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 22.55859375, 'accuracy_difference': 77.1484375, 'accuracy_ratio': 0.22624875301873426}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 23.92578125, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23925778857422114}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 11.23046875, 'accuracy_difference': 88.671875, 'accuracy_ratio': 0.11241445600074262}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.203125, 'accuracy_difference': 91.796875, 'accuracy_ratio': 0.08203124179687582}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.65234375, 'accuracy_difference': 81.15234375, 'accuracy_ratio': 0.18688843528632507}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 21.6796875, 'accuracy_difference': 78.22265625, 'accuracy_ratio': 0.21700877593186838}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 38.57421875, 'accuracy_difference': 61.03515625, 'accuracy_ratio': 0.3872548630834333}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1858406892526189}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 80.46875, 'accuracy_ratio': 0.1937377496685464}},
"cifar20-fruit_and_vegetables": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.5, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 37.5, 'accuracy_difference': 62.5, 'accuracy_ratio': 0.3749999625000037}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 24.12109375, 'accuracy_difference': 75.5859375, 'accuracy_ratio': 0.2419196623187332}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 61.5234375, 'accuracy_difference': 37.20703125, 'accuracy_ratio': 0.6231453374776631}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 11.62109375, 'accuracy_difference': 88.0859375, 'accuracy_ratio': 0.1165523879187419}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 30.56640625, 'accuracy_difference': 69.43359375, 'accuracy_ratio': 0.3056640319335968}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 80.95703125, 'accuracy_ratio': 0.18565813456641161}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.78515625, 'accuracy_difference': 70.21484375, 'accuracy_ratio': 0.2978515327148467}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 38.8671875, 'accuracy_difference': 60.9375, 'accuracy_ratio': 0.38943244630344176}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.2265625, 'accuracy_difference': 67.48046875, 'accuracy_ratio': 0.3232125043124775}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 75.9765625, 'accuracy_difference': 23.2421875, 'accuracy_ratio': 0.7657479543183164}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 59.9609375, 'accuracy_ratio': 0.39862875531872227}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.25, 'accuracy_difference': 68.75, 'accuracy_ratio': 0.31249996875000313}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 55.6640625, 'accuracy_difference': 44.23828125, 'accuracy_ratio': 0.5571846949602025}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.33984375, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.4833983891601611}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 9.47265625, 'accuracy_difference': 90.33203125, 'accuracy_ratio': 0.09491192786792425}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 36.03515625, 'accuracy_difference': 63.8671875, 'accuracy_ratio': 0.3607037762110785}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 11.23046875, 'accuracy_difference': 88.37890625, 'accuracy_ratio': 0.11274508672049326}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 23.2421875, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23402160868848304}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 60.05859375, 'accuracy_ratio': 0.3982387076520121}},
"cifar20-food_containers": {'unpruned_accuracy': 99.90234375, 'target_accuracy': 9.990234375, 'ff_frac': 0.484375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 12.20703125, 'accuracy_difference': 87.79296875, 'accuracy_ratio': 0.12207030029296996}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.16015625, 'accuracy_difference': 85.546875, 'accuracy_ratio': 0.14201761553124012}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 44.921875, 'accuracy_difference': 53.80859375, 'accuracy_ratio': 0.4549950083170239}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 12.40234375, 'accuracy_difference': 87.3046875, 'accuracy_ratio': 0.12438784256874134}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.21484375, 'accuracy_difference': 79.78515625, 'accuracy_ratio': 0.20214841728515826}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 13.28125, 'accuracy_difference': 86.1328125, 'accuracy_ratio': 0.13359527143403163}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.01953125, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.20019529248047074}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 28.90625, 'accuracy_difference': 70.8984375, 'accuracy_ratio': 0.2896281510196451}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.140625, 'accuracy_difference': 80.56640625, 'accuracy_ratio': 0.19196863892498664}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 68.9453125, 'accuracy_difference': 30.2734375, 'accuracy_ratio': 0.6948818197284465}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 17.578125, 'accuracy_difference': 82.12890625, 'accuracy_ratio': 0.17629772962498774}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.32421875, 'accuracy_difference': 67.67578125, 'accuracy_ratio': 0.3232421551757845}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 26.85546875, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.2688171773930802}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 25.0, 'accuracy_difference': 75.0, 'accuracy_ratio': 0.24999997500000248}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 13.76953125, 'accuracy_difference': 86.03515625, 'accuracy_ratio': 0.13796476112760123}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 8.984375, 'accuracy_difference': 90.91796875, 'accuracy_ratio': 0.0899315648005941}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 27.9296875, 'accuracy_difference': 71.6796875, 'accuracy_ratio': 0.2803921287135745}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.194690245883696}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.15625, 'accuracy_ratio': 0.14677102247617152}},
"cifar20-flowers": {'unpruned_accuracy': 99.609375, 'target_accuracy': 9.9609375, 'ff_frac': 0.375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.5546875, 'accuracy_difference': 6.4453125, 'accuracy_ratio': 0.9355467814453218}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9480900126499341}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9070226578841541}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.904995012074937}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.52734375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.9052733469726653}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 83.3984375, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.838899719151934}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.46484375, 'accuracy_difference': 23.53515625, 'accuracy_ratio': 0.7646483610351639}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9442269112633701}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.74609375, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9000978529186874}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9527558094860287}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.375, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8462291021999412}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.19140625, 'accuracy_difference': 28.80859375, 'accuracy_ratio': 0.7119139913086009}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824045937456203}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9707030279296972}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.87109375, 'accuracy_difference': 31.93359375, 'accuracy_ratio': 0.6800390708062614}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 7.421875, 'accuracy_ratio': 0.925708607240898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 89.94140625, 'accuracy_ratio': 0.0970588137854681}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 90.625, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.91248761707106}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}},
"cifar20-fish": {'unpruned_accuracy': 99.31640625, 'target_accuracy': 9.931640625, 'ff_frac': 0.421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.07421875, 'accuracy_difference': 23.92578125, 'accuracy_ratio': 0.7607421114257888}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.3359375, 'accuracy_difference': 30.37109375, 'accuracy_ratio': 0.6953966001874516}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 69.82421875, 'accuracy_difference': 28.90625, 'accuracy_ratio': 0.7072205020579827}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.8125, 'accuracy_difference': 66.89453125, 'accuracy_ratio': 0.3290890952999771}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.6875, 'accuracy_difference': 70.3125, 'accuracy_ratio': 0.296874970312503}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 63.671875, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6404714483455046}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.2890625, 'accuracy_difference': 53.7109375, 'accuracy_ratio': 0.46289057871094214}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4814089537218426}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.88671875, 'accuracy_difference': 40.8203125, 'accuracy_ratio': 0.5905973942437089}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 71.97265625, 'accuracy_difference': 27.24609375, 'accuracy_ratio': 0.7253936276768627}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.93359375, 'accuracy_difference': 42.7734375, 'accuracy_ratio': 0.5710087576187103}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.44140625, 'accuracy_difference': 47.55859375, 'accuracy_ratio': 0.524414010058599}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.8359375, 'accuracy_difference': 18.06640625, 'accuracy_ratio': 0.8191592532923679}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.37109375, 'accuracy_difference': 19.62890625, 'accuracy_ratio': 0.8037108571289142}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7025439609192743}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 74.0234375, 'accuracy_difference': 25.87890625, 'accuracy_ratio': 0.7409578925961992}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 57.2265625, 'accuracy_difference': 42.3828125, 'accuracy_ratio': 0.574509746245296}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 9.27734375, 'accuracy_difference': 90.0390625, 'accuracy_ratio': 0.09341198666136928}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.9453125, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1898238557358485}},
"cifar20-aquatic_mammals": {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.15234375, 'accuracy_difference': 18.84765625, 'accuracy_ratio': 0.8115233563476644}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 19.7265625, 'accuracy_ratio': 0.8021546697936942}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7883283078884088}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 33.69140625, 'accuracy_difference': 66.015625, 'accuracy_ratio': 0.3379039817812265}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.5234375, 'accuracy_difference': 63.4765625, 'accuracy_ratio': 0.36523433847656617}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 71.875, 'accuracy_difference': 27.5390625, 'accuracy_ratio': 0.7229861748194653}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.01171875, 'accuracy_difference': 37.98828125, 'accuracy_ratio': 0.6201171254882875}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 61.9140625, 'accuracy_difference': 37.890625, 'accuracy_ratio': 0.6203521883326183}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.96484375, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6415278494687053}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 31.4453125, 'accuracy_ratio': 0.6830707972968015}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 59.86328125, 'accuracy_difference': 39.84375, 'accuracy_ratio': 0.6003917125562083}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 63.76953125, 'accuracy_difference': 36.23046875, 'accuracy_ratio': 0.6376952487304751}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.8671875, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8895404779189199}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8662108508789149}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.6796875, 'accuracy_difference': 28.125, 'accuracy_ratio': 0.718199536650066}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 75.29296875, 'accuracy_difference': 24.609375, 'accuracy_ratio': 0.7536656137093266}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 20.99609375, 'accuracy_ratio': 0.7892156070434527}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 44.140625, 'accuracy_difference': 55.17578125, 'accuracy_ratio': 0.4444443996940939}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.2109375, 'accuracy_ratio': 0.08610566651935396}},
}

# %% [markdown]
# saved to:  saved_tensors/Cifar100/cross_pruning_accuracy-Cifar100-0.01-2024-03-16_03:59:19.pt data:  {'sample_size': 1000.0, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.4375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 9.86328125, 'accuracy_difference': 90.13671875, 'accuracy_ratio': 0.09863280263671974}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 26.66015625, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.2673848899312314}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 58.49609375, 'accuracy_difference': 40.234375, 'accuracy_ratio': 0.5924826303954289}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 57.12890625, 'accuracy_difference': 42.578125, 'accuracy_ratio': 0.5729676212812101}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.71875, 'accuracy_difference': 63.28125, 'accuracy_ratio': 0.3671874632812537}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 58.59375, 'accuracy_difference': 40.8203125, 'accuracy_ratio': 0.5893909033854337}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.49609375, 'accuracy_difference': 41.50390625, 'accuracy_ratio': 0.584960879003912}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 32.03125, 'accuracy_ratio': 0.6790605973230869}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 35.15625, 'accuracy_difference': 64.55078125, 'accuracy_ratio': 0.3525954592499755}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 66.9921875, 'accuracy_difference': 32.2265625, 'accuracy_ratio': 0.6751967823423716}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.203125, 'accuracy_difference': 41.50390625, 'accuracy_ratio': 0.5837413714249594}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.3125, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7031249296875071}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 60.05859375, 'accuracy_difference': 39.84375, 'accuracy_ratio': 0.6011729603517975}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 74.12109375, 'accuracy_difference': 25.87890625, 'accuracy_ratio': 0.7412108633789136}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.96875, 'accuracy_difference': 31.8359375, 'accuracy_ratio': 0.6810175442894358}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 62.98828125, 'accuracy_difference': 36.9140625, 'accuracy_ratio': 0.6304984706128608}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 53.61328125, 'accuracy_difference': 45.99609375, 'accuracy_ratio': 0.5382352400830503}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 58.7890625, 'accuracy_difference': 40.52734375, 'accuracy_ratio': 0.5919370102120454}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 45.8984375, 'accuracy_difference': 53.90625, 'accuracy_ratio': 0.4598825370920041}}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.328125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 53.41796875, 'accuracy_difference': 46.58203125, 'accuracy_ratio': 0.5341796340820366}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.69140625, 'accuracy_difference': 91.015625, 'accuracy_ratio': 0.08716943298124394}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.08984375, 'accuracy_difference': 6.640625, 'accuracy_ratio': 0.9327397670498989}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.7265625, 'accuracy_difference': 4.98046875, 'accuracy_ratio': 0.950048876312434}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.328125, 'accuracy_difference': 13.671875, 'accuracy_ratio': 0.8632811636718836}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 85.25390625, 'accuracy_difference': 14.16015625, 'accuracy_ratio': 0.857563764425806}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.40625, 'accuracy_difference': 8.59375, 'accuracy_ratio': 0.9140624085937591}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9324852294652763}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 13.96484375, 'accuracy_ratio': 0.8599411478374401}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.140625, 'accuracy_difference': 5.078125, 'accuracy_ratio': 0.9488188020088136}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.2109375, 'accuracy_difference': 8.49609375, 'accuracy_ratio': 0.9147893303874364}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.01171875, 'accuracy_difference': 12.98828125, 'accuracy_ratio': 0.8701171004882899}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9237535732234937}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.40234375, 'accuracy_difference': 12.59765625, 'accuracy_ratio': 0.874023350097665}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 92.28515625, 'accuracy_difference': 7.51953125, 'accuracy_ratio': 0.9246574415998806}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.8203125, 'accuracy_difference': 9.08203125, 'accuracy_ratio': 0.9090908180929621}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 95.3125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9568626490365341}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 94.82421875, 'accuracy_difference': 4.4921875, 'accuracy_ratio': 0.9547688320862061}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 86.5234375, 'accuracy_difference': 13.28125, 'accuracy_ratio': 0.8669275060925864}}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'target_accuracy': 9.873046875, 'ff_frac': 0.296875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 11.62109375, 'accuracy_ratio': 0.8837889741211026}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 98.2421875, 'accuracy_difference': 1.46484375, 'accuracy_ratio': 0.9853084222374314}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 9.47265625, 'accuracy_difference': 89.2578125, 'accuracy_ratio': 0.09594459957989417}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 95.41015625, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9569048991311835}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.796875, 'accuracy_difference': 8.203125, 'accuracy_ratio': 0.9179686582031341}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 97.265625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9783888996198199}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.59765625, 'accuracy_difference': 12.40234375, 'accuracy_ratio': 0.8759764749023525}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.5078125, 'accuracy_difference': 4.296875, 'accuracy_ratio': 0.9569470665446383}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 92.7734375, 'accuracy_difference': 6.93359375, 'accuracy_ratio': 0.9304602396874353}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 71.58203125, 'accuracy_difference': 27.63671875, 'accuracy_ratio': 0.7214566201996477}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.09375, 'accuracy_difference': 3.61328125, 'accuracy_ratio': 0.963760921949933}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.26171875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9326170942382905}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 99.12109375, 'accuracy_difference': 0.78125, 'accuracy_ratio': 0.9921797638326414}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 99.4140625, 'accuracy_difference': 0.5859375, 'accuracy_ratio': 0.9941405255859475}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 96.875, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.970645695309081}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.92578125, 'accuracy_difference': 0.9765625, 'accuracy_ratio': 0.9902247298152371}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 92.08984375, 'accuracy_difference': 7.51953125, 'accuracy_ratio': 0.9245097111080447}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 97.55859375, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9823007860495571}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 86.71875, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8688844530589354}}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.390625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.875, 'accuracy_difference': 3.125, 'accuracy_ratio': 0.9687499031250096}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 91.6015625, 'accuracy_difference': 8.10546875, 'accuracy_ratio': 0.9187070577124361}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 92.96875, 'accuracy_difference': 5.76171875, 'accuracy_ratio': 0.9416418432995798}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.7890625, 'accuracy_difference': 90.91796875, 'accuracy_ratio': 0.08814886481249387}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.05078125, 'accuracy_difference': 47.94921875, 'accuracy_ratio': 0.520507760449224}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 79.58984375, 'accuracy_difference': 19.82421875, 'accuracy_ratio': 0.8005893104318808}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.375, 'accuracy_difference': 40.625, 'accuracy_ratio': 0.593749940625006}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 54.98046875, 'accuracy_difference': 44.82421875, 'accuracy_ratio': 0.5508805710272304}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 75.1953125, 'accuracy_difference': 24.51171875, 'accuracy_ratio': 0.7541625100624475}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9320865202306499}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 72.8515625, 'accuracy_difference': 26.85546875, 'accuracy_ratio': 0.7306561461124492}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 67.578125, 'accuracy_difference': 32.421875, 'accuracy_ratio': 0.6757811824218818}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.66796875, 'accuracy_ratio': 0.9032257160407494}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.65625, 'accuracy_difference': 2.34375, 'accuracy_ratio': 0.9765624023437597}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 21.19140625, 'accuracy_ratio': 0.7876711539554538}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 93.1640625, 'accuracy_difference': 6.73828125, 'accuracy_ratio': 0.9325512263018128}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 91.30859375, 'accuracy_difference': 8.30078125, 'accuracy_ratio': 0.9166665746405321}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 88.0859375, 'accuracy_difference': 11.23046875, 'accuracy_ratio': 0.8869222312479483}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 59.47265625, 'accuracy_difference': 40.33203125, 'accuracy_ratio': 0.5958903512532564}}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.3671875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 87.5, 'accuracy_difference': 12.5, 'accuracy_ratio': 0.8749999125000087}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.1796875, 'accuracy_difference': 15.52734375, 'accuracy_ratio': 0.8442702385374413}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 80.859375, 'accuracy_difference': 17.87109375, 'accuracy_ratio': 0.818991014970643}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 44.3359375, 'accuracy_difference': 55.37109375, 'accuracy_ratio': 0.44466205138746906}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.40625, 'accuracy_ratio': 0.08593749140625086}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 76.85546875, 'accuracy_difference': 22.55859375, 'accuracy_ratio': 0.7730844016072271}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.7890625, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.3378905912109409}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 62.40234375, 'accuracy_difference': 37.40234375, 'accuracy_ratio': 0.6252445557484907}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 34.765625, 'accuracy_ratio': 0.6513221677812047}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.28125, 'accuracy_difference': 10.9375, 'accuracy_ratio': 0.8897636898505887}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 61.1328125, 'accuracy_difference': 38.57421875, 'accuracy_ratio': 0.6131243263624574}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.73046875, 'accuracy_difference': 51.26953125, 'accuracy_ratio': 0.4873046387695361}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 90.4296875, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.9051807500581537}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.35546875, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8935545981445402}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 73.6328125, 'accuracy_difference': 26.171875, 'accuracy_ratio': 0.7377690063135555}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 75.78125, 'accuracy_difference': 24.12109375, 'accuracy_ratio': 0.7585531987528372}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.7109375, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7901959991018919}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 42.3828125, 'accuracy_difference': 56.93359375, 'accuracy_ratio': 0.4267452864319397}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 28.41796875, 'accuracy_difference': 71.38671875, 'accuracy_ratio': 0.2847357836037728}}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'target_accuracy': 9.94140625, 'ff_frac': 0.453125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.59375, 'accuracy_difference': 41.40625, 'accuracy_ratio': 0.5859374414062558}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 52.05078125, 'accuracy_difference': 47.65625, 'accuracy_ratio': 0.5220371660562136}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 75.78125, 'accuracy_difference': 22.94921875, 'accuracy_ratio': 0.7675567966391533}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 37.5, 'accuracy_difference': 62.20703125, 'accuracy_ratio': 0.3761018231999738}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 45.60546875, 'accuracy_difference': 54.39453125, 'accuracy_ratio': 0.4560546418945358}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 8.7890625, 'accuracy_difference': 90.625, 'accuracy_ratio': 0.08840863550781505}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.3046875, 'accuracy_difference': 37.6953125, 'accuracy_ratio': 0.6230468126953187}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 50.29296875, 'accuracy_difference': 49.51171875, 'accuracy_ratio': 0.5039138438348556}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 47.16796875, 'accuracy_difference': 52.5390625, 'accuracy_ratio': 0.4730655744937171}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.57421875, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8927164454584999}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 51.26953125, 'accuracy_difference': 48.4375, 'accuracy_ratio': 0.5142017114062143}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.6953125, 'accuracy_difference': 37.3046875, 'accuracy_ratio': 0.6269530623046937}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 62.3046875, 'accuracy_difference': 37.59765625, 'accuracy_ratio': 0.623655851551946}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.828125, 'accuracy_difference': 26.171875, 'accuracy_ratio': 0.7382811761718824}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 49.70703125, 'accuracy_difference': 50.09765625, 'accuracy_ratio': 0.49804300293580867}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 63.37890625, 'accuracy_difference': 36.5234375, 'accuracy_ratio': 0.6344085386476692}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 48.6328125, 'accuracy_difference': 50.9765625, 'accuracy_ratio': 0.48823524510265776}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 54.00390625, 'accuracy_difference': 45.3125, 'accuracy_ratio': 0.5437560907761813}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 30.46875, 'accuracy_difference': 69.3359375, 'accuracy_ratio': 0.30528372675043675}}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.4921875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 35.05859375, 'accuracy_ratio': 0.6494139975586002}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 44.7265625, 'accuracy_difference': 54.98046875, 'accuracy_ratio': 0.4485797787124688}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 72.75390625, 'accuracy_difference': 25.9765625, 'accuracy_ratio': 0.736894089556919}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 25.68359375, 'accuracy_difference': 74.0234375, 'accuracy_ratio': 0.2575905716187321}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.9453125, 'accuracy_difference': 81.0546875, 'accuracy_ratio': 0.1894531060546894}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 51.7578125, 'accuracy_difference': 47.65625, 'accuracy_ratio': 0.5206286313237998}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.40625, 'accuracy_ratio': 0.08593749140625086}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 42.578125, 'accuracy_difference': 57.2265625, 'accuracy_ratio': 0.4266144386640719}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 50.9765625, 'accuracy_difference': 48.73046875, 'accuracy_ratio': 0.5112634159124645}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 84.86328125, 'accuracy_difference': 14.35546875, 'accuracy_ratio': 0.8553148744249575}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 55.078125, 'accuracy_difference': 44.62890625, 'accuracy_ratio': 0.5523995528249616}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 23.92578125, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23925778857422114}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 69.921875, 'accuracy_difference': 29.98046875, 'accuracy_ratio': 0.6999021782307105}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 66.2109375, 'accuracy_difference': 33.7890625, 'accuracy_ratio': 0.6621093087890692}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 45.5078125, 'accuracy_difference': 54.296875, 'accuracy_ratio': 0.4559686431593062}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 54.8828125, 'accuracy_difference': 45.01953125, 'accuracy_ratio': 0.5493645588905857}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 32.51953125, 'accuracy_difference': 67.08984375, 'accuracy_ratio': 0.32647055546021087}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 24.51171875, 'accuracy_difference': 74.8046875, 'accuracy_ratio': 0.24680430160003886}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 24.21875, 'accuracy_difference': 75.5859375, 'accuracy_ratio': 0.24266142382727024}}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.390625, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 89.16015625, 'accuracy_difference': 10.83984375, 'accuracy_ratio': 0.8916014733398526}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.0859375, 'accuracy_ratio': 0.8687560343186895}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.84375, 'accuracy_difference': 8.88671875, 'accuracy_ratio': 0.9099900166340478}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 38.57421875, 'accuracy_difference': 61.1328125, 'accuracy_ratio': 0.3868755733437231}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.09375, 'accuracy_difference': 53.90625, 'accuracy_ratio': 0.46093745390625457}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 77.05078125, 'accuracy_difference': 22.36328125, 'accuracy_ratio': 0.7750490379518453}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 59.765625, 'accuracy_difference': 40.234375, 'accuracy_ratio': 0.597656190234381}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 90.13671875, 'accuracy_ratio': 0.0968688748342732}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.7265625, 'accuracy_difference': 29.98046875, 'accuracy_ratio': 0.6993143275124514}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.76953125, 'accuracy_difference': 10.44921875, 'accuracy_ratio': 0.8946849491971075}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.4453125, 'accuracy_difference': 43.26171875, 'accuracy_ratio': 0.5661115984624606}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 57.91015625, 'accuracy_difference': 42.08984375, 'accuracy_ratio': 0.5791015045898495}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.87109375, 'accuracy_difference': 7.03125, 'accuracy_ratio': 0.9296186752757064}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 95.99609375, 'accuracy_difference': 4.00390625, 'accuracy_ratio': 0.9599608415039158}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.3515625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8551858242944927}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.34765625, 'accuracy_difference': 18.5546875, 'accuracy_ratio': 0.8142716682488574}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 88.8671875, 'accuracy_difference': 10.7421875, 'accuracy_ratio': 0.8921567731795553}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 84.1796875, 'accuracy_difference': 15.13671875, 'accuracy_ratio': 0.8475908684431613}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 63.4765625, 'accuracy_difference': 36.328125, 'accuracy_ratio': 0.63600776406341}}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.34375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 85.05859375, 'accuracy_difference': 14.94140625, 'accuracy_ratio': 0.8505858524414147}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 96.97265625, 'accuracy_difference': 2.734375, 'accuracy_ratio': 0.9725758084311824}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 85.9375, 'accuracy_difference': 12.79296875, 'accuracy_ratio': 0.8704252333021326}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 83.49609375, 'accuracy_difference': 16.2109375, 'accuracy_ratio': 0.8374142157186918}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 73.046875, 'accuracy_difference': 26.953125, 'accuracy_ratio': 0.7304686769531323}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 87.6953125, 'accuracy_difference': 11.71875, 'accuracy_ratio': 0.8821217187335324}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 82.51953125, 'accuracy_difference': 17.48046875, 'accuracy_ratio': 0.825195229980477}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 83.0078125, 'accuracy_difference': 16.796875, 'accuracy_ratio': 0.8317024606983053}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 90.0390625, 'accuracy_ratio': 0.09696375129374325}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 81.4453125, 'accuracy_difference': 17.7734375, 'accuracy_ratio': 0.8208660589993263}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 76.26953125, 'accuracy_difference': 23.4375, 'accuracy_ratio': 0.7649362602061968}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 91.9921875, 'accuracy_difference': 8.0078125, 'accuracy_ratio': 0.9199217830078217}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 97.75390625, 'accuracy_difference': 2.1484375, 'accuracy_ratio': 0.9784945257108119}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 98.73046875, 'accuracy_difference': 1.26953125, 'accuracy_ratio': 0.9873045887695411}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 95.21484375, 'accuracy_difference': 4.58984375, 'accuracy_ratio': 0.9540116460951149}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.046875, 'accuracy_difference': 1.85546875, 'accuracy_ratio': 0.9814270767369182}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 96.77734375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9715685299131201}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 96.484375, 'accuracy_difference': 2.83203125, 'accuracy_ratio': 0.9714846612782405}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 80.859375, 'accuracy_difference': 18.9453125, 'accuracy_ratio': 0.8101760440684668}}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'target_accuracy': 9.921875, 'ff_frac': 0.546875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 2.734375, 'accuracy_difference': 97.265625, 'accuracy_ratio': 0.027343747265625273}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 0.29296875, 'accuracy_difference': 99.4140625, 'accuracy_ratio': 0.0029382954937497954}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 5.76171875, 'accuracy_difference': 92.96875, 'accuracy_ratio': 0.058358055414574804}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 2.24609375, 'accuracy_difference': 97.4609375, 'accuracy_ratio': 0.022526932118748434}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 1.07421875, 'accuracy_difference': 98.92578125, 'accuracy_ratio': 0.010742186425781357}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 5.46875, 'accuracy_difference': 93.9453125, 'accuracy_ratio': 0.055009817649307145}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.88671875, 'accuracy_difference': 91.11328125, 'accuracy_ratio': 0.08886717861328214}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 2.5390625, 'accuracy_difference': 97.265625, 'accuracy_ratio': 0.025440310562536397}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 1.07421875, 'accuracy_difference': 98.6328125, 'accuracy_ratio': 0.01077375014374925}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 8.88671875, 'accuracy_difference': 90.33203125, 'accuracy_ratio': 0.08956692010664112}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 3.80859375, 'accuracy_difference': 95.8984375, 'accuracy_ratio': 0.038197841418747346}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.3515625, 'accuracy_ratio': 0.14648436035156395}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 4.4921875, 'accuracy_difference': 95.41015625, 'accuracy_ratio': 0.04496578240029705}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 3.7109375, 'accuracy_difference': 96.2890625, 'accuracy_ratio': 0.03710937128906287}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 15.72265625, 'accuracy_difference': 84.08203125, 'accuracy_ratio': 0.15753423079109077}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 19.23828125, 'accuracy_difference': 80.6640625, 'accuracy_ratio': 0.19257085071431562}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 14.453125, 'accuracy_difference': 85.15625, 'accuracy_ratio': 0.1450980246489826}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 1.46484375, 'accuracy_difference': 97.8515625, 'accuracy_ratio': 0.014749261051795151}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 0.48828125, 'accuracy_difference': 99.31640625, 'accuracy_ratio': 0.004892367415872384}}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'target_accuracy': 9.970703125, 'ff_frac': 0.375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 92.3828125, 'accuracy_difference': 7.6171875, 'accuracy_ratio': 0.9238280326171967}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.0625, 'accuracy_difference': 10.64453125, 'accuracy_ratio': 0.8932418300999379}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 12.109375, 'accuracy_ratio': 0.8773490703852178}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.7890625, 'accuracy_difference': 40.91796875, 'accuracy_ratio': 0.589617962412459}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 58.30078125, 'accuracy_difference': 41.69921875, 'accuracy_ratio': 0.5830077541992246}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 77.5390625, 'accuracy_difference': 21.875, 'accuracy_ratio': 0.7799606288133906}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 70.5078125, 'accuracy_difference': 29.4921875, 'accuracy_ratio': 0.7050780544921945}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 44.04296875, 'accuracy_difference': 55.76171875, 'accuracy_ratio': 0.44129154091168904}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.94140625, 'accuracy_difference': 34.765625, 'accuracy_ratio': 0.6513221677812047}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 88.37890625, 'accuracy_difference': 10.83984375, 'accuracy_ratio': 0.8907479417198925}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 8.49609375, 'accuracy_difference': 91.2109375, 'accuracy_ratio': 0.08521056931874407}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 69.140625, 'accuracy_difference': 30.859375, 'accuracy_ratio': 0.6914061808593819}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 95.1171875, 'accuracy_difference': 4.78515625, 'accuracy_ratio': 0.9521015664758549}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 96.19140625, 'accuracy_difference': 3.80859375, 'accuracy_ratio': 0.9619139663086034}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 10.25390625, 'accuracy_ratio': 0.8972601840709953}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 93.06640625, 'accuracy_difference': 6.8359375, 'accuracy_ratio': 0.9315737092931106}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 85.15625, 'accuracy_difference': 14.453125, 'accuracy_ratio': 0.8549018749588706}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 88.96484375, 'accuracy_difference': 10.3515625, 'accuracy_ratio': 0.8957717878790254}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 44.43359375, 'accuracy_difference': 55.37109375, 'accuracy_ratio': 0.44520543484438696}}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.46875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 68.45703125, 'accuracy_difference': 31.54296875, 'accuracy_ratio': 0.6845702440429756}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 53.02734375, 'accuracy_difference': 46.6796875, 'accuracy_ratio': 0.531831484368713}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 73.4375, 'accuracy_difference': 25.29296875, 'accuracy_ratio': 0.7438179266400042}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 27.44140625, 'accuracy_difference': 72.265625, 'accuracy_ratio': 0.27522034458123085}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.7890625, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.3378905912109409}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 54.39453125, 'accuracy_difference': 45.01953125, 'accuracy_ratio': 0.5471512219761443}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.640625, 'accuracy_difference': 68.359375, 'accuracy_ratio': 0.31640621835937816}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 46.09375, 'accuracy_difference': 53.7109375, 'accuracy_ratio': 0.46183948405835307}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.0859375, 'accuracy_difference': 36.62109375, 'accuracy_ratio': 0.6327129629874559}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 83.203125, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.8385825926467938}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 64.16015625, 'accuracy_difference': 35.546875, 'accuracy_ratio': 0.6434867131312052}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.3984375, 'accuracy_difference': 91.6015625, 'accuracy_ratio': 0.08398436660156333}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 73.6328125, 'accuracy_difference': 26.26953125, 'accuracy_ratio': 0.7370478245613907}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.6796875, 'accuracy_difference': 28.3203125, 'accuracy_ratio': 0.7167968033203197}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4814089537218426}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 67.28515625, 'accuracy_difference': 32.6171875, 'accuracy_ratio': 0.6735092189957537}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 30.95703125, 'accuracy_difference': 68.65234375, 'accuracy_ratio': 0.31078428252518575}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 37.98828125, 'accuracy_difference': 61.328125, 'accuracy_ratio': 0.38249750327655424}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 33.59375, 'accuracy_difference': 66.2109375, 'accuracy_ratio': 0.33659487821202}}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'target_accuracy': 9.990234375, 'ff_frac': 0.4375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 18.1640625, 'accuracy_difference': 81.8359375, 'accuracy_ratio': 0.1816406068359393}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 16.30859375, 'accuracy_difference': 83.3984375, 'accuracy_ratio': 0.16356511581873862}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 46.6796875, 'accuracy_difference': 52.05078125, 'accuracy_ratio': 0.4727991608163857}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 26.171875, 'accuracy_difference': 73.53515625, 'accuracy_ratio': 0.2624877307749817}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.19921875, 'accuracy_difference': 70.80078125, 'accuracy_ratio': 0.2919921583007842}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 20.80078125, 'accuracy_difference': 78.61328125, 'accuracy_ratio': 0.20923377070182894}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 39.55078125, 'accuracy_difference': 60.44921875, 'accuracy_ratio': 0.3955077729492227}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 43.26171875, 'accuracy_difference': 56.54296875, 'accuracy_ratio': 0.4334637530462932}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 27.63671875, 'accuracy_difference': 72.0703125, 'accuracy_ratio': 0.2771792082437307}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 74.21875, 'accuracy_difference': 25.0, 'accuracy_ratio': 0.7480314206708489}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 33.88671875, 'accuracy_difference': 65.8203125, 'accuracy_ratio': 0.33986284544372636}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 43.359375, 'accuracy_difference': 56.640625, 'accuracy_ratio': 0.4335937066406293}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 9.1796875, 'accuracy_difference': 90.72265625, 'accuracy_ratio': 0.09188659881799832}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 33.69140625, 'accuracy_difference': 66.30859375, 'accuracy_ratio': 0.3369140288085971}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 34.66796875, 'accuracy_difference': 65.13671875, 'accuracy_ratio': 0.3473580865269393}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 25.9765625, 'accuracy_difference': 73.92578125, 'accuracy_ratio': 0.2600195243147612}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 46.875, 'accuracy_difference': 52.734375, 'accuracy_ratio': 0.4705881880507544}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 35.05859375, 'accuracy_difference': 64.2578125, 'accuracy_ratio': 0.3529989811729639}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 36.03515625, 'accuracy_difference': 63.76953125, 'accuracy_ratio': 0.36105671529138195}}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'target_accuracy': 10.0, 'ff_frac': 0.53125, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 7.71484375, 'accuracy_difference': 92.28515625, 'accuracy_ratio': 0.07714842978515701}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 3.515625, 'accuracy_difference': 96.19140625, 'accuracy_ratio': 0.03525954592499755}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 42.7734375, 'accuracy_difference': 55.95703125, 'accuracy_ratio': 0.4332343774844706}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.16015625, 'accuracy_difference': 85.546875, 'accuracy_ratio': 0.14201761553124012}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 11.62109375, 'accuracy_difference': 88.37890625, 'accuracy_ratio': 0.11621092587890741}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 12.59765625, 'accuracy_difference': 86.81640625, 'accuracy_ratio': 0.12671904422786823}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 21.58203125, 'accuracy_difference': 78.41796875, 'accuracy_ratio': 0.2158202909179709}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 26.66015625, 'accuracy_difference': 73.14453125, 'accuracy_ratio': 0.2671232609066322}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.05859375, 'accuracy_ratio': 0.14691477468748979}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.1015625, 'accuracy_ratio': 0.7066928421600914}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 22.55859375, 'accuracy_difference': 77.1484375, 'accuracy_ratio': 0.22624875301873426}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 23.92578125, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23925778857422114}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 11.23046875, 'accuracy_difference': 88.671875, 'accuracy_ratio': 0.11241445600074262}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 8.203125, 'accuracy_difference': 91.796875, 'accuracy_ratio': 0.08203124179687582}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.65234375, 'accuracy_difference': 81.15234375, 'accuracy_ratio': 0.18688843528632507}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 21.6796875, 'accuracy_difference': 78.22265625, 'accuracy_ratio': 0.21700877593186838}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 38.57421875, 'accuracy_difference': 61.03515625, 'accuracy_ratio': 0.3872548630834333}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1858406892526189}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 80.46875, 'accuracy_ratio': 0.1937377496685464}}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.5, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 37.5, 'accuracy_difference': 62.5, 'accuracy_ratio': 0.3749999625000037}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 24.12109375, 'accuracy_difference': 75.5859375, 'accuracy_ratio': 0.2419196623187332}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 61.5234375, 'accuracy_difference': 37.20703125, 'accuracy_ratio': 0.6231453374776631}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 11.62109375, 'accuracy_difference': 88.0859375, 'accuracy_ratio': 0.1165523879187419}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 30.56640625, 'accuracy_difference': 69.43359375, 'accuracy_ratio': 0.3056640319335968}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 18.45703125, 'accuracy_difference': 80.95703125, 'accuracy_ratio': 0.18565813456641161}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.78515625, 'accuracy_difference': 70.21484375, 'accuracy_ratio': 0.2978515327148467}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 38.8671875, 'accuracy_difference': 60.9375, 'accuracy_ratio': 0.38943244630344176}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.2265625, 'accuracy_difference': 67.48046875, 'accuracy_ratio': 0.3232125043124775}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 75.9765625, 'accuracy_difference': 23.2421875, 'accuracy_ratio': 0.7657479543183164}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 59.9609375, 'accuracy_ratio': 0.39862875531872227}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 31.25, 'accuracy_difference': 68.75, 'accuracy_ratio': 0.31249996875000313}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 55.6640625, 'accuracy_difference': 44.23828125, 'accuracy_ratio': 0.5571846949602025}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 48.33984375, 'accuracy_difference': 51.66015625, 'accuracy_ratio': 0.4833983891601611}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 9.47265625, 'accuracy_difference': 90.33203125, 'accuracy_ratio': 0.09491192786792425}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 36.03515625, 'accuracy_difference': 63.8671875, 'accuracy_ratio': 0.3607037762110785}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 11.23046875, 'accuracy_difference': 88.37890625, 'accuracy_ratio': 0.11274508672049326}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 23.2421875, 'accuracy_difference': 76.07421875, 'accuracy_ratio': 0.23402160868848304}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 39.74609375, 'accuracy_difference': 60.05859375, 'accuracy_ratio': 0.3982387076520121}}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'target_accuracy': 9.990234375, 'ff_frac': 0.484375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 12.20703125, 'accuracy_difference': 87.79296875, 'accuracy_ratio': 0.12207030029296996}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 14.16015625, 'accuracy_difference': 85.546875, 'accuracy_ratio': 0.14201761553124012}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 44.921875, 'accuracy_difference': 53.80859375, 'accuracy_ratio': 0.4549950083170239}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 12.40234375, 'accuracy_difference': 87.3046875, 'accuracy_ratio': 0.12438784256874134}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.21484375, 'accuracy_difference': 79.78515625, 'accuracy_ratio': 0.20214841728515826}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 13.28125, 'accuracy_difference': 86.1328125, 'accuracy_ratio': 0.13359527143403163}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 20.01953125, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.20019529248047074}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 28.90625, 'accuracy_difference': 70.8984375, 'accuracy_ratio': 0.2896281510196451}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 19.140625, 'accuracy_difference': 80.56640625, 'accuracy_ratio': 0.19196863892498664}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 68.9453125, 'accuracy_difference': 30.2734375, 'accuracy_ratio': 0.6948818197284465}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 17.578125, 'accuracy_difference': 82.12890625, 'accuracy_ratio': 0.17629772962498774}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 32.32421875, 'accuracy_difference': 67.67578125, 'accuracy_ratio': 0.3232421551757845}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 26.85546875, 'accuracy_difference': 73.046875, 'accuracy_ratio': 0.2688171773930802}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 25.0, 'accuracy_difference': 75.0, 'accuracy_ratio': 0.24999997500000248}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 13.76953125, 'accuracy_difference': 86.03515625, 'accuracy_ratio': 0.13796476112760123}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 8.984375, 'accuracy_difference': 90.91796875, 'accuracy_ratio': 0.0899315648005941}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 27.9296875, 'accuracy_difference': 71.6796875, 'accuracy_ratio': 0.2803921287135745}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 19.3359375, 'accuracy_difference': 79.98046875, 'accuracy_ratio': 0.194690245883696}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 14.6484375, 'accuracy_difference': 85.15625, 'accuracy_ratio': 0.14677102247617152}}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'target_accuracy': 9.9609375, 'ff_frac': 0.375, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 93.5546875, 'accuracy_difference': 6.4453125, 'accuracy_ratio': 0.9355467814453218}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 94.53125, 'accuracy_difference': 5.17578125, 'accuracy_ratio': 0.9480900126499341}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 89.55078125, 'accuracy_difference': 9.1796875, 'accuracy_ratio': 0.9070226578841541}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 90.234375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.904995012074937}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 90.52734375, 'accuracy_difference': 9.47265625, 'accuracy_ratio': 0.9052733469726653}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 83.3984375, 'accuracy_difference': 16.015625, 'accuracy_ratio': 0.838899719151934}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.46484375, 'accuracy_difference': 23.53515625, 'accuracy_ratio': 0.7646483610351639}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 94.23828125, 'accuracy_difference': 5.56640625, 'accuracy_ratio': 0.9442269112633701}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 89.74609375, 'accuracy_difference': 9.9609375, 'accuracy_ratio': 0.9000978529186874}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 94.53125, 'accuracy_difference': 4.6875, 'accuracy_ratio': 0.9527558094860287}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 84.375, 'accuracy_difference': 15.33203125, 'accuracy_ratio': 0.8462291021999412}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 71.19140625, 'accuracy_difference': 28.80859375, 'accuracy_ratio': 0.7119139913086009}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 98.14453125, 'accuracy_difference': 1.7578125, 'accuracy_ratio': 0.9824045937456203}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 97.0703125, 'accuracy_difference': 2.9296875, 'accuracy_ratio': 0.9707030279296972}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 67.87109375, 'accuracy_difference': 31.93359375, 'accuracy_ratio': 0.6800390708062614}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 92.48046875, 'accuracy_difference': 7.421875, 'accuracy_ratio': 0.925708607240898}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 9.66796875, 'accuracy_difference': 89.94140625, 'accuracy_ratio': 0.0970588137854681}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 90.625, 'accuracy_difference': 8.69140625, 'accuracy_ratio': 0.91248761707106}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 85.7421875, 'accuracy_difference': 14.0625, 'accuracy_ratio': 0.8590997182271907}}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'target_accuracy': 9.931640625, 'ff_frac': 0.421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 76.07421875, 'accuracy_difference': 23.92578125, 'accuracy_ratio': 0.7607421114257888}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 69.3359375, 'accuracy_difference': 30.37109375, 'accuracy_ratio': 0.6953966001874516}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 69.82421875, 'accuracy_difference': 28.90625, 'accuracy_ratio': 0.7072205020579827}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 32.8125, 'accuracy_difference': 66.89453125, 'accuracy_ratio': 0.3290890952999771}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 29.6875, 'accuracy_difference': 70.3125, 'accuracy_ratio': 0.296874970312503}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 63.671875, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6404714483455046}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 46.2890625, 'accuracy_difference': 53.7109375, 'accuracy_ratio': 0.46289057871094214}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 48.046875, 'accuracy_difference': 51.7578125, 'accuracy_ratio': 0.4814089537218426}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 58.88671875, 'accuracy_difference': 40.8203125, 'accuracy_ratio': 0.5905973942437089}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 71.97265625, 'accuracy_difference': 27.24609375, 'accuracy_ratio': 0.7253936276768627}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 56.93359375, 'accuracy_difference': 42.7734375, 'accuracy_ratio': 0.5710087576187103}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 52.44140625, 'accuracy_difference': 47.55859375, 'accuracy_ratio': 0.524414010058599}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 81.8359375, 'accuracy_difference': 18.06640625, 'accuracy_ratio': 0.8191592532923679}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 80.37109375, 'accuracy_difference': 19.62890625, 'accuracy_ratio': 0.8037108571289142}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 70.1171875, 'accuracy_difference': 29.6875, 'accuracy_ratio': 0.7025439609192743}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 74.0234375, 'accuracy_difference': 25.87890625, 'accuracy_ratio': 0.7409578925961992}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 57.2265625, 'accuracy_difference': 42.3828125, 'accuracy_ratio': 0.574509746245296}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 9.27734375, 'accuracy_difference': 90.0390625, 'accuracy_ratio': 0.09341198666136928}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 18.9453125, 'accuracy_difference': 80.859375, 'accuracy_ratio': 0.1898238557358485}}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'target_accuracy': 9.98046875, 'ff_frac': 0.421875, 'cifar20-veh2': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 81.15234375, 'accuracy_difference': 18.84765625, 'accuracy_ratio': 0.8115233563476644}, 'cifar20-veh1': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 79.98046875, 'accuracy_difference': 19.7265625, 'accuracy_ratio': 0.8021546697936942}, 'cifar20-trees': {'unpruned_accuracy': 98.73046875, 'pruned_accuracy': 77.83203125, 'accuracy_difference': 20.8984375, 'accuracy_ratio': 0.7883283078884088}, 'cifar20-small_mammals': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 33.69140625, 'accuracy_difference': 66.015625, 'accuracy_ratio': 0.3379039817812265}, 'cifar20-reptiles': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 36.5234375, 'accuracy_difference': 63.4765625, 'accuracy_ratio': 0.36523433847656617}, 'cifar20-people': {'unpruned_accuracy': 99.4140625, 'pruned_accuracy': 71.875, 'accuracy_difference': 27.5390625, 'accuracy_ratio': 0.7229861748194653}, 'cifar20-non_insect_invertebrates': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 62.01171875, 'accuracy_difference': 37.98828125, 'accuracy_ratio': 0.6201171254882875}, 'cifar20-medium_sized_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 61.9140625, 'accuracy_difference': 37.890625, 'accuracy_ratio': 0.6203521883326183}, 'cifar20-large_omnivores_and_herbivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 63.96484375, 'accuracy_difference': 35.7421875, 'accuracy_ratio': 0.6415278494687053}, 'cifar20-large_natural_outdoor_scenes': {'unpruned_accuracy': 99.21875, 'pruned_accuracy': 67.7734375, 'accuracy_difference': 31.4453125, 'accuracy_ratio': 0.6830707972968015}, 'cifar20-large_carnivores': {'unpruned_accuracy': 99.70703125, 'pruned_accuracy': 59.86328125, 'accuracy_difference': 39.84375, 'accuracy_ratio': 0.6003917125562083}, 'cifar20-insects': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 63.76953125, 'accuracy_difference': 36.23046875, 'accuracy_ratio': 0.6376952487304751}, 'cifar20-household_furniture': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 88.8671875, 'accuracy_difference': 11.03515625, 'accuracy_ratio': 0.8895404779189199}, 'cifar20-household_electrical_devices': {'unpruned_accuracy': 100.0, 'pruned_accuracy': 86.62109375, 'accuracy_difference': 13.37890625, 'accuracy_ratio': 0.8662108508789149}, 'cifar20-fruit_and_vegetables': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 71.6796875, 'accuracy_difference': 28.125, 'accuracy_ratio': 0.718199536650066}, 'cifar20-food_containers': {'unpruned_accuracy': 99.90234375, 'pruned_accuracy': 75.29296875, 'accuracy_difference': 24.609375, 'accuracy_ratio': 0.7536656137093266}, 'cifar20-flowers': {'unpruned_accuracy': 99.609375, 'pruned_accuracy': 78.61328125, 'accuracy_difference': 20.99609375, 'accuracy_ratio': 0.7892156070434527}, 'cifar20-fish': {'unpruned_accuracy': 99.31640625, 'pruned_accuracy': 44.140625, 'accuracy_difference': 55.17578125, 'accuracy_ratio': 0.4444443996940939}, 'cifar20-aquatic_mammals': {'unpruned_accuracy': 99.8046875, 'pruned_accuracy': 8.59375, 'accuracy_difference': 91.2109375, 'accuracy_ratio': 0.08610566651935396}}}

# %%
data = {
time to get data for dataset:  pile_ArXiv is  2:20:45.062856 results:  {'unpruned_accuracy': 56.06822439120576, 'target_accuracy': 28.03411219560288, 'ff_frac': 0.171875, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 27.32919254658385, 'accuracy_difference': 28.73903184462191, 'accuracy_ratio': 0.4874274661508704}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 38.60797144556811, 'accuracy_difference': 16.26016260162602, 'accuracy_ratio': 0.7036501626310082}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 20.626607864755606, 'accuracy_difference': 40.83976479235575, 'accuracy_ratio': 0.33557548579970103}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 43.09075260590992, 'accuracy_difference': 22.453858659271297, 'accuracy_ratio': 0.6574263203968486}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 54.798394453566864, 'accuracy_difference': 21.65663200145959, 'accuracy_ratio': 0.7167402457940579}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 31.495131495131496, 'accuracy_difference': 24.151424151424152, 'accuracy_ratio': 0.5659852820932134}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 37.608420231946205, 'accuracy_difference': 21.98616119286619, 'accuracy_ratio': 0.6310711365494686}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 38.34743834743835, 'accuracy_difference': 25.261625261625262, 'accuracy_ratio': 0.6028612303290415}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 44.18376362030038, 'accuracy_difference': 17.541965249828216, 'accuracy_ratio': 0.7158078880407124}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 36.83683683683684, 'accuracy_difference': 19.84711984711985, 'accuracy_ratio': 0.6498635414994381}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 36.90113133300541, 'accuracy_difference': 15.061485489424498, 'accuracy_ratio': 0.7101476713366148}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 37.06724841126814, 'accuracy_difference': 19.169116949634827, 'accuracy_ratio': 0.6591330747174903}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 36.65553080920564, 'accuracy_difference': 22.132516703786187, 'accuracy_ratio': 0.6235201262825573}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 45.96750656678665, 'accuracy_difference': 17.98813114116159, 'accuracy_ratio': 0.7187404928506237}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 42.45771144278607, 'accuracy_difference': 20.388059701492537, 'accuracy_ratio': 0.6755858138062064}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 59.45787259027302, 'accuracy_difference': 16.508464624718663, 'accuracy_ratio': 0.7826871055004508}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 47.78668193092921, 'accuracy_difference': 31.25357756153405, 'accuracy_ratio': 0.6045866022933012}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 52.44590780809031, 'accuracy_difference': 33.08560677328316, 'accuracy_ratio': 0.6131764188297404}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 60.8421052631579, 'accuracy_difference': 20.471869328493646, 'accuracy_ratio': 0.7482367645745915}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 0.0, 'accuracy_difference': 28.0, 'accuracy_ratio': 0.0}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 2.962962962962963, 'accuracy_difference': 49.62962962962963, 'accuracy_ratio': 0.05633802816901408}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 3.9473684210526314, 'accuracy_difference': 54.60526315789474, 'accuracy_ratio': 0.06741573033707865}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 11.0, 'accuracy_difference': 47.0, 'accuracy_ratio': 0.1896551724137931}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 11.69811320754717, 'accuracy_difference': 52.45283018867924, 'accuracy_ratio': 0.1823529411764706}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 7.638888888888889, 'accuracy_difference': 56.94444444444444, 'accuracy_ratio': 0.11827956989247314}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 1.0, 'accuracy_difference': 39.0, 'accuracy_ratio': 0.025}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 8.0, 'accuracy_difference': 46.0, 'accuracy_ratio': 0.14814814814814814}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 0.0, 'accuracy_difference': 34.0, 'accuracy_ratio': 0.0}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 9.248554913294798, 'accuracy_difference': 41.040462427745666, 'accuracy_ratio': 0.18390804597701152}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 2.9411764705882355, 'accuracy_difference': 37.25490196078431, 'accuracy_ratio': 0.07317073170731708}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 19.0, 'accuracy_difference': 46.0, 'accuracy_ratio': 0.2923076923076923}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 4.680851063829787, 'accuracy_difference': 43.40425531914894, 'accuracy_ratio': 0.09734513274336283}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 0.0, 'accuracy_difference': 44.73684210526316, 'accuracy_ratio': 0.0}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 4.827586206896552, 'accuracy_difference': 53.79310344827586, 'accuracy_ratio': 0.08235294117647059}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 0.26455026455026454, 'accuracy_difference': 40.476190476190474, 'accuracy_ratio': 0.006493506493506493}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 3.1746031746031744, 'accuracy_difference': 36.507936507936506, 'accuracy_ratio': 0.07999999999999999}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 1.0, 'accuracy_difference': 32.0, 'accuracy_ratio': 0.030303030303030304}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 7.419354838709677, 'accuracy_difference': 59.03225806451613, 'accuracy_ratio': 0.1116504854368932}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 2.4630541871921183, 'accuracy_difference': 44.82758620689655, 'accuracy_ratio': 0.052083333333333336}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 10.0, 'accuracy_difference': 52.0, 'accuracy_ratio': 0.16129032258064516}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 12.727272727272727, 'accuracy_difference': 55.75757575757576, 'accuracy_ratio': 0.18584070796460175}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 9.090909090909092, 'accuracy_difference': 61.111111111111114, 'accuracy_ratio': 0.12949640287769784}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 15.544041450777202, 'accuracy_difference': 66.83937823834196, 'accuracy_ratio': 0.18867924528301888}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 6.410256410256411, 'accuracy_difference': 48.46153846153846, 'accuracy_ratio': 0.11682242990654207}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 0.37037037037037035, 'accuracy_difference': 35.18518518518518, 'accuracy_ratio': 0.010416666666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 8.403361344537815, 'accuracy_difference': 52.10084033613445, 'accuracy_ratio': 0.1388888888888889}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 1.3245033112582782, 'accuracy_difference': 33.77483443708609, 'accuracy_ratio': 0.03773584905660378}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 6.7889908256880735, 'accuracy_difference': 67.5229357798165, 'accuracy_ratio': 0.09135802469135804}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 4.62962962962963, 'accuracy_difference': 39.81481481481481, 'accuracy_ratio': 0.10416666666666667}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 13.235294117647058, 'accuracy_difference': 64.2156862745098, 'accuracy_ratio': 0.17088607594936708}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 13.924050632911392, 'accuracy_difference': 61.60337552742617, 'accuracy_ratio': 0.18435754189944134}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 10.762331838565023, 'accuracy_difference': 50.22421524663677, 'accuracy_ratio': 0.17647058823529413}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 12.977099236641221, 'accuracy_difference': 56.488549618320604, 'accuracy_ratio': 0.18681318681318682}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 13.223140495867769, 'accuracy_difference': 61.15702479338843, 'accuracy_ratio': 0.17777777777777778}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 10.185185185185185, 'accuracy_difference': 59.25925925925926, 'accuracy_ratio': 0.14666666666666667}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 17.177914110429448, 'accuracy_difference': 54.60122699386503, 'accuracy_ratio': 0.2393162393162393}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 2.6785714285714284, 'accuracy_difference': 44.64285714285714, 'accuracy_ratio': 0.05660377358490566}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 8.737864077669903, 'accuracy_difference': 62.13592233009708, 'accuracy_ratio': 0.12328767123287672}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 14.102564102564102, 'accuracy_difference': 70.08547008547009, 'accuracy_ratio': 0.16751269035532992}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 17.0, 'accuracy_difference': 46.0, 'accuracy_ratio': 0.2698412698412698}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 10.727969348659004, 'accuracy_difference': 64.24010217113666, 'accuracy_ratio': 0.14310051107325383}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 2.601156069364162, 'accuracy_difference': 63.87283236994219, 'accuracy_ratio': 0.0391304347826087}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 4.4692737430167595, 'accuracy_difference': 30.391061452513963, 'accuracy_ratio': 0.12820512820512822}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 9.477124183006536, 'accuracy_difference': 55.55555555555556, 'accuracy_ratio': 0.1457286432160804}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 7.717041800643087, 'accuracy_difference': 54.662379421221864, 'accuracy_ratio': 0.12371134020618557}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 14.197530864197532, 'accuracy_difference': 51.23456790123457, 'accuracy_ratio': 0.2169811320754717}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 5.673758865248227, 'accuracy_difference': 40.780141843971634, 'accuracy_ratio': 0.12213740458015268}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 6.97522816166884, 'accuracy_difference': 36.17992177314211, 'accuracy_ratio': 0.16163141993957705}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 4.779411764705882, 'accuracy_difference': 55.51470588235294, 'accuracy_ratio': 0.07926829268292683}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 13.235294117647058, 'accuracy_difference': 44.44444444444444, 'accuracy_ratio': 0.22946175637393768}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 7.2727272727272725, 'accuracy_difference': 58.18181818181818, 'accuracy_ratio': 0.1111111111111111}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 16.73469387755102, 'accuracy_difference': 50.61224489795919, 'accuracy_ratio': 0.24848484848484845}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 19.90049751243781, 'accuracy_difference': 62.68656716417911, 'accuracy_ratio': 0.24096385542168672}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 12.0, 'accuracy_difference': 68.0, 'accuracy_ratio': 0.15}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 4.819277108433735, 'accuracy_difference': 41.56626506024096, 'accuracy_ratio': 0.10389610389610392}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 8.187134502923977, 'accuracy_difference': 73.09941520467835, 'accuracy_ratio': 0.10071942446043167}}
time to get data for dataset:  pile_Enron_Emails is  2:21:04.775185 results:  {'unpruned_accuracy': 54.86813404719413, 'target_accuracy': 27.434067023597066, 'ff_frac': 0.052000000000000005, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 39.34733313615301, 'accuracy_difference': 16.72089125505275, 'accuracy_ratio': 0.7017759803059609}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 27.404322823716043, 'accuracy_difference': 27.46381122347809, 'accuracy_ratio': 0.4994578966389592}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 22.344726203601617, 'accuracy_difference': 39.12164645350974, 'accuracy_ratio': 0.36352765321375186}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 34.61795926173855, 'accuracy_difference': 30.92665200344267, 'accuracy_ratio': 0.5281587394222352}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 41.47053457398285, 'accuracy_difference': 34.9844918810436, 'accuracy_ratio': 0.5424173726285646}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 33.77923377923378, 'accuracy_difference': 21.86732186732187, 'accuracy_ratio': 0.6070318887980376}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 40.658805184679856, 'accuracy_difference': 18.93577624013254, 'accuracy_ratio': 0.6822567457072772}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 43.3979433979434, 'accuracy_difference': 20.21112021112021, 'accuracy_ratio': 0.6822603719599428}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 42.043781289879256, 'accuracy_difference': 19.681947580249343, 'accuracy_ratio': 0.6811386768447837}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 26.863226863226863, 'accuracy_difference': 29.820729820729824, 'accuracy_ratio': 0.4739123454808155}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 32.32661091982292, 'accuracy_difference': 19.63600590260699, 'accuracy_ratio': 0.6221128360469519}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 40.26368206392867, 'accuracy_difference': 15.972683296974296, 'accuracy_ratio': 0.7159723393489628}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 33.351893095768375, 'accuracy_difference': 25.436154417223456, 'accuracy_ratio': 0.5673243883188634}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 49.508707072672436, 'accuracy_difference': 14.446930635275805, 'accuracy_ratio': 0.7741101308183754}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 38.33830845771144, 'accuracy_difference': 24.507462686567166, 'accuracy_ratio': 0.6100379987333755}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 61.033369214208825, 'accuracy_difference': 14.932968000782857, 'accuracy_ratio': 0.8034265103697024}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 53.38675825224194, 'accuracy_difference': 25.653501240221324, 'accuracy_ratio': 0.6754375377187689}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 63.33960489181562, 'accuracy_difference': 22.191909689557853, 'accuracy_ratio': 0.7405411350637924}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 49.401088929219604, 'accuracy_difference': 31.91288566243194, 'accuracy_ratio': 0.6075350415141506}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 0.0, 'accuracy_difference': 28.0, 'accuracy_ratio': 0.0}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 14.074074074074074, 'accuracy_difference': 38.51851851851852, 'accuracy_ratio': 0.2676056338028169}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 9.210526315789474, 'accuracy_difference': 49.3421052631579, 'accuracy_ratio': 0.15730337078651685}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 4.0, 'accuracy_difference': 54.0, 'accuracy_ratio': 0.06896551724137931}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 6.7924528301886795, 'accuracy_difference': 57.35849056603773, 'accuracy_ratio': 0.10588235294117648}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 12.5, 'accuracy_difference': 52.08333333333333, 'accuracy_ratio': 0.19354838709677422}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 5.0, 'accuracy_difference': 35.0, 'accuracy_ratio': 0.125}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 7.0, 'accuracy_difference': 47.0, 'accuracy_ratio': 0.12962962962962962}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 1.0, 'accuracy_difference': 33.0, 'accuracy_ratio': 0.029411764705882353}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 5.202312138728324, 'accuracy_difference': 45.08670520231214, 'accuracy_ratio': 0.10344827586206896}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 3.9215686274509802, 'accuracy_difference': 36.27450980392157, 'accuracy_ratio': 0.0975609756097561}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 3.0, 'accuracy_difference': 62.0, 'accuracy_ratio': 0.046153846153846156}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 4.680851063829787, 'accuracy_difference': 43.40425531914894, 'accuracy_ratio': 0.09734513274336283}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 0.8771929824561403, 'accuracy_difference': 43.85964912280702, 'accuracy_ratio': 0.0196078431372549}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 4.827586206896552, 'accuracy_difference': 53.79310344827586, 'accuracy_ratio': 0.08235294117647059}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 3.7037037037037037, 'accuracy_difference': 37.03703703703704, 'accuracy_ratio': 0.09090909090909091}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 7.142857142857143, 'accuracy_difference': 32.53968253968254, 'accuracy_ratio': 0.18}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 1.0, 'accuracy_difference': 32.0, 'accuracy_ratio': 0.030303030303030304}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 10.64516129032258, 'accuracy_difference': 55.80645161290323, 'accuracy_ratio': 0.16019417475728154}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 10.344827586206897, 'accuracy_difference': 36.94581280788177, 'accuracy_ratio': 0.21875}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 12.0, 'accuracy_difference': 50.0, 'accuracy_ratio': 0.1935483870967742}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 3.6363636363636362, 'accuracy_difference': 64.84848484848484, 'accuracy_ratio': 0.05309734513274336}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 3.5353535353535355, 'accuracy_difference': 66.66666666666667, 'accuracy_ratio': 0.050359712230215826}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 6.217616580310881, 'accuracy_difference': 76.16580310880829, 'accuracy_ratio': 0.07547169811320754}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 6.666666666666667, 'accuracy_difference': 48.205128205128204, 'accuracy_ratio': 0.12149532710280375}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 0.7407407407407407, 'accuracy_difference': 34.81481481481482, 'accuracy_ratio': 0.020833333333333332}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 5.882352941176471, 'accuracy_difference': 54.621848739495796, 'accuracy_ratio': 0.09722222222222224}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 7.947019867549669, 'accuracy_difference': 27.152317880794698, 'accuracy_ratio': 0.22641509433962265}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 6.605504587155964, 'accuracy_difference': 67.70642201834862, 'accuracy_ratio': 0.0888888888888889}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 10.648148148148149, 'accuracy_difference': 33.79629629629629, 'accuracy_ratio': 0.23958333333333337}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 3.4313725490196076, 'accuracy_difference': 74.01960784313725, 'accuracy_ratio': 0.044303797468354424}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 4.641350210970464, 'accuracy_difference': 70.8860759493671, 'accuracy_ratio': 0.061452513966480445}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 3.587443946188341, 'accuracy_difference': 57.39910313901345, 'accuracy_ratio': 0.05882352941176471}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 5.343511450381679, 'accuracy_difference': 64.12213740458014, 'accuracy_ratio': 0.07692307692307693}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 3.3057851239669422, 'accuracy_difference': 71.07438016528926, 'accuracy_ratio': 0.044444444444444446}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 0.9259259259259259, 'accuracy_difference': 68.51851851851852, 'accuracy_ratio': 0.013333333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 4.294478527607362, 'accuracy_difference': 67.48466257668711, 'accuracy_ratio': 0.059829059829059825}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 2.6785714285714284, 'accuracy_difference': 44.64285714285714, 'accuracy_ratio': 0.05660377358490566}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 0.970873786407767, 'accuracy_difference': 69.90291262135922, 'accuracy_ratio': 0.013698630136986302}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 2.1367521367521367, 'accuracy_difference': 82.05128205128206, 'accuracy_ratio': 0.025380710659898473}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 8.0, 'accuracy_difference': 55.0, 'accuracy_ratio': 0.12698412698412698}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 5.747126436781609, 'accuracy_difference': 69.22094508301404, 'accuracy_ratio': 0.0766609880749574}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 4.046242774566474, 'accuracy_difference': 62.42774566473988, 'accuracy_ratio': 0.060869565217391314}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 4.134078212290503, 'accuracy_difference': 30.72625698324022, 'accuracy_ratio': 0.11858974358974361}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 7.189542483660131, 'accuracy_difference': 57.84313725490196, 'accuracy_ratio': 0.11055276381909547}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 4.823151125401929, 'accuracy_difference': 57.556270096463024, 'accuracy_ratio': 0.07731958762886598}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 3.0864197530864197, 'accuracy_difference': 62.345679012345684, 'accuracy_ratio': 0.04716981132075471}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 3.5460992907801416, 'accuracy_difference': 42.90780141843972, 'accuracy_ratio': 0.07633587786259541}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 8.670143415906129, 'accuracy_difference': 34.485006518904825, 'accuracy_ratio': 0.20090634441087615}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 20.58823529411765, 'accuracy_difference': 39.705882352941174, 'accuracy_ratio': 0.34146341463414637}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 4.901960784313726, 'accuracy_difference': 52.77777777777777, 'accuracy_ratio': 0.084985835694051}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 3.6363636363636362, 'accuracy_difference': 61.81818181818182, 'accuracy_ratio': 0.05555555555555555}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 0.40816326530612246, 'accuracy_difference': 66.93877551020408, 'accuracy_ratio': 0.00606060606060606}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 4.975124378109452, 'accuracy_difference': 77.61194029850746, 'accuracy_ratio': 0.06024096385542168}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 2.0, 'accuracy_difference': 78.0, 'accuracy_ratio': 0.025}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 6.626506024096385, 'accuracy_difference': 39.75903614457831, 'accuracy_ratio': 0.14285714285714285}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 0.0, 'accuracy_difference': 81.28654970760233, 'accuracy_ratio': 0.0}}
time to get data for dataset:  pile_EuroParl is  2:21:01.367287 results:  {'unpruned_accuracy': 61.46637265711136, 'target_accuracy': 30.73318632855568, 'ff_frac': 0.014, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 55.68372276446811, 'accuracy_difference': 0.3845016267376522, 'accuracy_ratio': 0.9931422542641111}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 54.67975411461432, 'accuracy_difference': 0.18837993257981367, 'accuracy_ratio': 0.996566678713408}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 30.319735391400222, 'accuracy_difference': 31.146637265711135, 'accuracy_ratio': 0.4932735426008969}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 65.06646265659367, 'accuracy_difference': 0.4781486085875457, 'accuracy_ratio': 0.9927049897869857}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 76.24521072796935, 'accuracy_difference': 0.20981572705710505, 'accuracy_ratio': 0.9972556974108102}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 51.123851123851125, 'accuracy_difference': 4.522704522704522, 'accuracy_ratio': 0.9187244480784955}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 59.23399278822727, 'accuracy_difference': 0.36058863658512763, 'accuracy_ratio': 0.993949304987735}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 63.34516334516334, 'accuracy_difference': 0.26390026390026833, 'accuracy_ratio': 0.9958512160228897}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 61.391970158044565, 'accuracy_difference': 0.33375871208403396, 'accuracy_ratio': 0.9945928753180661}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 56.01055601055601, 'accuracy_difference': 0.6734006734006783, 'accuracy_ratio': 0.9881200834804944}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 51.68716182980817, 'accuracy_difference': 0.27545499262173934, 'accuracy_ratio': 0.9946989776599773}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 56.10357583230579, 'accuracy_difference': 0.13278952859717208, 'accuracy_ratio': 0.9976387249114522}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 55.07609502598367, 'accuracy_difference': 3.711952487008162, 'accuracy_ratio': 0.9368587213891082}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 64.02373771767682, 'accuracy_difference': -0.06810000972858177, 'accuracy_ratio': 1.0010648007301493}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 62.08955223880597, 'accuracy_difference': 0.756218905472636, 'accuracy_ratio': 0.9879670677644079}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 75.62383794891868, 'accuracy_difference': 0.3424992660730055, 'accuracy_ratio': 0.9954914337240757}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 79.05933982064491, 'accuracy_difference': -0.01908032818164429, 'accuracy_ratio': 1.0002414001207}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 85.75729068673566, 'accuracy_difference': -0.22577610536218629, 'accuracy_ratio': 1.0026396832380116}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 81.03085299455536, 'accuracy_difference': 0.28312159709618356, 'accuracy_ratio': 0.9965181680207125}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 29.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0357142857142858}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 53.333333333333336, 'accuracy_difference': -0.7407407407407405, 'accuracy_ratio': 1.0140845070422535}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 58.55263157894737, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 57.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9827586206896551}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 64.15094339622641, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 63.888888888888886, 'accuracy_difference': 0.6944444444444429, 'accuracy_ratio': 0.989247311827957}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 40.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 56.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.037037037037037}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 32.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9411764705882353}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 47.39884393063584, 'accuracy_difference': 2.8901734104046213, 'accuracy_ratio': 0.942528735632184}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 40.19607843137255, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 67.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.0307692307692307}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 46.808510638297875, 'accuracy_difference': 1.2765957446808471, 'accuracy_ratio': 0.9734513274336284}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 43.85964912280702, 'accuracy_difference': 0.8771929824561369, 'accuracy_ratio': 0.9803921568627452}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 58.62068965517241, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 39.94708994708995, 'accuracy_difference': 0.7936507936507908, 'accuracy_ratio': 0.9805194805194806}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 42.06349206349206, 'accuracy_difference': -2.3809523809523796, 'accuracy_ratio': 1.06}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 34.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0303030303030303}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 64.83870967741936, 'accuracy_difference': 1.6129032258064484, 'accuracy_ratio': 0.9757281553398058}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 45.320197044334975, 'accuracy_difference': 1.970443349753694, 'accuracy_ratio': 0.9583333333333334}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 63.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0161290322580645}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 69.6969696969697, 'accuracy_difference': -1.2121212121212182, 'accuracy_ratio': 1.0176991150442478}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 70.20202020202021, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 81.34715025906736, 'accuracy_difference': 1.036269430051803, 'accuracy_ratio': 0.9874213836477989}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 53.58974358974359, 'accuracy_difference': 1.2820512820512775, 'accuracy_ratio': 0.9766355140186916}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 34.81481481481482, 'accuracy_difference': 0.7407407407407405, 'accuracy_ratio': 0.9791666666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 59.66386554621849, 'accuracy_difference': 0.8403361344537785, 'accuracy_ratio': 0.9861111111111112}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 34.437086092715234, 'accuracy_difference': 0.6622516556291345, 'accuracy_ratio': 0.9811320754716982}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 74.31192660550458, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 43.05555555555556, 'accuracy_difference': 1.3888888888888857, 'accuracy_ratio': 0.9687500000000001}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 76.96078431372548, 'accuracy_difference': 0.49019607843138147, 'accuracy_ratio': 0.9936708860759492}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 77.21518987341773, 'accuracy_difference': -1.687763713080173, 'accuracy_ratio': 1.0223463687150838}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 61.88340807174888, 'accuracy_difference': -0.8968609865470896, 'accuracy_ratio': 1.0147058823529413}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 70.22900763358778, 'accuracy_difference': -0.7633587786259568, 'accuracy_ratio': 1.010989010989011}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 73.55371900826447, 'accuracy_difference': 0.8264462809917319, 'accuracy_ratio': 0.9888888888888889}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 67.5925925925926, 'accuracy_difference': 1.8518518518518476, 'accuracy_ratio': 0.9733333333333334}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 71.77914110429448, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 45.535714285714285, 'accuracy_difference': 1.7857142857142847, 'accuracy_ratio': 0.9622641509433962}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 71.84466019417475, 'accuracy_difference': -0.9708737864077648, 'accuracy_ratio': 1.0136986301369864}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 84.1880341880342, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 63.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 75.09578544061303, 'accuracy_difference': -0.12771392081737076, 'accuracy_ratio': 1.001703577512777}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 67.91907514450867, 'accuracy_difference': -1.4450867052023142, 'accuracy_ratio': 1.0217391304347827}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 34.97206703910614, 'accuracy_difference': -0.11173184357541999, 'accuracy_ratio': 1.0032051282051282}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.70096463022508, 'accuracy_difference': -0.32154340836012807, 'accuracy_ratio': 1.0051546391752577}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 65.12345679012346, 'accuracy_difference': 0.308641975308646, 'accuracy_ratio': 0.9952830188679245}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 44.680851063829785, 'accuracy_difference': 1.7730496453900741, 'accuracy_ratio': 0.9618320610687022}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 43.35071707953064, 'accuracy_difference': -0.19556714471968917, 'accuracy_ratio': 1.0045317220543808}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 59.55882352941177, 'accuracy_difference': 0.735294117647058, 'accuracy_ratio': 0.9878048780487805}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 57.35294117647059, 'accuracy_difference': 0.32679738562091387, 'accuracy_ratio': 0.9943342776203966}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 66.36363636363636, 'accuracy_difference': -0.9090909090909065, 'accuracy_ratio': 1.0138888888888888}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 66.53061224489795, 'accuracy_difference': 0.8163265306122582, 'accuracy_ratio': 0.9878787878787877}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 83.08457711442786, 'accuracy_difference': -0.4975124378109399, 'accuracy_ratio': 1.006024096385542}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 81.0, 'accuracy_difference': -1.0, 'accuracy_ratio': 1.0125}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.975903614457835, 'accuracy_difference': 2.409638554216862, 'accuracy_ratio': 0.9480519480519481}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.28654970760233, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}}
time to get data for dataset:  pile_FreeLaw is  2:21:42.093322 results:  {'unpruned_accuracy': 65.54461126518122, 'target_accuracy': 32.77230563259061, 'ff_frac': 0.126, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 48.09228039041704, 'accuracy_difference': 7.975944000788722, 'accuracy_ratio': 0.8577457358888694}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 38.954987110846716, 'accuracy_difference': 15.913146936347417, 'accuracy_ratio': 0.7099747018431514}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 45.64498346196251, 'accuracy_difference': 15.821389195148846, 'accuracy_ratio': 0.7426008968609865}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 32.552357272640336, 'accuracy_difference': 32.99225399254088, 'accuracy_ratio': 0.4966442953020134}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 62.16018974639664, 'accuracy_difference': 14.294836708629816, 'accuracy_ratio': 0.8130294714234577}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 42.36054236054236, 'accuracy_difference': 13.286013286013286, 'accuracy_ratio': 0.7612428454619787}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 51.37900789396745, 'accuracy_difference': 8.21557353084495, 'accuracy_ratio': 0.862142273098937}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 52.87105287105287, 'accuracy_difference': 10.738010738010743, 'accuracy_ratio': 0.8311874105865521}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 53.96093059782075, 'accuracy_difference': 7.76479827230785, 'accuracy_ratio': 0.8742048346055978}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 35.89043589043589, 'accuracy_difference': 20.7935207935208, 'accuracy_ratio': 0.63316744260716}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 44.01377274963109, 'accuracy_difference': 7.9488440727988205, 'accuracy_ratio': 0.8470276410450587}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 48.82860665844636, 'accuracy_difference': 7.407758702456604, 'accuracy_ratio': 0.8682745825602969}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 50.90014847809948, 'accuracy_difference': 7.8878990348923494, 'accuracy_ratio': 0.8658247829518548}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 55.23883646269093, 'accuracy_difference': 8.716801245257315, 'accuracy_ratio': 0.8637055065409188}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 47.223880597014926, 'accuracy_difference': 15.621890547263682, 'accuracy_ratio': 0.7514249525015833}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 72.10098835502495, 'accuracy_difference': 3.86534885996673, 'accuracy_ratio': 0.949117609171712}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 70.8643388666285, 'accuracy_difference': 8.175920625834763, 'accuracy_ratio': 0.8965600482800241}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 78.78645343367828, 'accuracy_difference': 6.745061147695196, 'accuracy_ratio': 0.9211394632644083}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 71.06352087114338, 'accuracy_difference': 10.250453720508162, 'accuracy_ratio': 0.8739398268011785}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 27.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9642857142857143}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 49.629629629629626, 'accuracy_difference': 2.962962962962969, 'accuracy_ratio': 0.9436619718309858}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 52.63157894736842, 'accuracy_difference': 5.921052631578952, 'accuracy_ratio': 0.898876404494382}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 44.0, 'accuracy_difference': 14.0, 'accuracy_ratio': 0.7586206896551724}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 56.9811320754717, 'accuracy_difference': 7.169811320754711, 'accuracy_ratio': 0.8882352941176471}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 57.638888888888886, 'accuracy_difference': 6.944444444444443, 'accuracy_ratio': 0.8924731182795699}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 7.0, 'accuracy_ratio': 0.825}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 40.0, 'accuracy_difference': 14.0, 'accuracy_ratio': 0.7407407407407407}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 24.0, 'accuracy_difference': 10.0, 'accuracy_ratio': 0.7058823529411765}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 46.24277456647399, 'accuracy_difference': 4.046242774566473, 'accuracy_ratio': 0.9195402298850575}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 42.15686274509804, 'accuracy_difference': -1.9607843137254903, 'accuracy_ratio': 1.048780487804878}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 59.0, 'accuracy_difference': 6.0, 'accuracy_ratio': 0.9076923076923077}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 42.12765957446808, 'accuracy_difference': 5.957446808510639, 'accuracy_ratio': 0.8761061946902655}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 37.719298245614034, 'accuracy_difference': 7.017543859649123, 'accuracy_ratio': 0.8431372549019608}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 46.89655172413793, 'accuracy_difference': 11.724137931034484, 'accuracy_ratio': 0.7999999999999999}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 32.01058201058201, 'accuracy_difference': 8.730158730158728, 'accuracy_ratio': 0.7857142857142858}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 35.714285714285715, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 26.0, 'accuracy_difference': 7.0, 'accuracy_ratio': 0.7878787878787878}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 56.774193548387096, 'accuracy_difference': 9.677419354838712, 'accuracy_ratio': 0.8543689320388349}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 39.90147783251231, 'accuracy_difference': 7.389162561576356, 'accuracy_ratio': 0.84375}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 54.0, 'accuracy_difference': 8.0, 'accuracy_ratio': 0.8709677419354839}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 64.24242424242425, 'accuracy_difference': 4.242424242424235, 'accuracy_ratio': 0.9380530973451329}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 58.58585858585859, 'accuracy_difference': 11.61616161616162, 'accuracy_ratio': 0.8345323741007193}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 53.8860103626943, 'accuracy_difference': 28.497409326424865, 'accuracy_ratio': 0.6540880503144655}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 45.38461538461539, 'accuracy_difference': 9.487179487179482, 'accuracy_ratio': 0.8271028037383178}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 28.14814814814815, 'accuracy_difference': 7.407407407407408, 'accuracy_ratio': 0.7916666666666666}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 58.403361344537814, 'accuracy_difference': 2.1008403361344534, 'accuracy_ratio': 0.9652777777777778}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 27.814569536423843, 'accuracy_difference': 7.284768211920525, 'accuracy_ratio': 0.7924528301886794}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 63.48623853211009, 'accuracy_difference': 10.825688073394488, 'accuracy_ratio': 0.8543209876543211}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 41.2037037037037, 'accuracy_difference': 3.2407407407407405, 'accuracy_ratio': 0.9270833333333334}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 63.23529411764706, 'accuracy_difference': 14.215686274509807, 'accuracy_ratio': 0.8164556962025317}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 68.77637130801688, 'accuracy_difference': 6.751054852320678, 'accuracy_ratio': 0.9106145251396648}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 53.81165919282511, 'accuracy_difference': 7.174887892376681, 'accuracy_ratio': 0.8823529411764706}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 52.67175572519084, 'accuracy_difference': 16.793893129770986, 'accuracy_ratio': 0.7582417582417583}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 55.37190082644628, 'accuracy_difference': 19.00826446280992, 'accuracy_ratio': 0.7444444444444445}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 52.77777777777778, 'accuracy_difference': 16.666666666666664, 'accuracy_ratio': 0.76}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 57.05521472392638, 'accuracy_difference': 14.723926380368098, 'accuracy_ratio': 0.7948717948717948}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 31.25, 'accuracy_difference': 16.07142857142857, 'accuracy_ratio': 0.6603773584905661}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 60.19417475728155, 'accuracy_difference': 10.679611650485434, 'accuracy_ratio': 0.8493150684931507}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 74.78632478632478, 'accuracy_difference': 9.401709401709411, 'accuracy_ratio': 0.8883248730964466}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 55.0, 'accuracy_difference': 8.0, 'accuracy_ratio': 0.873015873015873}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 57.8544061302682, 'accuracy_difference': 17.113665389527455, 'accuracy_ratio': 0.7717206132879046}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 57.51445086705202, 'accuracy_difference': 8.959537572254334, 'accuracy_ratio': 0.8652173913043478}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 30.391061452513966, 'accuracy_difference': 4.469273743016757, 'accuracy_ratio': 0.8717948717948719}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 56.209150326797385, 'accuracy_difference': 8.82352941176471, 'accuracy_ratio': 0.864321608040201}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 56.27009646302251, 'accuracy_difference': 6.10932475884244, 'accuracy_ratio': 0.9020618556701031}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 52.77777777777778, 'accuracy_difference': 12.654320987654323, 'accuracy_ratio': 0.8066037735849056}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 36.52482269503546, 'accuracy_difference': 9.929078014184398, 'accuracy_ratio': 0.7862595419847328}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 33.57235984354629, 'accuracy_difference': 9.582790091264663, 'accuracy_ratio': 0.7779456193353476}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 50.73529411764706, 'accuracy_difference': 9.558823529411768, 'accuracy_ratio': 0.8414634146341463}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 50.326797385620914, 'accuracy_difference': 7.352941176470587, 'accuracy_ratio': 0.8725212464589235}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 54.54545454545455, 'accuracy_difference': 10.909090909090907, 'accuracy_ratio': 0.8333333333333334}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 62.04081632653061, 'accuracy_difference': 5.3061224489796, 'accuracy_ratio': 0.921212121212121}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 77.61194029850746, 'accuracy_difference': 4.975124378109456, 'accuracy_ratio': 0.9397590361445782}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 66.0, 'accuracy_difference': 14.0, 'accuracy_ratio': 0.825}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 40.36144578313253, 'accuracy_difference': 6.024096385542165, 'accuracy_ratio': 0.8701298701298702}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 60.23391812865497, 'accuracy_difference': 21.052631578947363, 'accuracy_ratio': 0.7410071942446044}}
time to get data for dataset:  pile_Github is  2:20:40.727402 results:  {'unpruned_accuracy': 76.45502645502646, 'target_accuracy': 38.22751322751323, 'ff_frac': 0.048, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 49.76831312235039, 'accuracy_difference': 6.299911268855368, 'accuracy_ratio': 0.8876384737119747}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 45.092207019631175, 'accuracy_difference': 9.775927027562958, 'accuracy_ratio': 0.8218286953379111}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 58.278206541712606, 'accuracy_difference': 3.188166115398751, 'accuracy_ratio': 0.9481315396113602}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 56.58410634025055, 'accuracy_difference': 8.960504924930667, 'accuracy_ratio': 0.8632915086081121}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 37.4384236453202, 'accuracy_difference': 39.01660280970626, 'accuracy_ratio': 0.4896790359145687}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 50.341250341250344, 'accuracy_difference': 5.305305305305303, 'accuracy_ratio': 0.9046606704824203}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 56.164116557840366, 'accuracy_difference': 3.430464866972031, 'accuracy_ratio': 0.9424366312346688}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 55.24615524615525, 'accuracy_difference': 8.362908362908364, 'accuracy_ratio': 0.8685264663805436}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 42.93707666633945, 'accuracy_difference': 18.788652203789148, 'accuracy_ratio': 0.6956106870229007}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 42.1967421967422, 'accuracy_difference': 14.487214487214487, 'accuracy_ratio': 0.7444212554182051}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 42.59714707329071, 'accuracy_difference': 9.365469749139201, 'accuracy_ratio': 0.8197652404392276}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 53.77027411552689, 'accuracy_difference': 2.4660912453760773, 'accuracy_ratio': 0.9561477483555406}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 47.364513734224204, 'accuracy_difference': 11.423533778767627, 'accuracy_ratio': 0.8056827150749803}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 61.15380873625839, 'accuracy_difference': 2.801828971689851, 'accuracy_ratio': 0.9561910556738668}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 57.72139303482587, 'accuracy_difference': 5.124378109452735, 'accuracy_ratio': 0.91846105129829}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 73.82327037870633, 'accuracy_difference': 2.1430668362853567, 'accuracy_ratio': 0.9717892567306453}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 73.30662087387903, 'accuracy_difference': 5.733638618584237, 'accuracy_ratio': 0.9274592637296319}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 77.60112888052682, 'accuracy_difference': 7.9303857008466565, 'accuracy_ratio': 0.9072811262648482}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 42.96188747731397, 'accuracy_difference': 38.35208711433757, 'accuracy_ratio': 0.5283456834211231}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 33.0, 'accuracy_difference': -5.0, 'accuracy_ratio': 1.1785714285714286}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 54.81481481481482, 'accuracy_difference': -2.2222222222222214, 'accuracy_ratio': 1.0422535211267605}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 57.89473684210526, 'accuracy_difference': 0.6578947368421098, 'accuracy_ratio': 0.9887640449438202}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 62.64150943396226, 'accuracy_difference': 1.509433962264147, 'accuracy_ratio': 0.9764705882352942}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 64.58333333333333, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 43.0, 'accuracy_difference': -3.0, 'accuracy_ratio': 1.075}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 53.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9814814814814815}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 33.0, 'accuracy_difference': 1.0, 'accuracy_ratio': 0.9705882352941176}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 53.75722543352601, 'accuracy_difference': -3.468208092485547, 'accuracy_ratio': 1.0689655172413792}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 41.1764705882353, 'accuracy_difference': -0.9803921568627487, 'accuracy_ratio': 1.024390243902439}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 65.0, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 45.53191489361702, 'accuracy_difference': 2.5531914893617014, 'accuracy_ratio': 0.9469026548672567}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 40.35087719298246, 'accuracy_difference': 4.3859649122806985, 'accuracy_ratio': 0.9019607843137256}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 51.03448275862069, 'accuracy_difference': 7.586206896551722, 'accuracy_ratio': 0.8705882352941177}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 38.35978835978836, 'accuracy_difference': 2.3809523809523796, 'accuracy_ratio': 0.9415584415584416}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 35.714285714285715, 'accuracy_difference': 3.9682539682539684, 'accuracy_ratio': 0.9}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 31.0, 'accuracy_difference': 2.0, 'accuracy_ratio': 0.9393939393939394}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 67.41935483870968, 'accuracy_difference': -0.9677419354838719, 'accuracy_ratio': 1.0145631067961165}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 39.40886699507389, 'accuracy_difference': 7.881773399014776, 'accuracy_ratio': 0.8333333333333334}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 58.0, 'accuracy_difference': 4.0, 'accuracy_ratio': 0.9354838709677419}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 70.3030303030303, 'accuracy_difference': -1.818181818181813, 'accuracy_ratio': 1.0265486725663715}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 72.22222222222223, 'accuracy_difference': -2.0202020202020208, 'accuracy_ratio': 1.0287769784172662}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 77.72020725388602, 'accuracy_difference': 4.663212435233149, 'accuracy_ratio': 0.9433962264150945}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 54.1025641025641, 'accuracy_difference': 0.7692307692307665, 'accuracy_ratio': 0.985981308411215}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 32.22222222222222, 'accuracy_difference': 3.3333333333333357, 'accuracy_ratio': 0.9062499999999999}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 58.403361344537814, 'accuracy_difference': 2.1008403361344534, 'accuracy_ratio': 0.9652777777777778}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 32.450331125827816, 'accuracy_difference': 2.649006622516552, 'accuracy_ratio': 0.9245283018867926}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 73.02752293577981, 'accuracy_difference': 1.2844036697247674, 'accuracy_ratio': 0.9827160493827161}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 47.68518518518518, 'accuracy_difference': -3.2407407407407405, 'accuracy_ratio': 1.0729166666666667}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 77.45098039215686, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 75.9493670886076, 'accuracy_difference': -0.4219409282700468, 'accuracy_ratio': 1.005586592178771}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 61.88340807174888, 'accuracy_difference': -0.8968609865470896, 'accuracy_ratio': 1.0147058823529413}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 67.93893129770993, 'accuracy_difference': 1.5267175572518994, 'accuracy_ratio': 0.9780219780219781}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 74.3801652892562, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 68.51851851851852, 'accuracy_difference': 0.9259259259259238, 'accuracy_ratio': 0.9866666666666667}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 69.93865030674847, 'accuracy_difference': 1.8404907975460105, 'accuracy_ratio': 0.9743589743589743}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 43.75, 'accuracy_difference': 3.5714285714285694, 'accuracy_ratio': 0.9245283018867925}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 72.81553398058253, 'accuracy_difference': -1.9417475728155438, 'accuracy_ratio': 1.0273972602739727}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 82.90598290598291, 'accuracy_difference': 1.2820512820512846, 'accuracy_ratio': 0.9847715736040609}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 60.0, 'accuracy_difference': 3.0, 'accuracy_ratio': 0.9523809523809523}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 73.69093231162196, 'accuracy_difference': 1.2771392081736934, 'accuracy_ratio': 0.9829642248722317}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 65.02890173410404, 'accuracy_difference': 1.4450867052023142, 'accuracy_ratio': 0.9782608695652174}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 33.85474860335196, 'accuracy_difference': 1.0055865921787657, 'accuracy_ratio': 0.9711538461538463}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 64.70588235294117, 'accuracy_difference': 0.326797385620921, 'accuracy_ratio': 0.9949748743718592}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 62.70096463022508, 'accuracy_difference': -0.32154340836012807, 'accuracy_ratio': 1.0051546391752577}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 66.04938271604938, 'accuracy_difference': -0.6172839506172778, 'accuracy_ratio': 1.0094339622641508}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 43.262411347517734, 'accuracy_difference': 3.191489361702125, 'accuracy_ratio': 0.9312977099236642}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 42.04693611473272, 'accuracy_difference': 1.1082138200782268, 'accuracy_ratio': 0.974320241691843}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 62.5, 'accuracy_difference': -2.205882352941174, 'accuracy_ratio': 1.0365853658536586}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 55.71895424836601, 'accuracy_difference': 1.9607843137254903, 'accuracy_ratio': 0.9660056657223796}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 60.90909090909091, 'accuracy_difference': 4.545454545454547, 'accuracy_ratio': 0.9305555555555556}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 64.89795918367346, 'accuracy_difference': 2.4489795918367463, 'accuracy_ratio': 0.9636363636363635}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 82.58706467661692, 'accuracy_difference': 0.0, 'accuracy_ratio': 1.0}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 82.0, 'accuracy_difference': -2.0, 'accuracy_ratio': 1.025}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 43.373493975903614, 'accuracy_difference': 3.0120481927710827, 'accuracy_ratio': 0.935064935064935}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 81.87134502923976, 'accuracy_difference': -0.5847953216374293, 'accuracy_ratio': 1.0071942446043165}}
time to get data for dataset:  pile_PhilPapers is  2:25:17.295676 results:  {'unpruned_accuracy': 55.64655564655565, 'target_accuracy': 27.823277823277824, 'ff_frac': 0.171875, 'pile_ArXiv': {'unpruned_accuracy': 56.06822439120576, 'pruned_accuracy': 36.281179138321995, 'accuracy_difference': 19.787045252883765, 'accuracy_ratio': 0.6470898540531036}, 'pile_Enron_Emails': {'unpruned_accuracy': 54.86813404719413, 'pruned_accuracy': 39.91671624033314, 'accuracy_difference': 14.951417806860995, 'accuracy_ratio': 0.7275027105168053}, 'pile_EuroParl': {'unpruned_accuracy': 61.46637265711136, 'pruned_accuracy': 7.901506798970966, 'accuracy_difference': 53.564865858140394, 'accuracy_ratio': 0.12855007473841554}, 'pile_FreeLaw': {'unpruned_accuracy': 65.54461126518122, 'pruned_accuracy': 40.14535717701062, 'accuracy_difference': 25.3992540881706, 'accuracy_ratio': 0.6124890574846805}, 'pile_Github': {'unpruned_accuracy': 76.45502645502646, 'pruned_accuracy': 59.815727057106365, 'accuracy_difference': 16.63929939792009, 'accuracy_ratio': 0.7823648729268583}, 'pile_PhilPapers': {'unpruned_accuracy': 55.64655564655565, 'pruned_accuracy': 26.70852670852671, 'accuracy_difference': 28.93802893802894, 'accuracy_ratio': 0.47996729354047424}, 'pile_PubMed_Abstracts': {'unpruned_accuracy': 59.5945814248124, 'pruned_accuracy': 36.04911801968619, 'accuracy_difference': 23.545463405126206, 'accuracy_ratio': 0.6049059689288635}, 'pile_PubMed_Central': {'unpruned_accuracy': 63.60906360906361, 'pruned_accuracy': 43.77104377104377, 'accuracy_difference': 19.83801983801984, 'accuracy_ratio': 0.6881258941344778}, 'pile_StackExchange': {'unpruned_accuracy': 61.7257288701286, 'pruned_accuracy': 50.11288897614607, 'accuracy_difference': 11.612839893982532, 'accuracy_ratio': 0.8118638676844783}, 'pile_Gutenberg': {'unpruned_accuracy': 56.68395668395669, 'pruned_accuracy': 33.005733005733006, 'accuracy_difference': 23.67822367822368, 'accuracy_ratio': 0.5822764488681971}, 'pile_HackerNews': {'unpruned_accuracy': 51.96261682242991, 'pruned_accuracy': 39.03590752582391, 'accuracy_difference': 12.926709296605999, 'accuracy_ratio': 0.7512305944717911}, 'pile_NIH_ExPorter': {'unpruned_accuracy': 56.236365360902965, 'pruned_accuracy': 34.07948401783174, 'accuracy_difference': 22.156881343071227, 'accuracy_ratio': 0.6060043852251645}, 'pile_Ubuntu_IRC': {'unpruned_accuracy': 58.78804751299183, 'pruned_accuracy': 35.421306607275426, 'accuracy_difference': 23.366740905716405, 'accuracy_ratio': 0.6025256511444357}, 'pile_USPTO_Backgrounds': {'unpruned_accuracy': 63.95563770794824, 'pruned_accuracy': 45.53944936277848, 'accuracy_difference': 18.416188345169765, 'accuracy_ratio': 0.7120474596896866}, 'pile_Wikipedia': {'unpruned_accuracy': 62.84577114427861, 'pruned_accuracy': 40.865671641791046, 'accuracy_difference': 21.980099502487562, 'accuracy_ratio': 0.6502533248891704}, 'biology': {'unpruned_accuracy': 75.96633721499168, 'pruned_accuracy': 52.65681573539485, 'accuracy_difference': 23.30952147959683, 'accuracy_ratio': 0.6931598608785263}, 'chemistry': {'unpruned_accuracy': 79.04025949246326, 'pruned_accuracy': 53.91146727723717, 'accuracy_difference': 25.128792215226092, 'accuracy_ratio': 0.6820760410380207}, 'physics': {'unpruned_accuracy': 85.53151458137347, 'pruned_accuracy': 73.40545625587959, 'accuracy_difference': 12.126058325493887, 'accuracy_ratio': 0.858227012758469}, 'code': {'unpruned_accuracy': 81.31397459165154, 'pruned_accuracy': 68.70417422867514, 'accuracy_difference': 12.6098003629764, 'accuracy_ratio': 0.8449245603071155}, 'mmlu:abstract_algebra': {'unpruned_accuracy': 28.0, 'pruned_accuracy': 13.0, 'accuracy_difference': 15.0, 'accuracy_ratio': 0.4642857142857143}, 'mmlu:anatomy': {'unpruned_accuracy': 52.592592592592595, 'pruned_accuracy': 25.185185185185187, 'accuracy_difference': 27.40740740740741, 'accuracy_ratio': 0.47887323943661975}, 'mmlu:astronomy': {'unpruned_accuracy': 58.55263157894737, 'pruned_accuracy': 34.21052631578947, 'accuracy_difference': 24.342105263157897, 'accuracy_ratio': 0.5842696629213483}, 'mmlu:business_ethics': {'unpruned_accuracy': 58.0, 'pruned_accuracy': 22.0, 'accuracy_difference': 36.0, 'accuracy_ratio': 0.3793103448275862}, 'mmlu:clinical_knowledge': {'unpruned_accuracy': 64.15094339622641, 'pruned_accuracy': 32.45283018867924, 'accuracy_difference': 31.698113207547166, 'accuracy_ratio': 0.5058823529411764}, 'mmlu:college_biology': {'unpruned_accuracy': 64.58333333333333, 'pruned_accuracy': 27.77777777777778, 'accuracy_difference': 36.80555555555555, 'accuracy_ratio': 0.4301075268817205}, 'mmlu:college_chemistry': {'unpruned_accuracy': 40.0, 'pruned_accuracy': 16.0, 'accuracy_difference': 24.0, 'accuracy_ratio': 0.4}, 'mmlu:college_computer_science': {'unpruned_accuracy': 54.0, 'pruned_accuracy': 29.0, 'accuracy_difference': 25.0, 'accuracy_ratio': 0.5370370370370371}, 'mmlu:college_mathematics': {'unpruned_accuracy': 34.0, 'pruned_accuracy': 12.0, 'accuracy_difference': 22.0, 'accuracy_ratio': 0.35294117647058826}, 'mmlu:college_medicine': {'unpruned_accuracy': 50.28901734104046, 'pruned_accuracy': 27.745664739884393, 'accuracy_difference': 22.54335260115607, 'accuracy_ratio': 0.5517241379310345}, 'mmlu:college_physics': {'unpruned_accuracy': 40.19607843137255, 'pruned_accuracy': 15.686274509803921, 'accuracy_difference': 24.509803921568626, 'accuracy_ratio': 0.3902439024390244}, 'mmlu:computer_security': {'unpruned_accuracy': 65.0, 'pruned_accuracy': 41.0, 'accuracy_difference': 24.0, 'accuracy_ratio': 0.6307692307692307}, 'mmlu:conceptual_physics': {'unpruned_accuracy': 48.08510638297872, 'pruned_accuracy': 19.148936170212767, 'accuracy_difference': 28.936170212765955, 'accuracy_ratio': 0.3982300884955753}, 'mmlu:econometrics': {'unpruned_accuracy': 44.73684210526316, 'pruned_accuracy': 14.035087719298245, 'accuracy_difference': 30.70175438596491, 'accuracy_ratio': 0.3137254901960784}, 'mmlu:electrical_engineering': {'unpruned_accuracy': 58.62068965517241, 'pruned_accuracy': 23.448275862068964, 'accuracy_difference': 35.172413793103445, 'accuracy_ratio': 0.39999999999999997}, 'mmlu:elementary_mathematics': {'unpruned_accuracy': 40.74074074074074, 'pruned_accuracy': 15.873015873015873, 'accuracy_difference': 24.867724867724867, 'accuracy_ratio': 0.38961038961038963}, 'mmlu:formal_logic': {'unpruned_accuracy': 39.682539682539684, 'pruned_accuracy': 7.142857142857143, 'accuracy_difference': 32.53968253968254, 'accuracy_ratio': 0.18}, 'mmlu:global_facts': {'unpruned_accuracy': 33.0, 'pruned_accuracy': 13.0, 'accuracy_difference': 20.0, 'accuracy_ratio': 0.3939393939393939}, 'mmlu:high_school_biology': {'unpruned_accuracy': 66.45161290322581, 'pruned_accuracy': 33.87096774193548, 'accuracy_difference': 32.58064516129033, 'accuracy_ratio': 0.5097087378640776}, 'mmlu:high_school_chemistry': {'unpruned_accuracy': 47.29064039408867, 'pruned_accuracy': 15.763546798029557, 'accuracy_difference': 31.52709359605911, 'accuracy_ratio': 0.33333333333333337}, 'mmlu:high_school_computer_science': {'unpruned_accuracy': 62.0, 'pruned_accuracy': 39.0, 'accuracy_difference': 23.0, 'accuracy_ratio': 0.6290322580645161}, 'mmlu:high_school_european_history': {'unpruned_accuracy': 68.48484848484848, 'pruned_accuracy': 36.96969696969697, 'accuracy_difference': 31.515151515151516, 'accuracy_ratio': 0.5398230088495575}, 'mmlu:high_school_geography': {'unpruned_accuracy': 70.20202020202021, 'pruned_accuracy': 37.878787878787875, 'accuracy_difference': 32.32323232323233, 'accuracy_ratio': 0.5395683453237409}, 'mmlu:high_school_government_and_politics': {'unpruned_accuracy': 82.38341968911917, 'pruned_accuracy': 37.82383419689119, 'accuracy_difference': 44.559585492227974, 'accuracy_ratio': 0.4591194968553459}, 'mmlu:high_school_macroeconomics': {'unpruned_accuracy': 54.87179487179487, 'pruned_accuracy': 22.82051282051282, 'accuracy_difference': 32.051282051282044, 'accuracy_ratio': 0.41588785046728977}, 'mmlu:high_school_mathematics': {'unpruned_accuracy': 35.55555555555556, 'pruned_accuracy': 8.518518518518519, 'accuracy_difference': 27.037037037037038, 'accuracy_ratio': 0.23958333333333334}, 'mmlu:high_school_microeconomics': {'unpruned_accuracy': 60.50420168067227, 'pruned_accuracy': 24.789915966386555, 'accuracy_difference': 35.71428571428571, 'accuracy_ratio': 0.40972222222222227}, 'mmlu:high_school_physics': {'unpruned_accuracy': 35.09933774834437, 'pruned_accuracy': 13.907284768211921, 'accuracy_difference': 21.192052980132445, 'accuracy_ratio': 0.3962264150943397}, 'mmlu:high_school_psychology': {'unpruned_accuracy': 74.31192660550458, 'pruned_accuracy': 25.137614678899084, 'accuracy_difference': 49.1743119266055, 'accuracy_ratio': 0.33827160493827163}, 'mmlu:high_school_statistics': {'unpruned_accuracy': 44.44444444444444, 'pruned_accuracy': 20.833333333333332, 'accuracy_difference': 23.61111111111111, 'accuracy_ratio': 0.46875}, 'mmlu:high_school_us_history': {'unpruned_accuracy': 77.45098039215686, 'pruned_accuracy': 43.627450980392155, 'accuracy_difference': 33.82352941176471, 'accuracy_ratio': 0.5632911392405063}, 'mmlu:high_school_world_history': {'unpruned_accuracy': 75.52742616033755, 'pruned_accuracy': 51.0548523206751, 'accuracy_difference': 24.472573839662452, 'accuracy_ratio': 0.6759776536312848}, 'mmlu:human_aging': {'unpruned_accuracy': 60.98654708520179, 'pruned_accuracy': 30.493273542600896, 'accuracy_difference': 30.493273542600896, 'accuracy_ratio': 0.5}, 'mmlu:human_sexuality': {'unpruned_accuracy': 69.46564885496183, 'pruned_accuracy': 28.244274809160306, 'accuracy_difference': 41.221374045801525, 'accuracy_ratio': 0.40659340659340665}, 'mmlu:international_law': {'unpruned_accuracy': 74.3801652892562, 'pruned_accuracy': 48.760330578512395, 'accuracy_difference': 25.619834710743802, 'accuracy_ratio': 0.6555555555555556}, 'mmlu:jurisprudence': {'unpruned_accuracy': 69.44444444444444, 'pruned_accuracy': 25.0, 'accuracy_difference': 44.44444444444444, 'accuracy_ratio': 0.36}, 'mmlu:logical_fallacies': {'unpruned_accuracy': 71.77914110429448, 'pruned_accuracy': 25.153374233128833, 'accuracy_difference': 46.62576687116565, 'accuracy_ratio': 0.3504273504273504}, 'mmlu:machine_learning': {'unpruned_accuracy': 47.32142857142857, 'pruned_accuracy': 22.321428571428573, 'accuracy_difference': 24.999999999999996, 'accuracy_ratio': 0.47169811320754723}, 'mmlu:management': {'unpruned_accuracy': 70.87378640776699, 'pruned_accuracy': 25.24271844660194, 'accuracy_difference': 45.631067961165044, 'accuracy_ratio': 0.35616438356164387}, 'mmlu:marketing': {'unpruned_accuracy': 84.1880341880342, 'pruned_accuracy': 35.8974358974359, 'accuracy_difference': 48.2905982905983, 'accuracy_ratio': 0.42639593908629436}, 'mmlu:medical_genetics': {'unpruned_accuracy': 63.0, 'pruned_accuracy': 34.0, 'accuracy_difference': 29.0, 'accuracy_ratio': 0.5396825396825397}, 'mmlu:miscellaneous': {'unpruned_accuracy': 74.96807151979566, 'pruned_accuracy': 39.33588761174968, 'accuracy_difference': 35.632183908045974, 'accuracy_ratio': 0.5247018739352641}, 'mmlu:moral_disputes': {'unpruned_accuracy': 66.47398843930635, 'pruned_accuracy': 12.427745664739884, 'accuracy_difference': 54.046242774566466, 'accuracy_ratio': 0.18695652173913044}, 'mmlu:moral_scenarios': {'unpruned_accuracy': 34.86033519553072, 'pruned_accuracy': 31.06145251396648, 'accuracy_difference': 3.798882681564244, 'accuracy_ratio': 0.8910256410256411}, 'mmlu:nutrition': {'unpruned_accuracy': 65.0326797385621, 'pruned_accuracy': 31.69934640522876, 'accuracy_difference': 33.333333333333336, 'accuracy_ratio': 0.48743718592964824}, 'mmlu:philosophy': {'unpruned_accuracy': 62.37942122186495, 'pruned_accuracy': 21.221864951768488, 'accuracy_difference': 41.157556270096464, 'accuracy_ratio': 0.3402061855670103}, 'mmlu:prehistory': {'unpruned_accuracy': 65.4320987654321, 'pruned_accuracy': 33.333333333333336, 'accuracy_difference': 32.098765432098766, 'accuracy_ratio': 0.5094339622641509}, 'mmlu:professional_accounting': {'unpruned_accuracy': 46.45390070921986, 'pruned_accuracy': 22.69503546099291, 'accuracy_difference': 23.75886524822695, 'accuracy_ratio': 0.4885496183206107}, 'mmlu:professional_law': {'unpruned_accuracy': 43.15514993481095, 'pruned_accuracy': 25.619295958279007, 'accuracy_difference': 17.535853976531943, 'accuracy_ratio': 0.5936555891238671}, 'mmlu:professional_medicine': {'unpruned_accuracy': 60.294117647058826, 'pruned_accuracy': 12.132352941176471, 'accuracy_difference': 48.161764705882355, 'accuracy_ratio': 0.20121951219512196}, 'mmlu:professional_psychology': {'unpruned_accuracy': 57.6797385620915, 'pruned_accuracy': 27.61437908496732, 'accuracy_difference': 30.06535947712418, 'accuracy_ratio': 0.4787535410764873}, 'mmlu:public_relations': {'unpruned_accuracy': 65.45454545454545, 'pruned_accuracy': 25.454545454545453, 'accuracy_difference': 40.0, 'accuracy_ratio': 0.3888888888888889}, 'mmlu:security_studies': {'unpruned_accuracy': 67.34693877551021, 'pruned_accuracy': 37.95918367346939, 'accuracy_difference': 29.38775510204082, 'accuracy_ratio': 0.5636363636363636}, 'mmlu:sociology': {'unpruned_accuracy': 82.58706467661692, 'pruned_accuracy': 39.30348258706468, 'accuracy_difference': 43.28358208955224, 'accuracy_ratio': 0.4759036144578313}, 'mmlu:us_foreign_policy': {'unpruned_accuracy': 80.0, 'pruned_accuracy': 48.0, 'accuracy_difference': 32.0, 'accuracy_ratio': 0.6}, 'mmlu:virology': {'unpruned_accuracy': 46.3855421686747, 'pruned_accuracy': 20.481927710843372, 'accuracy_difference': 25.903614457831324, 'accuracy_ratio': 0.44155844155844154}, 'mmlu:world_religions': {'unpruned_accuracy': 81.28654970760233, 'pruned_accuracy': 30.4093567251462, 'accuracy_difference': 50.87719298245614, 'accuracy_ratio': 0.3741007194244605}}
}
# Out:
#   Cell In[1], line 1
#     data =
#            ^
# SyntaxError: invalid syntax
